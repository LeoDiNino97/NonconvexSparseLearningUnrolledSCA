# %%
import numpy as np
import cvxpy as cp

from tqdm import tqdm
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator

import pickle

import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.utils.data as Data
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
from models.LISTA import LISTA_Net, LISTA
from models.L20_ISTA import L2O_ISTA
from models.TiLISTA import TiLISTA
from models.ALISTA import ALISTA

from utils.ISTA_FISTA import *
from utils.train import train, layerwise_train, layerwise_train_DC
from utils.synthetic_data import SyntheticSignals

# %%
torch.cuda.is_available()
# Out:
# True

# %%
class LDC_ISTA(nn.Module):
    def __init__(self, A, mode, lambd=0.1, p =0.012, p_max = 0.12, T = 5):
        super().__init__()
    
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        assert mode in ['EXP', 'PNEG', 'SCAD']

        self.mode = mode
        self.linear_shared = False
        self.A = A.to(self.device)  # Move A to the correct device
        self.A.requires_grad = False

        self.T = T

        self.L = torch.max(torch.real(torch.linalg.eigvals(A.t() @ A))).to(self.device)

        # Initialization of the learnable parameters
        self.lambd = nn.ParameterList([
            nn.Parameter(torch.tensor(1).reshape(1, 1).to(self.device) * lambd / self.L, requires_grad=True)
            for _ in range(self.T + 1)
        ])

        self.theta = nn.ParameterList([
            nn.Parameter(torch.tensor(1.0).reshape(1, 1).to(self.device), requires_grad=True)
            for _ in range(self.T + 1)
            ])
        
        # Linear layers
        self.Ws_1 = nn.ModuleList()
        self.Ws_2 = nn.ModuleList()
        
        for _ in range(self.T + 1):
            W1 = nn.Linear(A.shape[1], A.shape[0], bias=False).to(self.device)
            W2 = nn.Linear(A.shape[1], A.shape[1], bias=False).to(self.device)

            W1.weight.data = torch.clone(self.A.T).to(self.device) / self.L
            W2.weight.data = torch.eye(A.shape[1]).to(self.device) - torch.clone(A.t() @ A).to(self.device)/self.L
            self.Ws_1.append(W1)
            self.Ws_2.append(W2)


        # Support selection mechanism parameters
        self.p = p
        self.p_max = p_max

        # Losses when doing inference (placeholder for NMSE accumulation)
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Mode setting for the layer
        if mode == 'EXP':
            self.ddx = self.ddxEXP
            self.eta = self.etaEXP

        if mode == 'PNEG':
            self.P = nn.ParameterList([
            nn.Parameter(torch.tensor(1.0).reshape(1, 1).to(self.device) * (-1), requires_grad=True)
            for _ in range(self.T + 1)
            ])            

            self.ddx = self.ddxNEG
            self.eta = self.etaNEG

        if mode == 'SCAD':
            self.a = nn.ParameterList([
            nn.Parameter(torch.tensor(1.0).reshape(1, 1).to(self.device), requires_grad=True)
            for _ in range(self.T + 1)
            ])        
            
            self.ddx = self.ddxSCAD
            self.eta = self.etaSCAD

    #_________________________________________________________________
    #______________ METHODS FOR ENABLING DIFFERENT LAYERS_____________
    #_________________________________________________________________
    
    # Derivatives of the nonconvex components
    def ddxEXP(self, x, t):
        return torch.sign(x) * self.theta[t] * (1 - torch.exp(-self.theta[t] * torch.abs(x)))

    def ddxNEG(self, x, t):
        return - torch.sign(x) * self.P[t] * self.theta[t] * (1 - (1 + self.theta[t] * torch.abs(x)) ** (self.P[t] - 1))

    def ddxSCAD(self, x, t):
        abs_x = torch.abs(x)

        mask1 = (abs_x <= 1)
        mask2 = (1 / self.theta[t] < abs_x) & (abs_x <= self.a[t] / self.theta[t])
        mask3 = (abs_x > self.a[t] / self.theta[t])

        # Compute the value for each condition
        val1 = torch.zeros_like(x)
        val2 = torch.sign(x) * (2 * self.theta[t] * (self.theta[t] * abs_x - 1)) / (self.a[t] ** 2 - 1)
        val3 = torch.sign(x) * (2 * self.theta[t] / (self.a[t] + 1))

        # Apply the masks to compute the final result
        result = torch.where(mask1, val1, torch.where(mask2, val2, val3))

        return result

    # Parametrization for the surrogates
    def etaEXP(self, t):
        return self.theta[t]

    def etaNEG(self, t):
        return -self.P[t] * self.theta[t]

    def etaSCAD(self, t):
        return 2 * self.theta[t] / (self.a[t] + 1)
    
    #___________________________________________________________________
    #___________________________________________________________________
        
    def _shrink(self, x, beta, t):
        # Get the absolute values of the elements in x
        abs_x = torch.abs(x)
        
        # Sort the elements of x by magnitude along the last dimension (num_features)
        sorted_abs_x, _ = torch.sort(abs_x, dim=-1, descending=True)

        # Determine the threshold index corresponding to the top p% elements in each sample
        p = torch.min(torch.tensor([self.p * t, self.p_max], device=self.device))
        threshold_idx = int(p * x.shape[-1])
        
        # Get the magnitude threshold for the top p% of elements (per batch)
        if threshold_idx > 0:
            threshold_value = sorted_abs_x[:, threshold_idx - 1:threshold_idx]  # Shape: (batch_size, 1)
        else:
            threshold_value = torch.zeros(x.shape[0], 1, device=x.device)  # Shape: (batch_size, 1)

        # Create a mask to exclude the top p% of elements from shrinkage
        mask = abs_x >= threshold_value
        
        # Apply soft thresholding only to elements outside the top p%
        x_shrink = beta * F.softshrink(x / beta, lambd=1)
        
        # Return the original values for the top p% and the shrinked values for others
        return torch.where(mask, x, x_shrink)

    
    def forward(self, y, its=None, S=None):     
        # Move inputs to the correct device
        if its is None:
            its = self.T

        y = y.to(self.device)
        if S is not None:
            S = S.to(self.device)

        # Initial sparse estimate using the first layer
        x = torch.zeros((y.shape[0], self.A.shape[1])).to(self.device)
        x = self._shrink(self.Ws_1[0](y) + self.lambd[0] * self.ddx(x, 0), self.eta(0) * self.lambd[0], 1)
        
        # Loop over layers to refine the estimate
        for t in range(1, its + 1):
            x = self._shrink(self.Ws_2[t](x) + self.Ws_1[t](y) + self.lambd[t] * self.ddx(x, t), 
                             self.eta(t) * self.lambd[t],
                             t)
            
            if S is not None:  # During inference, compute the NMSE at each layer
                with torch.no_grad():
                    mse_loss = F.mse_loss(x.detach(), S.detach(), reduction="sum")
                    signal_power = torch.sum(S.detach() ** 2)

                    self.losses[t - 1] += mse_loss.item()
                    self.est_powers[t - 1] += signal_power.item() + 1e-6

        return x

    # Method to compute NMSE during inference mode
    def compute_nmse_inference(self, test_loader):
        # Reset the losses accumulator
        self.losses = torch.zeros(self.T, device=self.device)
        
        # Iterate over test_loader
        for _, (Y, S) in enumerate(test_loader):
            Y, S = Y.to(self.device), S.to(self.device)
            _ = self.forward(Y, its = None, S = S)  # This will accumulate NMSE values
        
        # Convert accumulated NMSE to dB
        nmse_db = 10 * torch.log10(self.losses / self.est_powers)
        
        # Reset the losses after inference
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Return NMSE in dB for each layer
        return nmse_db

# %%
import torch.optim as optim

def layerwise_train_DC(
        model, 
        train_loader, 
        valid_loader, 
        model_class,
        DCSIP,
        lr=5e-4, 
        ft_lr=3e-5,
        num_epochs=100, 
        verbose=True, 
        clip_value=10.0, 
        eps=1e-6, 
        fine_tune_epochs=100, 
        patience=10):

    assert model_class in [
        'L-DC-ISTA',
        'LISTA-DC-CPSS',
        'TIL-DC-ISTA',
        'AL-DC-ISTA'
    ]

    assert DCSIP in [
        'EXP',
        'PNEG',
        'SCAD'
    ]

    device = model.device
    model = model.to(device)

    linear_shared = model.linear_shared

    loss_train_all = {}
    loss_test_all = {}

    T = model.T  # Number of layers/iterations

    for t in range(T):

        if verbose:
            print(f"===== Training Layer {t+1}/{T} =====")

        # Freeze parameters beyond current layer t
        for layer_idx in range(t):
            
            if DCSIP == 'SCAD':
                model.a[layer_idx].requires_grad = False
            if DCSIP == 'PNEG':
                model.P[layer_idx].requires_grad = False
                
            model.lambd[layer_idx].requires_grad = False
            model.theta[layer_idx].requires_grad = False

            if model_class != 'L-DC-ISTA' and linear_shared == True:
                model.mu[layer_idx].requires_grad = False

            if not linear_shared:
                if model_class == 'L-DC-ISTA':
                    model.Ws_1[layer_idx].weight.requires_grad = False
                    model.Ws_2[layer_idx].weight.requires_grad = False
                if model_class == 'L-DC-ISTA-CPSS':
                    model.Ws[layer_idx].weight.requires_grad = False            


        # Define optimizer to include W1, W2, and parameters up to layer t
        if model_class == 'L-DC-ISTA':
            params = list(model.lambd)[:t+1] + list(model.theta)[:t+1] 
            if DCSIP == 'PNEG':
                params += list(model.P)[:t+1]
            if DCSIP == 'SCAD':
                params += list(model.a)[:t+1]
            if not linear_shared:
                optimizer = optim.Adam(
                    list(model.Ws_1.parameters())[:t+1] + 
                    list(model.Ws_2.parameters())[:t+1] + 
                    params,
                    lr=lr,
                    eps=eps
                )

        if model_class == 'LISTA-CPSS':
            optimizer = optim.Adam(
                list(model.Ws.parameters())[:t+1] +
                list(model.beta)[:t+1],
                lr=lr,
                eps=eps
            )

        if model_class == 'TILISTA':
            optimizer = optim.Adam(
                list(model.W.parameters()) +
                list(model.beta)[:t+1] + 
                list(model.mu)[:t+1],
                lr=lr,
                eps=eps
            )

        if model_class == 'AL-DC-ISTA':
            params = list(model.lambd)[:t+1] + list(model.theta)[:t+1] + list(model.mu)[:t+1]
            if DCSIP == 'PNEG':
                params += list(model.P)[:t+1]
            if DCSIP == 'SCAD':
                params += list(model.a)[:t+1]
            optimizer = optim.Adam(
                params,
                lr=lr,
                eps=eps
            )

        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

        # Initialize loss tracking for current layer
        loss_train = np.zeros((num_epochs,))
        loss_test = np.zeros((num_epochs,))

        # Early stopping variables
        best_val_loss = float('inf')
        epochs_since_improvement = 0
        best_model_state = None

        for epoch in range(num_epochs):
            model.train()
            train_loss = 0.0
            signal_power_train = 0.0

            for Y, S in train_loader:
                Y = Y.to(device)
                S = S.to(device)

                optimizer.zero_grad()
                S_hat = model(y=Y, its=t, S = None)

                mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                signal_power = torch.sum(S ** 2)

                loss = mse_loss
                loss.backward()

                # Apply gradient clipping
                torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)

                optimizer.step()

                train_loss += mse_loss.item()
                signal_power_train += signal_power.item()

            # Compute NMSE in dB for training set
            nmse_train = train_loss / (signal_power_train + eps)
            loss_train[epoch] = 10 * np.log10(nmse_train + eps)
            scheduler.step()

            # Validation
            model.eval()
            test_loss_epoch = 0.0
            signal_power_test = 0.0

            with torch.no_grad():
                for Y, S in valid_loader:
                    Y = Y.to(device)
                    S = S.to(device)

                    S_hat = model(Y, its=t)

                    mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                    signal_power = torch.sum(S ** 2)

                    test_loss_epoch += mse_loss.item()
                    signal_power_test += signal_power.item()

            nmse_test = test_loss_epoch / (signal_power_test + eps)
            loss_test[epoch] = 10 * np.log10(nmse_test + eps)

            if verbose and (epoch % 10 == 0 or epoch == num_epochs - 1):
                print(
                    f"Layer {t+1}, Epoch {epoch+1}/{num_epochs}, "
                    f"Train NMSE (dB): {loss_train[epoch]:.6f}, "
                    f"Validation NMSE (dB): {loss_test[epoch]:.6f}"
                )

            # Early stopping check
            if loss_test[epoch] < best_val_loss:
                best_val_loss = loss_test[epoch]
                epochs_since_improvement = 0
                best_model_state = model.state_dict()  # Save the best model state
            else:
                epochs_since_improvement += 1

            if epochs_since_improvement >= patience:
                if verbose:
                    print(f"Early stopping triggered after {epoch+1} epochs")
                model.load_state_dict(best_model_state)  # Restore best model state
                break

        # Store losses for current layer
        loss_train_all[f"Layer_{t+1}"] = loss_train[:epoch+1]
        loss_test_all[f"Layer_{t+1}"] = loss_test[:epoch+1]

        if verbose:
            print(f"===== Finished Training Layer {t+1}/{T} =====\n")

        # Optionally, fine-tune the entire network
        if fine_tune_epochs > 0:
            if verbose:
                print("===== Fine-Tuning the Entire Network =====")

            # Unfreeze all parameters
            for layer_idx in range(t + 1):                
                if DCSIP == 'SCAD':
                    model.a[layer_idx].requires_grad = True
                if DCSIP == 'PNEG':
                    model.P[layer_idx].requires_grad = True
                    
                model.lambd[layer_idx].requires_grad = True
                model.theta[layer_idx].requires_grad = True

                if model_class != 'L-DC-ISTA' and linear_shared == True:
                    model.mu[layer_idx].requires_grad = True

                if not linear_shared:
                    if model_class == 'L-DC-ISTA':
                        model.Ws_1[layer_idx].weight.requires_grad = True
                        model.Ws_2[layer_idx].weight.requires_grad = True
                    if model_class == 'L-DC-ISTA-CPSS':
                        model.Ws[layer_idx].weight.requires_grad = True       

            if model_class == 'L-DC-ISTA':
                params = list(model.lambd)[:t+1] + list(model.theta)[:t+1] 
                if DCSIP == 'PNEG':
                    params += list(model.P)[:t+1]
                if DCSIP == 'SCAD':
                    params += list(model.a)[:t+1]
                if not linear_shared:
                    optimizer = optim.Adam(
                        list(model.Ws_1.parameters())[:t+1] + 
                        list(model.Ws_2.parameters())[:t+1] + 
                        params,
                        lr=lr,
                        eps=eps
                    )

            if model_class == 'LISTA-CPSS':
                optimizer = optim.Adam(
                    list(model.Ws.parameters())[:t+1] +
                    list(model.beta)[:t+1],
                    lr=ft_lr,
                    eps=eps
                )

            if model_class == 'TILISTA':
                optimizer = optim.Adam(
                    list(model.W.parameters()) +
                    list(model.beta)[:t+1] + 
                    list(model.mu)[:t+1],
                    lr=ft_lr,
                    eps=eps
                )

            if model_class == 'AL-DC-ISTA':
                params = list(model.lambd)[:t+1] + list(model.theta)[:t+1] + list(model.mu)[:t+1]
                if DCSIP == 'PNEG':
                    params += list(model.P)[:t+1]
                if DCSIP == 'SCAD':
                    params += list(model.a)[:t+1]
                optimizer = optim.Adam(
                    params,
                    lr=lr,
                    eps=eps
                )

            scheduler_ft = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

            # Initialize loss tracking for fine-tuning
            loss_train_ft = np.zeros((fine_tune_epochs,))
            loss_test_ft = np.zeros((fine_tune_epochs,))

            best_val_loss_ft = float('inf')
            epochs_since_improvement_ft = 0
            best_model_state_ft = None

            for epoch in range(fine_tune_epochs):
                model.train()
                train_loss = 0.0
                signal_power_train = 0.0

                for Y, S in train_loader:
                    Y = Y.to(device)
                    S = S.to(device)

                    optimizer.zero_grad()
                    S_hat = model(Y, its=t)

                    mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                    signal_power = torch.sum(S ** 2)

                    loss = mse_loss
                    loss.backward()

                    # Apply gradient clipping
                    torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)

                    optimizer.step()

                    train_loss += mse_loss.item()
                    signal_power_train += signal_power.item()

                # Compute NMSE in dB for training set
                nmse_train = train_loss / (signal_power_train + eps)
                loss_train_ft[epoch] = 10 * np.log10(nmse_train + eps)
                scheduler_ft.step()

                # Validation
                model.eval()
                test_loss_epoch = 0.0
                signal_power_test = 0.0

                with torch.no_grad():
                    for Y, S in valid_loader:
                        Y = Y.to(device)
                        S = S.to(device)

                        S_hat = model(Y, its=t)

                        mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                        signal_power = torch.sum(S ** 2)

                        test_loss_epoch += mse_loss.item()
                        signal_power_test += signal_power.item()

                nmse_test = test_loss_epoch / (signal_power_test + eps)
                loss_test_ft[epoch] = 10 * np.log10(nmse_test + eps)

                if verbose and (epoch % 10 == 0 or epoch == fine_tune_epochs - 1):
                    print(
                        f"Fine-Tune Epoch {epoch+1}/{fine_tune_epochs}, "
                        f"Train NMSE (dB): {loss_train_ft[epoch]:.6f}, "
                        f"Validation NMSE (dB): {loss_test_ft[epoch]:.6f}"
                    )

                # Early stopping for fine-tuning
                if loss_test_ft[epoch] < best_val_loss_ft:
                    best_val_loss_ft = loss_test_ft[epoch]
                    epochs_since_improvement_ft = 0
                    best_model_state_ft = model.state_dict()  # Save the best model state
                else:
                    epochs_since_improvement_ft += 1

                if epochs_since_improvement_ft >= patience:
                    if verbose:
                        print(f"Early stopping for fine-tuning triggered after {epoch+1} epochs")
                    model.load_state_dict(best_model_state_ft)  # Restore best model state
                    break

            # Store fine-tuning losses
            loss_train_all["Fine_Tune"] = loss_train_ft[:epoch+1]
            loss_test_all["Fine_Tune"] = loss_test_ft[:epoch+1]

            if verbose:
                print("===== Finished Fine-Tuning =====\n")

    return loss_train_all, loss_test_all

# %%
n_ = 500
m_ = 250
p_ = 0.1

# Sensing matrix

A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
A_ /= torch.linalg.norm(A_, dim = 0)

# Building a training set and a test set 
train_set = SyntheticSignals(
    A = A_,
    n = n_,        
    m = m_,
    p = p_,
    SNR = None,
    size = 10000,
    batch_size = 1000
    ).set_loader()

test_set = SyntheticSignals(
    A = A_,
    n = n_,        
    m = m_,
    p = p_,
    SNR = None,
    size = 1000
    ).set_loader()

# %%
model2 = LISTA(torch.clone(A_), 0.4, T = 16)

# %%
layerwise_train(model2, train_set, test_set, model_class='LISTA',lr = 3e-3, verbose = True)
# Out:
# ===== Training Layer 1/16 =====
# Layer 1, Epoch 1/100, Train NMSE (dB): -1.920432, Validation NMSE (dB): -2.480774
# Layer 1, Epoch 11/100, Train NMSE (dB): -6.050169, Validation NMSE (dB): -5.594059
# Layer 1, Epoch 21/100, Train NMSE (dB): -6.549745, Validation NMSE (dB): -5.699549
# Early stopping triggered after 24 epochs
# ===== Finished Training Layer 1/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -6.693543, Validation NMSE (dB): -5.696904
# Fine-Tune Epoch 11/100, Train NMSE (dB): -6.704248, Validation NMSE (dB): -5.700602
# Fine-Tune Epoch 21/100, Train NMSE (dB): -6.710351, Validation NMSE (dB): -5.704369
# Fine-Tune Epoch 31/100, Train NMSE (dB): -6.713469, Validation NMSE (dB): -5.706460
# Fine-Tune Epoch 41/100, Train NMSE (dB): -6.715829, Validation NMSE (dB): -5.708848
# Fine-Tune Epoch 51/100, Train NMSE (dB): -6.719496, Validation NMSE (dB): -5.709773
# Fine-Tune Epoch 61/100, Train NMSE (dB): -6.719139, Validation NMSE (dB): -5.709997
# Fine-Tune Epoch 71/100, Train NMSE (dB): -6.719345, Validation NMSE (dB): -5.710124
# Fine-Tune Epoch 81/100, Train NMSE (dB): -6.719413, Validation NMSE (dB): -5.710190
# Fine-Tune Epoch 91/100, Train NMSE (dB): -6.719237, Validation NMSE (dB): -5.710277
# Early stopping for fine-tuning triggered after 97 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 2/16 =====
# Layer 2, Epoch 1/100, Train NMSE (dB): -7.232744, Validation NMSE (dB): -6.668415
# Layer 2, Epoch 11/100, Train NMSE (dB): -9.789506, Validation NMSE (dB): -7.806301
# Layer 2, Epoch 21/100, Train NMSE (dB): -10.763591, Validation NMSE (dB): -8.350093
# Layer 2, Epoch 31/100, Train NMSE (dB): -11.413194, Validation NMSE (dB): -8.668727
# Layer 2, Epoch 41/100, Train NMSE (dB): -11.822227, Validation NMSE (dB): -8.824985
# Layer 2, Epoch 51/100, Train NMSE (dB): -12.386806, Validation NMSE (dB): -8.901426
# Layer 2, Epoch 61/100, Train NMSE (dB): -12.526680, Validation NMSE (dB): -8.924275
# Layer 2, Epoch 71/100, Train NMSE (dB): -12.547198, Validation NMSE (dB): -8.928741
# Layer 2, Epoch 81/100, Train NMSE (dB): -12.566298, Validation NMSE (dB): -8.931715
# Layer 2, Epoch 91/100, Train NMSE (dB): -12.584084, Validation NMSE (dB): -8.933033
# Layer 2, Epoch 100/100, Train NMSE (dB): -12.598945, Validation NMSE (dB): -8.935909
# ===== Finished Training Layer 2/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -12.606323, Validation NMSE (dB): -8.937037
# Fine-Tune Epoch 11/100, Train NMSE (dB): -12.669231, Validation NMSE (dB): -8.944302
# Fine-Tune Epoch 21/100, Train NMSE (dB): -12.699996, Validation NMSE (dB): -8.941176
# Early stopping for fine-tuning triggered after 21 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 3/16 =====
# Layer 3, Epoch 1/100, Train NMSE (dB): -12.271261, Validation NMSE (dB): -9.213641
# Layer 3, Epoch 11/100, Train NMSE (dB): -13.530104, Validation NMSE (dB): -9.767949
# Layer 3, Epoch 21/100, Train NMSE (dB): -13.867824, Validation NMSE (dB): -10.035254
# Layer 3, Epoch 31/100, Train NMSE (dB): -14.291041, Validation NMSE (dB): -10.230980
# Layer 3, Epoch 41/100, Train NMSE (dB): -14.593491, Validation NMSE (dB): -10.378643
# Layer 3, Epoch 51/100, Train NMSE (dB): -15.358700, Validation NMSE (dB): -10.572063
# Layer 3, Epoch 61/100, Train NMSE (dB): -15.671741, Validation NMSE (dB): -10.630518
# Layer 3, Epoch 71/100, Train NMSE (dB): -15.711512, Validation NMSE (dB): -10.644621
# Layer 3, Epoch 81/100, Train NMSE (dB): -15.745787, Validation NMSE (dB): -10.656244
# Layer 3, Epoch 91/100, Train NMSE (dB): -15.775658, Validation NMSE (dB): -10.666222
# Layer 3, Epoch 100/100, Train NMSE (dB): -15.800371, Validation NMSE (dB): -10.673936
# ===== Finished Training Layer 3/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -15.812946, Validation NMSE (dB): -10.677601
# Fine-Tune Epoch 11/100, Train NMSE (dB): -16.009034, Validation NMSE (dB): -10.705632
# Fine-Tune Epoch 21/100, Train NMSE (dB): -16.127409, Validation NMSE (dB): -10.717654
# Fine-Tune Epoch 31/100, Train NMSE (dB): -16.226936, Validation NMSE (dB): -10.723292
# Fine-Tune Epoch 41/100, Train NMSE (dB): -16.318293, Validation NMSE (dB): -10.726875
# Fine-Tune Epoch 51/100, Train NMSE (dB): -16.416060, Validation NMSE (dB): -10.727316
# Early stopping for fine-tuning triggered after 53 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 4/16 =====
# Layer 4, Epoch 1/100, Train NMSE (dB): -14.995271, Validation NMSE (dB): -10.713101
# Layer 4, Epoch 11/100, Train NMSE (dB): -15.411469, Validation NMSE (dB): -10.591997
# Layer 4, Epoch 21/100, Train NMSE (dB): -16.342729, Validation NMSE (dB): -11.109667
# Early stopping triggered after 30 epochs
# ===== Finished Training Layer 4/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -15.272786, Validation NMSE (dB): -10.760590
# Fine-Tune Epoch 11/100, Train NMSE (dB): -17.217952, Validation NMSE (dB): -11.285789
# Fine-Tune Epoch 21/100, Train NMSE (dB): -17.552500, Validation NMSE (dB): -11.311773
# Fine-Tune Epoch 31/100, Train NMSE (dB): -17.743834, Validation NMSE (dB): -11.324205
# Fine-Tune Epoch 41/100, Train NMSE (dB): -17.899625, Validation NMSE (dB): -11.335602
# Fine-Tune Epoch 51/100, Train NMSE (dB): -18.062775, Validation NMSE (dB): -11.344212
# Fine-Tune Epoch 61/100, Train NMSE (dB): -18.076144, Validation NMSE (dB): -11.344026
# Early stopping for fine-tuning triggered after 65 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 5/16 =====
# Layer 5, Epoch 1/100, Train NMSE (dB): -16.213489, Validation NMSE (dB): -11.214117
# Layer 5, Epoch 11/100, Train NMSE (dB): -17.621954, Validation NMSE (dB): -11.514834
# Layer 5, Epoch 21/100, Train NMSE (dB): -17.641524, Validation NMSE (dB): -11.598472
# Layer 5, Epoch 31/100, Train NMSE (dB): -17.109767, Validation NMSE (dB): -11.340904
# Layer 5, Epoch 41/100, Train NMSE (dB): -17.486884, Validation NMSE (dB): -12.032604
# Layer 5, Epoch 51/100, Train NMSE (dB): -18.927401, Validation NMSE (dB): -12.038919
# Layer 5, Epoch 61/100, Train NMSE (dB): -19.675523, Validation NMSE (dB): -12.091213
# Layer 5, Epoch 71/100, Train NMSE (dB): -19.760334, Validation NMSE (dB): -12.116423
# Layer 5, Epoch 81/100, Train NMSE (dB): -19.821494, Validation NMSE (dB): -12.133717
# Layer 5, Epoch 91/100, Train NMSE (dB): -19.870716, Validation NMSE (dB): -12.147791
# Layer 5, Epoch 100/100, Train NMSE (dB): -19.910798, Validation NMSE (dB): -12.164486
# ===== Finished Training Layer 5/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -19.894159, Validation NMSE (dB): -12.181828
# Fine-Tune Epoch 11/100, Train NMSE (dB): -20.279063, Validation NMSE (dB): -12.277221
# Fine-Tune Epoch 21/100, Train NMSE (dB): -20.488114, Validation NMSE (dB): -12.335617
# Fine-Tune Epoch 31/100, Train NMSE (dB): -20.663243, Validation NMSE (dB): -12.366486
# Fine-Tune Epoch 41/100, Train NMSE (dB): -20.811326, Validation NMSE (dB): -12.372106
# Early stopping for fine-tuning triggered after 50 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 6/16 =====
# Layer 6, Epoch 1/100, Train NMSE (dB): -18.389984, Validation NMSE (dB): -12.423799
# Layer 6, Epoch 11/100, Train NMSE (dB): -19.158207, Validation NMSE (dB): -12.228884
# Layer 6, Epoch 21/100, Train NMSE (dB): -19.968318, Validation NMSE (dB): -12.694012
# Layer 6, Epoch 31/100, Train NMSE (dB): -19.806121, Validation NMSE (dB): -12.657534
# Layer 6, Epoch 41/100, Train NMSE (dB): -19.311750, Validation NMSE (dB): -12.941771
# Layer 6, Epoch 51/100, Train NMSE (dB): -20.830456, Validation NMSE (dB): -13.012784
# Layer 6, Epoch 61/100, Train NMSE (dB): -22.032244, Validation NMSE (dB): -12.854329
# Early stopping triggered after 61 epochs
# ===== Finished Training Layer 6/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -22.082601, Validation NMSE (dB): -12.871422
# Fine-Tune Epoch 11/100, Train NMSE (dB): -22.466596, Validation NMSE (dB): -12.918123
# Fine-Tune Epoch 21/100, Train NMSE (dB): -22.637484, Validation NMSE (dB): -12.946416
# Fine-Tune Epoch 31/100, Train NMSE (dB): -22.788615, Validation NMSE (dB): -12.960058
# Fine-Tune Epoch 41/100, Train NMSE (dB): -22.931584, Validation NMSE (dB): -12.959279
# Early stopping for fine-tuning triggered after 46 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 7/16 =====
# Layer 7, Epoch 1/100, Train NMSE (dB): -19.935918, Validation NMSE (dB): -13.194012
# Layer 7, Epoch 11/100, Train NMSE (dB): -21.961807, Validation NMSE (dB): -13.175605
# Layer 7, Epoch 21/100, Train NMSE (dB): -22.136237, Validation NMSE (dB): -13.334468
# Layer 7, Epoch 31/100, Train NMSE (dB): -21.309709, Validation NMSE (dB): -13.113342
# Layer 7, Epoch 41/100, Train NMSE (dB): -21.354684, Validation NMSE (dB): -13.453408
# Layer 7, Epoch 51/100, Train NMSE (dB): -22.393207, Validation NMSE (dB): -13.537034
# Layer 7, Epoch 61/100, Train NMSE (dB): -24.222186, Validation NMSE (dB): -13.490856
# Early stopping triggered after 62 epochs
# ===== Finished Training Layer 7/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -24.241917, Validation NMSE (dB): -13.508757
# Fine-Tune Epoch 11/100, Train NMSE (dB): -24.698695, Validation NMSE (dB): -13.566854
# Fine-Tune Epoch 21/100, Train NMSE (dB): -24.888416, Validation NMSE (dB): -13.568306
# Early stopping for fine-tuning triggered after 25 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 8/16 =====
# Layer 8, Epoch 1/100, Train NMSE (dB): -20.386326, Validation NMSE (dB): -13.416594
# Layer 8, Epoch 11/100, Train NMSE (dB): -23.258279, Validation NMSE (dB): -13.901073
# Layer 8, Epoch 21/100, Train NMSE (dB): -23.561161, Validation NMSE (dB): -13.975201
# Layer 8, Epoch 31/100, Train NMSE (dB): -23.760296, Validation NMSE (dB): -14.066203
# Layer 8, Epoch 41/100, Train NMSE (dB): -23.933955, Validation NMSE (dB): -14.131419
# Layer 8, Epoch 51/100, Train NMSE (dB): -24.983485, Validation NMSE (dB): -14.253572
# Layer 8, Epoch 61/100, Train NMSE (dB): -26.910679, Validation NMSE (dB): -14.218135
# Early stopping triggered after 62 epochs
# ===== Finished Training Layer 8/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -26.814386, Validation NMSE (dB): -14.244563
# Fine-Tune Epoch 11/100, Train NMSE (dB): -27.325949, Validation NMSE (dB): -14.272759
# Early stopping for fine-tuning triggered after 19 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 9/16 =====
# Layer 9, Epoch 1/100, Train NMSE (dB): -18.853892, Validation NMSE (dB): -13.486584
# Layer 9, Epoch 11/100, Train NMSE (dB): -24.399061, Validation NMSE (dB): -14.539552
# Layer 9, Epoch 21/100, Train NMSE (dB): -24.639503, Validation NMSE (dB): -14.585668
# Layer 9, Epoch 31/100, Train NMSE (dB): -24.916587, Validation NMSE (dB): -14.669534
# Layer 9, Epoch 41/100, Train NMSE (dB): -25.012249, Validation NMSE (dB): -14.709939
# Layer 9, Epoch 51/100, Train NMSE (dB): -26.021113, Validation NMSE (dB): -14.840367
# Layer 9, Epoch 61/100, Train NMSE (dB): -29.085660, Validation NMSE (dB): -14.882558
# Early stopping triggered after 64 epochs
# ===== Finished Training Layer 9/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -28.943287, Validation NMSE (dB): -14.893332
# Fine-Tune Epoch 11/100, Train NMSE (dB): -29.508840, Validation NMSE (dB): -14.878071
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 10/16 =====
# Layer 10, Epoch 1/100, Train NMSE (dB): -20.970709, Validation NMSE (dB): -14.833426
# Layer 10, Epoch 11/100, Train NMSE (dB): -25.995371, Validation NMSE (dB): -15.154071
# Layer 10, Epoch 21/100, Train NMSE (dB): -26.138805, Validation NMSE (dB): -15.217769
# Layer 10, Epoch 31/100, Train NMSE (dB): -26.234516, Validation NMSE (dB): -15.254562
# Layer 10, Epoch 41/100, Train NMSE (dB): -26.280418, Validation NMSE (dB): -15.303895
# Layer 10, Epoch 51/100, Train NMSE (dB): -27.183615, Validation NMSE (dB): -15.434393
# Layer 10, Epoch 61/100, Train NMSE (dB): -31.213294, Validation NMSE (dB): -15.546115
# Layer 10, Epoch 71/100, Train NMSE (dB): -31.252864, Validation NMSE (dB): -15.560502
# Layer 10, Epoch 81/100, Train NMSE (dB): -31.291598, Validation NMSE (dB): -15.566316
# Layer 10, Epoch 91/100, Train NMSE (dB): -31.315969, Validation NMSE (dB): -15.580344
# Layer 10, Epoch 100/100, Train NMSE (dB): -31.347647, Validation NMSE (dB): -15.591272
# ===== Finished Training Layer 10/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -31.052060, Validation NMSE (dB): -15.575733
# Fine-Tune Epoch 11/100, Train NMSE (dB): -31.868402, Validation NMSE (dB): -15.552013
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 11/16 =====
# Layer 11, Epoch 1/100, Train NMSE (dB): -22.222096, Validation NMSE (dB): -15.558970
# Layer 11, Epoch 11/100, Train NMSE (dB): -27.078754, Validation NMSE (dB): -15.849774
# Layer 11, Epoch 21/100, Train NMSE (dB): -27.199526, Validation NMSE (dB): -15.892088
# Layer 11, Epoch 31/100, Train NMSE (dB): -27.217782, Validation NMSE (dB): -15.915877
# Layer 11, Epoch 41/100, Train NMSE (dB): -27.286999, Validation NMSE (dB): -15.955583
# Layer 11, Epoch 51/100, Train NMSE (dB): -28.357364, Validation NMSE (dB): -16.108890
# Layer 11, Epoch 61/100, Train NMSE (dB): -33.110587, Validation NMSE (dB): -16.245228
# Layer 11, Epoch 71/100, Train NMSE (dB): -33.140763, Validation NMSE (dB): -16.254743
# Layer 11, Epoch 81/100, Train NMSE (dB): -33.164447, Validation NMSE (dB): -16.265052
# Layer 11, Epoch 91/100, Train NMSE (dB): -33.179487, Validation NMSE (dB): -16.273743
# Layer 11, Epoch 100/100, Train NMSE (dB): -33.194100, Validation NMSE (dB): -16.282293
# ===== Finished Training Layer 11/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -32.761311, Validation NMSE (dB): -16.263401
# Fine-Tune Epoch 11/100, Train NMSE (dB): -33.726481, Validation NMSE (dB): -16.257153
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 12/16 =====
# Layer 12, Epoch 1/100, Train NMSE (dB): -22.401629, Validation NMSE (dB): -16.141521
# Layer 12, Epoch 11/100, Train NMSE (dB): -27.642713, Validation NMSE (dB): -16.487284
# Layer 12, Epoch 21/100, Train NMSE (dB): -27.777238, Validation NMSE (dB): -16.511066
# Layer 12, Epoch 31/100, Train NMSE (dB): -27.821930, Validation NMSE (dB): -16.529620
# Layer 12, Epoch 41/100, Train NMSE (dB): -27.876047, Validation NMSE (dB): -16.545362
# Layer 12, Epoch 51/100, Train NMSE (dB): -28.929099, Validation NMSE (dB): -16.723590
# Layer 12, Epoch 61/100, Train NMSE (dB): -34.768762, Validation NMSE (dB): -16.801099
# Layer 12, Epoch 71/100, Train NMSE (dB): -34.788949, Validation NMSE (dB): -16.804956
# Layer 12, Epoch 81/100, Train NMSE (dB): -34.800423, Validation NMSE (dB): -16.812034
# Layer 12, Epoch 91/100, Train NMSE (dB): -34.821551, Validation NMSE (dB): -16.818163
# Layer 12, Epoch 100/100, Train NMSE (dB): -34.831342, Validation NMSE (dB): -16.823044
# ===== Finished Training Layer 12/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -34.209731, Validation NMSE (dB): -16.804925
# Fine-Tune Epoch 11/100, Train NMSE (dB): -35.293925, Validation NMSE (dB): -16.792014
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 13/16 =====
# Layer 13, Epoch 1/100, Train NMSE (dB): -22.631438, Validation NMSE (dB): -16.636424
# Layer 13, Epoch 11/100, Train NMSE (dB): -28.071940, Validation NMSE (dB): -16.994610
# Layer 13, Epoch 21/100, Train NMSE (dB): -28.220936, Validation NMSE (dB): -17.021441
# Layer 13, Epoch 31/100, Train NMSE (dB): -28.233958, Validation NMSE (dB): -17.024320
# Layer 13, Epoch 41/100, Train NMSE (dB): -28.259272, Validation NMSE (dB): -17.039296
# Layer 13, Epoch 51/100, Train NMSE (dB): -29.353507, Validation NMSE (dB): -17.185158
# Layer 13, Epoch 61/100, Train NMSE (dB): -36.227818, Validation NMSE (dB): -17.241466
# Layer 13, Epoch 71/100, Train NMSE (dB): -36.248618, Validation NMSE (dB): -17.248025
# Layer 13, Epoch 81/100, Train NMSE (dB): -36.261730, Validation NMSE (dB): -17.251201
# Layer 13, Epoch 91/100, Train NMSE (dB): -36.270409, Validation NMSE (dB): -17.254179
# Layer 13, Epoch 100/100, Train NMSE (dB): -36.272210, Validation NMSE (dB): -17.258311
# ===== Finished Training Layer 13/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -35.464971, Validation NMSE (dB): -17.240636
# Fine-Tune Epoch 11/100, Train NMSE (dB): -36.674204, Validation NMSE (dB): -17.233738
# Early stopping for fine-tuning triggered after 13 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 14/16 =====
# Layer 14, Epoch 1/100, Train NMSE (dB): -22.682407, Validation NMSE (dB): -17.037988
# Layer 14, Epoch 11/100, Train NMSE (dB): -28.389345, Validation NMSE (dB): -17.407896
# Layer 14, Epoch 21/100, Train NMSE (dB): -28.486685, Validation NMSE (dB): -17.420739
# Layer 14, Epoch 31/100, Train NMSE (dB): -28.536963, Validation NMSE (dB): -17.429781
# Layer 14, Epoch 41/100, Train NMSE (dB): -28.563346, Validation NMSE (dB): -17.439934
# Layer 14, Epoch 51/100, Train NMSE (dB): -29.696216, Validation NMSE (dB): -17.567035
# Layer 14, Epoch 61/100, Train NMSE (dB): -37.547937, Validation NMSE (dB): -17.625118
# Layer 14, Epoch 71/100, Train NMSE (dB): -37.564977, Validation NMSE (dB): -17.630294
# Layer 14, Epoch 81/100, Train NMSE (dB): -37.576553, Validation NMSE (dB): -17.631081
# Layer 14, Epoch 91/100, Train NMSE (dB): -37.587249, Validation NMSE (dB): -17.634052
# Layer 14, Epoch 100/100, Train NMSE (dB): -37.600951, Validation NMSE (dB): -17.638222
# ===== Finished Training Layer 14/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -36.594680, Validation NMSE (dB): -17.619401
# Fine-Tune Epoch 11/100, Train NMSE (dB): -37.899046, Validation NMSE (dB): -17.612602
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 15/16 =====
# Layer 15, Epoch 1/100, Train NMSE (dB): -22.739301, Validation NMSE (dB): -17.381090
# Layer 15, Epoch 11/100, Train NMSE (dB): -28.574032, Validation NMSE (dB): -17.783831
# Layer 15, Epoch 21/100, Train NMSE (dB): -28.714766, Validation NMSE (dB): -17.780683
# Layer 15, Epoch 31/100, Train NMSE (dB): -28.729672, Validation NMSE (dB): -17.792730
# Layer 15, Epoch 41/100, Train NMSE (dB): -28.777144, Validation NMSE (dB): -17.792048
# Layer 15, Epoch 51/100, Train NMSE (dB): -29.865817, Validation NMSE (dB): -17.918495
# Layer 15, Epoch 61/100, Train NMSE (dB): -38.707570, Validation NMSE (dB): -17.978984
# Layer 15, Epoch 71/100, Train NMSE (dB): -38.717904, Validation NMSE (dB): -17.981761
# Layer 15, Epoch 81/100, Train NMSE (dB): -38.721501, Validation NMSE (dB): -17.983023
# Layer 15, Epoch 91/100, Train NMSE (dB): -38.722356, Validation NMSE (dB): -17.986321
# Layer 15, Epoch 100/100, Train NMSE (dB): -38.741855, Validation NMSE (dB): -17.988829
# ===== Finished Training Layer 15/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -37.563748, Validation NMSE (dB): -17.966530
# Fine-Tune Epoch 11/100, Train NMSE (dB): -38.939633, Validation NMSE (dB): -17.970353
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 16/16 =====
# Layer 16, Epoch 1/100, Train NMSE (dB): -22.799806, Validation NMSE (dB): -17.700911
# Layer 16, Epoch 11/100, Train NMSE (dB): -28.759141, Validation NMSE (dB): -18.093060
# Layer 16, Epoch 21/100, Train NMSE (dB): -28.889073, Validation NMSE (dB): -18.097535
# Layer 16, Epoch 31/100, Train NMSE (dB): -28.897523, Validation NMSE (dB): -18.099104
# Layer 16, Epoch 41/100, Train NMSE (dB): -28.917602, Validation NMSE (dB): -18.104048
# Layer 16, Epoch 51/100, Train NMSE (dB): -30.087603, Validation NMSE (dB): -18.230868
# Layer 16, Epoch 61/100, Train NMSE (dB): -39.725402, Validation NMSE (dB): -18.287712
# Layer 16, Epoch 71/100, Train NMSE (dB): -39.722296, Validation NMSE (dB): -18.291408
# Layer 16, Epoch 81/100, Train NMSE (dB): -39.740313, Validation NMSE (dB): -18.293488
# Layer 16, Epoch 91/100, Train NMSE (dB): -39.724875, Validation NMSE (dB): -18.293503
# Layer 16, Epoch 100/100, Train NMSE (dB): -39.742111, Validation NMSE (dB): -18.296629
# ===== Finished Training Layer 16/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -38.416680, Validation NMSE (dB): -18.288348
# Fine-Tune Epoch 11/100, Train NMSE (dB): -39.875056, Validation NMSE (dB): -18.291756
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
# ({'Layer_1': array([-1.92043246, -2.88571094, -3.41079415, -3.84789003, -4.25441862,
#          -4.67439425, -5.04999283, -5.3672955 , -5.63783954, -5.86551052,
#          -6.05016868, -6.19011014, -6.28384644, -6.33746024, -6.36641272,
#          -6.40006521, -6.44975011, -6.48637434, -6.51942524, -6.53811173,
#          -6.54974506, -6.56048106, -6.57055089, -6.57595189]),
#   'Fine_Tune': array([-38.41667969, -38.86698807, -39.34468677, -39.58462131,
#          -39.70669701, -39.76910051, -39.80545531, -39.81738014,
#          -39.84876352, -39.86376178, -39.87505626, -39.89970872]),
#   'Layer_2': array([ -7.23274444,  -7.95729796,  -8.38306554,  -8.66589004,
#           -8.88441369,  -9.06395879,  -9.21033797,  -9.35133675,
#           -9.51129363,  -9.63138714,  -9.78950612,  -9.87992582,
#          -10.03598787, -10.11136041, -10.26448484, -10.31318847,
#          -18.10540111, -18.1008306 , -18.09910408, -18.08793455,
#          -18.10183338, -18.10399843, -18.09156712, -18.10377127,
#          -18.10851159, -18.08901932, -18.10604033, -18.10711825,
#          -18.10404752, -18.08582723, -18.11341139, -18.11043263,
#          -18.09850028, -18.09815765, -18.10779961, -18.1012762 ,
#          -18.10871228, -18.10811387, -18.2308675 , -18.27526482,
#          -18.27987962, -18.28640302, -18.28451387, -18.28778628,
#          -18.284632  , -18.28660222, -18.28730173, -18.28811437,
#          -18.28771244, -18.28684327, -18.28857761, -18.28805166,
#          -18.28813143, -18.28877117, -18.28946222, -18.29008381,
#          -18.2890979 , -18.2901719 , -18.29140783, -18.29038258,
#          -18.2893143 , -18.29168297, -18.29151768, -18.29167288,
#          -18.29233832, -18.29149017, -18.2925655 , -18.29187   ,
#          -18.29348795, -18.29263042, -18.29283909, -18.29303768,
#          -18.29378463, -18.29279574, -18.29524584, -18.29341257,
#          -18.29503076, -18.29462674, -18.29350325, -18.29459903,
#          -18.29550682, -18.29555182, -18.29491488, -18.29574766,
#          -18.29619644, -18.29375801, -18.29656891, -18.29662868])})

# %%
model = LDC_ISTA(torch.clone(A_), 'EXP', 1, T = 16)

# %%
model.compute_nmse_inference(test_set)
# Out:
# tensor([ -5.3020,  -6.4132,  -9.1098, -10.8656, -11.8027, -12.3323, -12.7461,
#         -13.0968, -13.4556, -13.9103, -14.3777, -14.8476, -15.2634, -15.5288,
#         -15.6493, -15.1554], device='cuda:0')

# %%
layerwise_train_DC(model, train_set, test_set, model_class = 'L-DC-ISTA', DCSIP = 'EXP', lr = 5e-4, ft_lr=5e-7)
# Out:
# ===== Training Layer 1/16 =====
# Layer 1, Epoch 1/100, Train NMSE (dB): -1.056808, Validation NMSE (dB): -1.273786
# Layer 1, Epoch 11/100, Train NMSE (dB): -3.776902, Validation NMSE (dB): -3.576556
# Layer 1, Epoch 21/100, Train NMSE (dB): -4.799551, Validation NMSE (dB): -4.460341
# Layer 1, Epoch 31/100, Train NMSE (dB): -5.555997, Validation NMSE (dB): -5.084311
# Layer 1, Epoch 41/100, Train NMSE (dB): -6.111807, Validation NMSE (dB): -5.496707
# Layer 1, Epoch 51/100, Train NMSE (dB): -6.462211, Validation NMSE (dB): -5.670495
# Layer 1, Epoch 61/100, Train NMSE (dB): -6.483032, Validation NMSE (dB): -5.677855
# Layer 1, Epoch 71/100, Train NMSE (dB): -6.496519, Validation NMSE (dB): -5.683121
# Layer 1, Epoch 81/100, Train NMSE (dB): -6.508459, Validation NMSE (dB): -5.687691
# Layer 1, Epoch 91/100, Train NMSE (dB): -6.518264, Validation NMSE (dB): -5.690950
# Layer 1, Epoch 100/100, Train NMSE (dB): -6.526422, Validation NMSE (dB): -5.694036
# ===== Finished Training Layer 1/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -6.480759, Validation NMSE (dB): -5.695496
# Fine-Tune Epoch 11/100, Train NMSE (dB): -6.572059, Validation NMSE (dB): -5.711280
# Fine-Tune Epoch 21/100, Train NMSE (dB): -6.607511, Validation NMSE (dB): -5.720393
# Fine-Tune Epoch 31/100, Train NMSE (dB): -6.633228, Validation NMSE (dB): -5.727293
# Fine-Tune Epoch 41/100, Train NMSE (dB): -6.650193, Validation NMSE (dB): -5.729563
# Fine-Tune Epoch 51/100, Train NMSE (dB): -6.677977, Validation NMSE (dB): -5.729943
# Early stopping for fine-tuning triggered after 59 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 2/16 =====
# Layer 2, Epoch 1/100, Train NMSE (dB): -6.900418, Validation NMSE (dB): -6.090257
# Layer 2, Epoch 11/100, Train NMSE (dB): -8.421867, Validation NMSE (dB): -6.729288
# Layer 2, Epoch 21/100, Train NMSE (dB): -9.362641, Validation NMSE (dB): -7.424060
# Layer 2, Epoch 31/100, Train NMSE (dB): -9.776140, Validation NMSE (dB): -7.653220
# Layer 2, Epoch 41/100, Train NMSE (dB): -10.068291, Validation NMSE (dB): -7.813812
# Layer 2, Epoch 51/100, Train NMSE (dB): -10.356363, Validation NMSE (dB): -7.936005
# Layer 2, Epoch 61/100, Train NMSE (dB): -10.382762, Validation NMSE (dB): -7.950695
# Layer 2, Epoch 71/100, Train NMSE (dB): -10.405540, Validation NMSE (dB): -7.963181
# Layer 2, Epoch 81/100, Train NMSE (dB): -10.427378, Validation NMSE (dB): -7.974751
# Layer 2, Epoch 91/100, Train NMSE (dB): -10.448626, Validation NMSE (dB): -7.986103
# Layer 2, Epoch 100/100, Train NMSE (dB): -10.467469, Validation NMSE (dB): -7.996152
# ===== Finished Training Layer 2/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -10.231618, Validation NMSE (dB): -8.003034
# Fine-Tune Epoch 11/100, Train NMSE (dB): -10.893773, Validation NMSE (dB): -8.139978
# Fine-Tune Epoch 21/100, Train NMSE (dB): -11.193035, Validation NMSE (dB): -8.191345
# Fine-Tune Epoch 31/100, Train NMSE (dB): -11.432246, Validation NMSE (dB): -8.228484
# Fine-Tune Epoch 41/100, Train NMSE (dB): -11.643018, Validation NMSE (dB): -8.261168
# Fine-Tune Epoch 51/100, Train NMSE (dB): -11.902302, Validation NMSE (dB): -8.287018
# Fine-Tune Epoch 61/100, Train NMSE (dB): -11.929899, Validation NMSE (dB): -8.290054
# Fine-Tune Epoch 71/100, Train NMSE (dB): -11.949231, Validation NMSE (dB): -8.293759
# Fine-Tune Epoch 81/100, Train NMSE (dB): -11.967257, Validation NMSE (dB): -8.296251
# Fine-Tune Epoch 91/100, Train NMSE (dB): -11.983178, Validation NMSE (dB): -8.298518
# Fine-Tune Epoch 100/100, Train NMSE (dB): -11.998828, Validation NMSE (dB): -8.301065
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 3/16 =====
# Layer 3, Epoch 1/100, Train NMSE (dB): -11.052536, Validation NMSE (dB): -8.253502
# Layer 3, Epoch 11/100, Train NMSE (dB): -12.479378, Validation NMSE (dB): -8.263974
# Layer 3, Epoch 21/100, Train NMSE (dB): -12.953916, Validation NMSE (dB): -8.704648
# Layer 3, Epoch 31/100, Train NMSE (dB): -13.318974, Validation NMSE (dB): -9.032509
# Layer 3, Epoch 41/100, Train NMSE (dB): -13.538796, Validation NMSE (dB): -9.165547
# Layer 3, Epoch 51/100, Train NMSE (dB): -13.785891, Validation NMSE (dB): -9.249590
# Layer 3, Epoch 61/100, Train NMSE (dB): -13.810405, Validation NMSE (dB): -9.259385
# Layer 3, Epoch 71/100, Train NMSE (dB): -13.826018, Validation NMSE (dB): -9.267777
# Layer 3, Epoch 81/100, Train NMSE (dB): -13.840256, Validation NMSE (dB): -9.275383
# Layer 3, Epoch 91/100, Train NMSE (dB): -13.854067, Validation NMSE (dB): -9.282704
# Layer 3, Epoch 100/100, Train NMSE (dB): -13.866261, Validation NMSE (dB): -9.289417
# ===== Finished Training Layer 3/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -13.294230, Validation NMSE (dB): -9.333884
# Fine-Tune Epoch 11/100, Train NMSE (dB): -14.423294, Validation NMSE (dB): -9.450181
# Fine-Tune Epoch 21/100, Train NMSE (dB): -14.949867, Validation NMSE (dB): -9.499208
# Fine-Tune Epoch 31/100, Train NMSE (dB): -15.403658, Validation NMSE (dB): -9.546360
# Fine-Tune Epoch 41/100, Train NMSE (dB): -15.837128, Validation NMSE (dB): -9.579974
# Fine-Tune Epoch 51/100, Train NMSE (dB): -16.415780, Validation NMSE (dB): -9.616399
# Fine-Tune Epoch 61/100, Train NMSE (dB): -16.514847, Validation NMSE (dB): -9.617114
# Fine-Tune Epoch 71/100, Train NMSE (dB): -16.559035, Validation NMSE (dB): -9.621377
# Fine-Tune Epoch 81/100, Train NMSE (dB): -16.599299, Validation NMSE (dB): -9.624633
# Fine-Tune Epoch 91/100, Train NMSE (dB): -16.636677, Validation NMSE (dB): -9.627592
# Fine-Tune Epoch 100/100, Train NMSE (dB): -16.674544, Validation NMSE (dB): -9.630232
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 4/16 =====
# Layer 4, Epoch 1/100, Train NMSE (dB): -13.820327, Validation NMSE (dB): -9.450377
# Layer 4, Epoch 11/100, Train NMSE (dB): -16.067634, Validation NMSE (dB): -9.388905
# Early stopping triggered after 11 epochs
# ===== Finished Training Layer 4/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -15.347589, Validation NMSE (dB): -9.401693
# Fine-Tune Epoch 11/100, Train NMSE (dB): -17.187792, Validation NMSE (dB): -9.815017
# Fine-Tune Epoch 21/100, Train NMSE (dB): -18.069810, Validation NMSE (dB): -10.028190
# Fine-Tune Epoch 31/100, Train NMSE (dB): -18.843236, Validation NMSE (dB): -10.096682
# Fine-Tune Epoch 41/100, Train NMSE (dB): -19.506789, Validation NMSE (dB): -10.115379
# Fine-Tune Epoch 51/100, Train NMSE (dB): -20.363642, Validation NMSE (dB): -10.164519
# Early stopping for fine-tuning triggered after 60 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 5/16 =====
# Layer 5, Epoch 1/100, Train NMSE (dB): -15.986898, Validation NMSE (dB): -10.250050
# Layer 5, Epoch 11/100, Train NMSE (dB): -19.072664, Validation NMSE (dB): -10.088397
# Early stopping triggered after 11 epochs
# ===== Finished Training Layer 5/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -17.898565, Validation NMSE (dB): -10.016363
# Fine-Tune Epoch 11/100, Train NMSE (dB): -20.309505, Validation NMSE (dB): -10.283108
# Fine-Tune Epoch 21/100, Train NMSE (dB): -21.225961, Validation NMSE (dB): -10.449448
# Fine-Tune Epoch 31/100, Train NMSE (dB): -22.118409, Validation NMSE (dB): -10.465934
# Early stopping for fine-tuning triggered after 34 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 6/16 =====
# Layer 6, Epoch 1/100, Train NMSE (dB): -17.394169, Validation NMSE (dB): -10.899752
# Layer 6, Epoch 11/100, Train NMSE (dB): -21.219229, Validation NMSE (dB): -10.669749
# Early stopping triggered after 11 epochs
# ===== Finished Training Layer 6/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -19.737303, Validation NMSE (dB): -10.429360
# Fine-Tune Epoch 11/100, Train NMSE (dB): -22.382253, Validation NMSE (dB): -10.670925
# Fine-Tune Epoch 21/100, Train NMSE (dB): -23.287066, Validation NMSE (dB): -10.777807
# Fine-Tune Epoch 31/100, Train NMSE (dB): -24.161840, Validation NMSE (dB): -10.798989
# Early stopping for fine-tuning triggered after 38 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 7/16 =====
# Layer 7, Epoch 1/100, Train NMSE (dB): -19.006355, Validation NMSE (dB): -11.369743
# Layer 7, Epoch 11/100, Train NMSE (dB): -23.715260, Validation NMSE (dB): -11.158417
# Early stopping triggered after 11 epochs
# ===== Finished Training Layer 7/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -21.652057, Validation NMSE (dB): -10.827654
# Fine-Tune Epoch 11/100, Train NMSE (dB): -24.143123, Validation NMSE (dB): -11.012856
# Fine-Tune Epoch 21/100, Train NMSE (dB): -25.086672, Validation NMSE (dB): -11.131999
# Fine-Tune Epoch 31/100, Train NMSE (dB): -25.801535, Validation NMSE (dB): -11.134879
# Early stopping for fine-tuning triggered after 35 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 8/16 =====
# Layer 8, Epoch 1/100, Train NMSE (dB): -20.835944, Validation NMSE (dB): -11.695134
# Layer 8, Epoch 11/100, Train NMSE (dB): -26.537672, Validation NMSE (dB): -11.655813
# Early stopping triggered after 13 epochs
# ===== Finished Training Layer 8/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -23.519484, Validation NMSE (dB): -11.407238
# Fine-Tune Epoch 11/100, Train NMSE (dB): -25.756882, Validation NMSE (dB): -11.492124
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 9/16 =====
# Layer 9, Epoch 1/100, Train NMSE (dB): -21.690602, Validation NMSE (dB): -12.012382
# Layer 9, Epoch 11/100, Train NMSE (dB): -28.652679, Validation NMSE (dB): -12.055508
# Early stopping triggered after 13 epochs
# ===== Finished Training Layer 9/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -24.179302, Validation NMSE (dB): -12.023110
# Fine-Tune Epoch 11/100, Train NMSE (dB): -26.152144, Validation NMSE (dB): -12.204889
# Fine-Tune Epoch 21/100, Train NMSE (dB): -26.398548, Validation NMSE (dB): -12.291095
# Fine-Tune Epoch 31/100, Train NMSE (dB): -26.356865, Validation NMSE (dB): -12.385964
# Fine-Tune Epoch 41/100, Train NMSE (dB): -26.420637, Validation NMSE (dB): -12.556627
# Fine-Tune Epoch 51/100, Train NMSE (dB): -27.768607, Validation NMSE (dB): -12.407626
# Early stopping for fine-tuning triggered after 51 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 10/16 =====
# Layer 10, Epoch 1/100, Train NMSE (dB): -21.927313, Validation NMSE (dB): -12.854178
# Layer 10, Epoch 11/100, Train NMSE (dB): -30.162523, Validation NMSE (dB): -12.820165
# Early stopping triggered after 12 epochs
# ===== Finished Training Layer 10/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -24.918395, Validation NMSE (dB): -12.919591
# Fine-Tune Epoch 11/100, Train NMSE (dB): -26.657856, Validation NMSE (dB): -12.875781
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 11/16 =====
# Layer 11, Epoch 1/100, Train NMSE (dB): -21.566807, Validation NMSE (dB): -13.432207
# Layer 11, Epoch 11/100, Train NMSE (dB): -28.751899, Validation NMSE (dB): -13.391834
# Early stopping triggered after 12 epochs
# ===== Finished Training Layer 11/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -24.277358, Validation NMSE (dB): -13.407093
# Fine-Tune Epoch 11/100, Train NMSE (dB): -26.247795, Validation NMSE (dB): -13.419155
# Early stopping for fine-tuning triggered after 13 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 12/16 =====
# Layer 12, Epoch 1/100, Train NMSE (dB): -21.462089, Validation NMSE (dB): -13.861167
# Layer 12, Epoch 11/100, Train NMSE (dB): -28.834246, Validation NMSE (dB): -13.795937
# Early stopping triggered after 12 epochs
# ===== Finished Training Layer 12/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -23.927185, Validation NMSE (dB): -13.817596
# Fine-Tune Epoch 11/100, Train NMSE (dB): -26.005692, Validation NMSE (dB): -13.826396
# Early stopping for fine-tuning triggered after 13 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 13/16 =====
# Layer 13, Epoch 1/100, Train NMSE (dB): -21.383715, Validation NMSE (dB): -14.296708
# Layer 13, Epoch 11/100, Train NMSE (dB): -28.786654, Validation NMSE (dB): -14.209500
# Early stopping triggered after 12 epochs
# ===== Finished Training Layer 13/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -23.564828, Validation NMSE (dB): -14.115825
# Fine-Tune Epoch 11/100, Train NMSE (dB): -25.646945, Validation NMSE (dB): -14.264802
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 14/16 =====
# Layer 14, Epoch 1/100, Train NMSE (dB): -21.245585, Validation NMSE (dB): -14.740138
# Layer 14, Epoch 11/100, Train NMSE (dB): -28.491918, Validation NMSE (dB): -14.658623
# Early stopping triggered after 12 epochs
# ===== Finished Training Layer 14/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -23.290708, Validation NMSE (dB): -14.471850
# Fine-Tune Epoch 11/100, Train NMSE (dB): -25.257317, Validation NMSE (dB): -14.724605
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 15/16 =====
# Layer 15, Epoch 1/100, Train NMSE (dB): -21.135851, Validation NMSE (dB): -15.225003
# Layer 15, Epoch 11/100, Train NMSE (dB): -28.269754, Validation NMSE (dB): -15.139143
# Early stopping triggered after 12 epochs
# ===== Finished Training Layer 15/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -22.896625, Validation NMSE (dB): -14.745200
# Fine-Tune Epoch 11/100, Train NMSE (dB): -24.922634, Validation NMSE (dB): -15.147547
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 16/16 =====
# Layer 16, Epoch 1/100, Train NMSE (dB): -21.047484, Validation NMSE (dB): -15.745458
# Layer 16, Epoch 11/100, Train NMSE (dB): -28.003296, Validation NMSE (dB): -15.663761
# Early stopping triggered after 12 epochs
# ===== Finished Training Layer 16/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -22.562086, Validation NMSE (dB): -15.156689
# Fine-Tune Epoch 11/100, Train NMSE (dB): -24.599819, Validation NMSE (dB): -15.568251
# Early stopping for fine-tuning triggered after 13 epochs
# ===== Finished Fine-Tuning =====
# ({'Layer_1': array([-1.0568081 , -1.49993005, -1.92631356, -2.32700979, -2.71366978,
#          -3.05831677, -3.27844287, -3.42880683, -3.55132766, -3.66456189,
#          -3.77690188, -3.89071885, -4.00495682, -4.11750282, -4.22643453,
#          -4.33093814, -4.43128157, -4.52795274, -4.62123057, -4.71155905,
#  tensor([[1.0823]], device='cuda:0'),
#  tensor([[0.9396]], device='cuda:0'),
#  tensor([[0.8828]], device='cuda:0'),
#  tensor([[0.7103]], device='cuda:0'),
#  tensor([[0.7029]], device='cuda:0'),
#  tensor([[0.7248]], device='cuda:0'),
#  tensor([[0.7633]], device='cuda:0'),
#  tensor([[0.8059]], device='cuda:0'),
#  tensor([[0.8557]], device='cuda:0'),
#  tensor([[0.8928]], device='cuda:0')]

# %%
[model.lambd[t].detach() * model.eta(t) for t in range(model.T)]
# Out:
# [tensor([[0.4103]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.2961]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.1194]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0560]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0361]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0293]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0259]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0430]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0393]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0280]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0226]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0249]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0251]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0250]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0229]], device='cuda:0', grad_fn=<MulBackward0>),
#  tensor([[0.0581]], device='cuda:0', grad_fn=<MulBackward0>)]

# %%
[torch.linalg.norm(model.Ws_3[t].weight.data) for t in range(model.T)]
# Out:
# [tensor(1.5666, device='cuda:0'),
#  tensor(35.8301, device='cuda:0'),
#  tensor(22.9912, device='cuda:0'),
#  tensor(18.1696, device='cuda:0'),
#  tensor(23.3411, device='cuda:0'),
#  tensor(29.3183, device='cuda:0'),
#  tensor(39.5211, device='cuda:0'),
#  tensor(46.7524, device='cuda:0'),
#  tensor(50.5844, device='cuda:0'),
#  tensor(47.6080, device='cuda:0'),
#  tensor(48.6159, device='cuda:0'),
#  tensor(42.8521, device='cuda:0'),
#  tensor(25.0908, device='cuda:0'),
#  tensor(24.9328, device='cuda:0'),
#  tensor(22.8825, device='cuda:0'),
#  tensor(20.8946, device='cuda:0')]

# %%
[torch.linalg.norm(torch.eye(500).to('cuda:0') - model.Ws_1[t].weight.data @ model.A - model.Ws_2[t].weight.data ) for t in range(model.T)]
# Out:
# [tensor(29.4942, device='cuda:0'),
#  tensor(17.1490, device='cuda:0'),
#  tensor(13.1171, device='cuda:0'),
#  tensor(6.0148, device='cuda:0'),
#  tensor(2.4450, device='cuda:0'),
#  tensor(1.3491, device='cuda:0'),
#  tensor(0.8874, device='cuda:0'),
#  tensor(1.1671, device='cuda:0'),
#  tensor(1.0340, device='cuda:0'),
#  tensor(0.8641, device='cuda:0'),
#  tensor(0.7280, device='cuda:0'),
#  tensor(0.7470, device='cuda:0'),
#  tensor(0.7696, device='cuda:0'),
#  tensor(0.8227, device='cuda:0'),
#  tensor(0.9746, device='cuda:0'),
#  tensor(1.2145, device='cuda:0')]

# %%
M = 10
LAYERS = 5
BETA_INIT = 0.4
EPOCHS = 50
SNR = None

LISTA_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 200
    m_ = 150
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = LISTA_Net(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = LDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = LDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = LDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    LISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set)
    LDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set)
    LDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set)
    LDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set)

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT)
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT)
# Out:
# 100%|██████████| 10/10 [08:32<00:00, 51.24s/it]

# %%
LISTA_LOSS = LISTA_LOSS.cpu().numpy()
LDC_LISTA_EXP_LOSS = LDC_LISTA_EXP_LOSS.cpu().numpy()
LDC_LISTA_PNEG_LOSS = LDC_LISTA_PNEG_LOSS.cpu().numpy()
LDC_LISTA_SCAD_LOSS = LDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

# %%
plt.plot(np.mean(LISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(LISTA_LOSS, axis = 0) - (2/np.sqrt(LISTA_LOSS.shape[1])) * np.std(LISTA_LOSS, axis = 0), 
                    np.mean(LISTA_LOSS, axis = 0) + (2/np.sqrt(LISTA_LOSS.shape[1])) * np.std(LISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_EXP_LOSS.shape[1])) * np.std(LDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_EXP_LOSS.shape[1])) * np.std(LDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_PNEG_LOSS.shape[1])) * np.std(LDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_PNEG_LOSS.shape[1])) * np.std(LDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_SCAD_LOSS.shape[1])) * np.std(LDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_SCAD_LOSS.shape[1])) * np.std(LDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
exp_1 = {
    'LISTA':LISTA_LOSS,
    'LDC-LISTA-EXP':LDC_LISTA_EXP_LOSS,
    'LDC-LISTA-PNEG':LDC_LISTA_PNEG_LOSS,
    'LDC-LISTA-SCAD':LDC_LISTA_SCAD_LOSS,
    'ISTA':ISTA_LOSS,
    'FISTA':FISTA_LOSS
}

with open('LDC-LISTA_1.pkl', 'wb') as handle:
    pickle.dump(exp_1, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
M = 10
LAYERS = 16
BETA_INIT = 0.4
EPOCHS = 50
SNR = 1000

LISTA_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 500
    m_ = 250
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = LISTA_Net(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = LDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = LDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = LDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    LISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set)
    LDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set)
    LDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set)
    LDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set)

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT)
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT)
# Out:
# 100%|██████████| 10/10 [21:32<00:00, 129.29s/it]

# %%
LISTA_LOSS = LISTA_LOSS.cpu().numpy()
LDC_LISTA_EXP_LOSS = LDC_LISTA_EXP_LOSS.cpu().numpy()
LDC_LISTA_PNEG_LOSS = LDC_LISTA_PNEG_LOSS.cpu().numpy()
LDC_LISTA_SCAD_LOSS = LDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

# %%
plt.plot(np.mean(LISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(LISTA_LOSS, axis = 0) - (2/np.sqrt(LISTA_LOSS.shape[1])) * np.std(LISTA_LOSS, axis = 0), 
                    np.mean(LISTA_LOSS, axis = 0) + (2/np.sqrt(LISTA_LOSS.shape[1])) * np.std(LISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_EXP_LOSS.shape[1])) * np.std(LDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_EXP_LOSS.shape[1])) * np.std(LDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_PNEG_LOSS.shape[1])) * np.std(LDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_PNEG_LOSS.shape[1])) * np.std(LDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_SCAD_LOSS.shape[1])) * np.std(LDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_SCAD_LOSS.shape[1])) * np.std(LDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')

plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
exp_2 = {
    'LISTA':LISTA_LOSS,
    'LDC-ISTA-EXP':LDC_LISTA_EXP_LOSS,
    'LDC-ISTA-PNEG':LDC_LISTA_PNEG_LOSS,
    'LDC-ISTA-SCAD':LDC_LISTA_SCAD_LOSS,
    'ISTA':ISTA_LOSS,
    'FISTA':FISTA_LOSS
}

with open('LDC-LISTA_2.pkl', 'wb') as handle:
    pickle.dump(exp_2, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
M = 10
LAYERS = 20
BETA_INIT = 0.4
EPOCHS = 50
SNR = 1000

LISTA_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
LDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 500
    m_ = 300
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = LISTA_Net(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = LDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = LDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = LDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    LISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set)
    LDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set)
    LDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set)
    LDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set)

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT)
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT)
# Out:
# 100%|██████████| 10/10 [26:00<00:00, 156.00s/it]

# %%
LISTA_LOSS = LISTA_LOSS.cpu().numpy()
LDC_LISTA_EXP_LOSS = LDC_LISTA_EXP_LOSS.cpu().numpy()
LDC_LISTA_PNEG_LOSS = LDC_LISTA_PNEG_LOSS.cpu().numpy()
LDC_LISTA_SCAD_LOSS = LDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

# %%
plt.plot(np.mean(LISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(LISTA_LOSS, axis = 0) - (2/np.sqrt(LISTA_LOSS.shape[1])) * np.std(LISTA_LOSS, axis = 0), 
                    np.mean(LISTA_LOSS, axis = 0) + (2/np.sqrt(LISTA_LOSS.shape[1])) * np.std(LISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_EXP_LOSS.shape[1])) * np.std(LDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_EXP_LOSS.shape[1])) * np.std(LDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_PNEG_LOSS.shape[1])) * np.std(LDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_PNEG_LOSS.shape[1])) * np.std(LDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(LDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(LDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(LDC_LISTA_SCAD_LOSS.shape[1])) * np.std(LDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(LDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(LDC_LISTA_SCAD_LOSS.shape[1])) * np.std(LDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')

#plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))

plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
exp_3 = {
    'LISTA':LISTA_LOSS,
    'LDC-LISTA-EXP':LDC_LISTA_EXP_LOSS,
    'LDC-LISTA-PNEG':LDC_LISTA_PNEG_LOSS,
    'LDC-LISTA-SCAD':LDC_LISTA_SCAD_LOSS,
    'ISTA':ISTA_LOSS,
    'FISTA':FISTA_LOSS
}

with open('LDC-LISTA_3.pkl', 'wb') as handle:
    pickle.dump(exp_3, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# _________

# %%
class TiLDC_ISTA(nn.Module):
    def __init__(self, A, mode, lambd=0.1, p =0.012, p_max = 0.12, T = 5):
        super().__init__()
    
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        assert mode in ['EXP', 'PNEG', 'SCAD']

        self.mode = mode

        self.A = A.to(self.device)  # Move A to the correct device
        self.A.requires_grad = False

        self.T = T

        self.L = torch.max(torch.real(torch.linalg.eigvals(A.t() @ A))).to(self.device)

        # Initialization of the learnable parameters
        self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device), requires_grad=True)
        self.mu = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) / self.L, requires_grad=True)
        self.lambd = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * lambd, requires_grad=True)
        
        # Linear layers
        self.W = nn.Linear(A.shape[1], A.shape[0], bias=False).to(self.device)
        self.W.weight.data = torch.clone(self.A.T).to(self.device)

        # Support selection mechanism parameters
        self.p = p
        self.p_max = p_max

        # Losses when doing inference (placeholder for NMSE accumulation)
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Mode setting for the layer
        if mode == 'EXP':
            self.ddx = self.ddxEXP
            self.eta = self.etaEXP

        if mode == 'PNEG':
            self.P = - nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) *0.1, requires_grad=True)
            self.ddx = self.ddxNEG
            self.eta = self.etaNEG

        if mode == 'SCAD':
            self.a = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * 2, requires_grad=True)
            self.ddx = self.ddxSCAD
            self.eta = self.etaSCAD

    #_________________________________________________________________
    #______________ METHODS FOR ENABLING DIFFERENT LAYERS_____________
    #_________________________________________________________________
    
    # Derivatives of the nonconvex components
    def ddxEXP(self, x, t):
        return torch.sign(x) * self.theta[t,:,:] * (1 - torch.exp(-self.theta[t,:,:] * torch.abs(x)))

    def ddxNEG(self, x, t):
        return -torch.sign(x) * self.P[t,:,:] * self.theta[t,:,:] * (1 - (1 + self.theta[t,:,:] * torch.abs(x)) ** (self.P[t,:,:] - 1))

    def ddxSCAD(self, x, t):
        abs_x = torch.abs(x)

        mask1 = (abs_x <= 1)
        mask2 = (1 / self.theta[t,:,:] < abs_x) & (abs_x <= self.a[t,:,:] / self.theta[t,:,:])
        mask3 = (abs_x > self.a[t,:,:] / self.theta[t,:,:])

        # Compute the value for each condition
        val1 = torch.zeros_like(x)
        val2 = torch.sign(x) * (2 * self.theta[t,:,:] * (self.theta[t,:,:] * abs_x - 1)) / (self.a[t,:,:] ** 2 - 1)
        val3 = torch.sign(x) * (2 * self.theta[t,:,:] / (self.a[t,:,:] + 1))

        # Apply the masks to compute the final result
        result = torch.where(mask1, val1, torch.where(mask2, val2, val3))

        return result

    # Parametrization for the surrogates
    def etaEXP(self, t):
        return self.theta[t,:,:]

    def etaNEG(self, t):
        return -self.P[t,:,:] * self.theta[t,:,:]

    def etaSCAD(self, t):
        return 2 * self.theta[t,:,:] / (self.a[t,:,:] + 1)
    
    #___________________________________________________________________
    #___________________________________________________________________
        
    def _shrink(self, x, beta, t):
        # Get the absolute values of the elements in x
        abs_x = torch.abs(x)
        
        # Sort the elements of x by magnitude along the last dimension (num_features)
        sorted_abs_x, _ = torch.sort(abs_x, dim=-1, descending=True)

        # Determine the threshold index corresponding to the top p% elements in each sample
        p = torch.min(torch.tensor([self.p * t, self.p_max], device=self.device))
        threshold_idx = int(p * x.shape[-1])
        
        # Get the magnitude threshold for the top p% of elements (per batch)
        if threshold_idx > 0:
            threshold_value = sorted_abs_x[:, threshold_idx - 1:threshold_idx]  # Shape: (batch_size, 1)
        else:
            threshold_value = torch.zeros(x.shape[0], 1, device=x.device)  # Shape: (batch_size, 1)

        # Create a mask to exclude the top p% of elements from shrinkage
        mask = abs_x >= threshold_value
        
        # Apply soft thresholding only to elements outside the top p%
        x_shrink = beta * F.softshrink(x / beta, lambd=1)
        
        # Return the original values for the top p% and the shrinked values for others
        return torch.where(mask, x, x_shrink)

    
    def forward(self, y, S=None):     
        # Move inputs to the correct device
        y = y.to(self.device)
        if S is not None:
            S = S.to(self.device)

        # Initial sparse estimate using the first layer
        x = self._shrink(self.mu[0, :, :] * self.W(y), self.eta(0) * self.lambd[0,:,:] * self.mu[0,:,:], 0)
        
        # Loop over layers to refine the estimate
        for t in range(1, self.T + 1):
            x = self._shrink(x - self.mu[t, :, :] * (self.W(torch.matmul(x, self.A.t()) - y)) + self.lambd[t,:,:] * self.mu[t,:,:] * self.ddx(x, t), 
                             self.eta(t) * self.lambd[t,:,:] * self.mu[t,:,:],
                             t)
            
            if S is not None:  # During inference, compute the NMSE at each layer
                with torch.no_grad():
                    mse_loss = F.mse_loss(x.detach(), S.detach(), reduction="sum")
                    signal_power = torch.sum(S.detach() ** 2)

                    self.losses[t - 1] += mse_loss.item()
                    self.est_powers[t - 1] += signal_power.item() + 1e-6

        return x

    # Method to compute NMSE during inference mode
    def compute_nmse_inference(self, test_loader):
        # Reset the losses accumulator
        self.losses = torch.zeros(self.T, device=self.device)
        
        # Iterate over test_loader
        for _, (Y, S) in enumerate(test_loader):
            Y, S = Y.to(self.device), S.to(self.device)
            _ = self.forward(Y, S)  # This will accumulate NMSE values
        
        # Convert accumulated NMSE to dB
        nmse_db = 10 * torch.log10(self.losses / self.est_powers)
        
        # Reset the losses after inference
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Return NMSE in dB for each layer
        return nmse_db

# %%
M = 10
LAYERS = 5
BETA_INIT = 0.4
EPOCHS = 50
SNR = None

TiLISTA_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 200
    m_ = 150
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = TiLISTA(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = TiLDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = TiLDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = TiLDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    TiLISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set).cpu()

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
# Out:
# 100%|██████████| 10/10 [08:42<00:00, 52.26s/it]

# %%
TiLISTA_LOSS = TiLISTA_LOSS.cpu().numpy()
TiLDC_LISTA_EXP_LOSS = TiLDC_LISTA_EXP_LOSS.cpu().numpy()
TiLDC_LISTA_PNEG_LOSS = TiLDC_LISTA_PNEG_LOSS.cpu().numpy()
TiLDC_LISTA_SCAD_LOSS = TiLDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

# %%
TiLISTA_LOSS = TiLISTA_LOSS.cpu().numpy()
TiLDC_LISTA_EXP_LOSS = TiLDC_LISTA_EXP_LOSS.cpu().numpy()
TiLDC_LISTA_PNEG_LOSS = TiLDC_LISTA_PNEG_LOSS.cpu().numpy()
TiLDC_LISTA_SCAD_LOSS = TiLDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

plt.plot(np.mean(TiLISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLISTA_LOSS, axis = 0) - (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    np.mean(TiLISTA_LOSS, axis = 0) + (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
M = 10
LAYERS = 16
BETA_INIT = 0.4
EPOCHS = 50
SNR = 1000

TiLISTA_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 500
    m_ = 250
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = TiLISTA(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = TiLDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = TiLDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = TiLDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    TiLISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set).cpu()

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
# Out:
# 100%|██████████| 10/10 [22:08<00:00, 132.85s/it]

# %%
TiLISTA_LOSS = TiLISTA_LOSS.cpu().numpy()
TiLDC_LISTA_EXP_LOSS = TiLDC_LISTA_EXP_LOSS.cpu().numpy()
TiLDC_LISTA_PNEG_LOSS = TiLDC_LISTA_PNEG_LOSS.cpu().numpy()
TiLDC_LISTA_SCAD_LOSS = TiLDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

# %%
plt.plot(np.mean(TiLISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLISTA_LOSS, axis = 0) - (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    np.mean(TiLISTA_LOSS, axis = 0) + (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %% [markdown]
# ________

# %%
class TiLDC_ISTA(nn.Module):
    def __init__(self, A, mode, lambd=0.1, p =0.012, p_max = 0.12, T = 5):
        super().__init__()
    
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        assert mode in ['EXP', 'PNEG', 'SCAD']

        self.mode = mode

        self.A = A.to(self.device)  # Move A to the correct device
        self.A.requires_grad = False

        self.T = T

        self.L = torch.max(torch.real(torch.linalg.eigvals(A.t() @ A))).to(self.device)

        # Initialization of the learnable parameters
        self.mu = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) / self.L, requires_grad=True)
        self.lambd = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * lambd, requires_grad=True)
        
        # Linear layers
        self.W = nn.Linear(A.shape[1], A.shape[0], bias=False).to(self.device)
        self.W.weight.data = torch.clone(self.A.T).to(self.device) 

        self.Z = torch.linalg.pinv(self.A.T).to(self.device) * lambd 

        # Support selection mechanism parameters
        self.p = p
        self.p_max = p_max

        # Losses when doing inference (placeholder for NMSE accumulation)
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Mode setting for the layer
        if mode == 'EXP':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * lambd /self.L, requires_grad=True)
            self.ddx = self.ddxEXP
            self.eta = self.etaEXP

        if mode == 'PNEG':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * (-lambd /(0.1*self.L)), requires_grad=True)
            self.P = - nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) *0.1, requires_grad=True)
            self.ddx = self.ddxNEG
            self.eta = self.etaNEG

        if mode == 'SCAD':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * 1.5 * lambd / self.L, requires_grad=True)
            self.a = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * 2, requires_grad=True)
            self.ddx = self.ddxSCAD
            self.eta = self.etaSCAD

    #_________________________________________________________________
    #______________ METHODS FOR ENABLING DIFFERENT LAYERS_____________
    #_________________________________________________________________
    
    # Derivatives of the nonconvex components
    def ddxEXP(self, x, t):
        return torch.sign(x) * self.theta[t,:,:] * (1 - torch.exp(-self.theta[t,:,:] * torch.abs(x)))

    def ddxNEG(self, x, t):
        return -torch.sign(x) * self.P[t,:,:] * self.theta[t,:,:] * (1 - (1 + self.theta[t,:,:] * torch.abs(x)) ** (self.P[t,:,:] - 1))

    def ddxSCAD(self, x, t):
        abs_x = torch.abs(x)

        mask1 = (abs_x <= 1)
        mask2 = (1 / self.theta[t,:,:] < abs_x) & (abs_x <= self.a[t,:,:] / self.theta[t,:,:])
        mask3 = (abs_x > self.a[t,:,:] / self.theta[t,:,:])

        # Compute the value for each condition
        val1 = torch.zeros_like(x)
        val2 = torch.sign(x) * (2 * self.theta[t,:,:] * (self.theta[t,:,:] * abs_x - 1)) / (self.a[t,:,:] ** 2 - 1)
        val3 = torch.sign(x) * (2 * self.theta[t,:,:] / (self.a[t,:,:] + 1))

        # Apply the masks to compute the final result
        result = torch.where(mask1, val1, torch.where(mask2, val2, val3))

        return result

    # Parametrization for the surrogates
    def etaEXP(self, t):
        return self.theta[t,:,:]

    def etaNEG(self, t):
        return -self.P[t,:,:] * self.theta[t,:,:]

    def etaSCAD(self, t):
        return 2 * self.theta[t,:,:] / (self.a[t,:,:] + 1)
    
    #___________________________________________________________________
    #___________________________________________________________________
        
    def _shrink(self, x, beta, t):
        # Get the absolute values of the elements in x
        abs_x = torch.abs(x)
        
        # Sort the elements of x by magnitude along the last dimension (num_features)
        sorted_abs_x, _ = torch.sort(abs_x, dim=-1, descending=True)

        # Determine the threshold index corresponding to the top p% elements in each sample
        p = torch.min(torch.tensor([self.p * t, self.p_max], device=self.device))
        threshold_idx = int(p * x.shape[-1])
        
        # Get the magnitude threshold for the top p% of elements (per batch)
        if threshold_idx > 0:
            threshold_value = sorted_abs_x[:, threshold_idx - 1:threshold_idx]  # Shape: (batch_size, 1)
        else:
            threshold_value = torch.zeros(x.shape[0], 1, device=x.device)  # Shape: (batch_size, 1)

        # Create a mask to exclude the top p% of elements from shrinkage
        mask = abs_x >= threshold_value
        
        # Apply soft thresholding only to elements outside the top p%
        x_shrink = beta * F.softshrink(x / beta, lambd=1)
        
        # Return the original values for the top p% and the shrinked values for others
        return torch.where(mask, x, x_shrink)

    
    def forward(self, y, S=None):     
        # Move inputs to the correct device
        y = y.to(self.device)
        if S is not None:
            S = S.to(self.device)

        # Initial sparse estimate using the first layer
        x = self._shrink(self.mu[0, :, :] * self.W(y), self.eta(0) * self.lambd[0,:,:] * self.mu[0,:,:], 0)
        
        # Loop over layers to refine the estimate
        for t in range(1, self.T + 1):
            x = self._shrink(x - self.mu[t, :, :] * self.W(
                torch.matmul(x, self.A.t()) - y + torch.matmul(self.ddx(x, t), self.Z.t())), 
                             self.eta(t) * self.lambd[t,:,:] * self.mu[t,:,:],
                             t)
            
            if S is not None:  # During inference, compute the NMSE at each layer
                with torch.no_grad():
                    mse_loss = F.mse_loss(x.detach(), S.detach(), reduction="sum")
                    signal_power = torch.sum(S.detach() ** 2)

                    self.losses[t - 1] += mse_loss.item()
                    self.est_powers[t - 1] += signal_power.item() + 1e-6

        return x

    # Method to compute NMSE during inference mode
    def compute_nmse_inference(self, test_loader):
        # Reset the losses accumulator
        self.losses = torch.zeros(self.T, device=self.device)
        
        # Iterate over test_loader
        for _, (Y, S) in enumerate(test_loader):
            Y, S = Y.to(self.device), S.to(self.device)
            _ = self.forward(Y, S)  # This will accumulate NMSE values
        
        # Convert accumulated NMSE to dB
        nmse_db = 10 * torch.log10(self.losses / self.est_powers)
        
        # Reset the losses after inference
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Return NMSE in dB for each layer
        return nmse_db

# %%
M = 10
LAYERS = 5
BETA_INIT = 0.4
EPOCHS = 50
SNR = None

TiLISTA_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 200
    m_ = 150
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = TiLISTA(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = TiLDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = TiLDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = TiLDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    TiLISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set).cpu()

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()

# %%
TiLISTA_LOSS = TiLISTA_LOSS.cpu().numpy()
TiLDC_LISTA_EXP_LOSS = TiLDC_LISTA_EXP_LOSS.cpu().numpy()
TiLDC_LISTA_PNEG_LOSS = TiLDC_LISTA_PNEG_LOSS.cpu().numpy()
TiLDC_LISTA_SCAD_LOSS = TiLDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

plt.plot(np.mean(TiLISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLISTA_LOSS, axis = 0) - (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    np.mean(TiLISTA_LOSS, axis = 0) + (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
M = 10
LAYERS = 16
BETA_INIT = 0.4
EPOCHS = 50
SNR = 1000

TiLISTA_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 500
    m_ = 250
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = TiLISTA(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = TiLDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = TiLDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = TiLDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    TiLISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set).cpu()

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
# Out:
# 100%|██████████| 10/10 [20:52<00:00, 125.27s/it]

# %%
TiLISTA_LOSS = TiLISTA_LOSS.cpu().numpy()
TiLDC_LISTA_EXP_LOSS = TiLDC_LISTA_EXP_LOSS.cpu().numpy()
TiLDC_LISTA_PNEG_LOSS = TiLDC_LISTA_PNEG_LOSS.cpu().numpy()
TiLDC_LISTA_SCAD_LOSS = TiLDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

plt.plot(np.mean(TiLISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLISTA_LOSS, axis = 0) - (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    np.mean(TiLISTA_LOSS, axis = 0) + (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
M = 10
LAYERS = 20
BETA_INIT = 0.4
EPOCHS = 50
SNR = 1000

TiLISTA_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 500
    m_ = 300
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = TiLISTA(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = TiLDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = TiLDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = TiLDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    TiLISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set).cpu()

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
# Out:
# 100%|██████████| 10/10 [26:43<00:00, 160.30s/it]

# %%
TiLISTA_LOSS = TiLISTA_LOSS.cpu().numpy()
TiLDC_LISTA_EXP_LOSS = TiLDC_LISTA_EXP_LOSS.cpu().numpy()
TiLDC_LISTA_PNEG_LOSS = TiLDC_LISTA_PNEG_LOSS.cpu().numpy()
TiLDC_LISTA_SCAD_LOSS = TiLDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

plt.plot(np.mean(TiLISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLISTA_LOSS, axis = 0) - (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    np.mean(TiLISTA_LOSS, axis = 0) + (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
torch.tensor(1.0).dtype
# Out:
# torch.float32

# %%
class ALDC_ISTA(nn.Module):
    def __init__(self, A, mode, lambd=0.1, p =0.012, p_max = 0.12, T = 5):
        super().__init__()
    
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        assert mode in ['EXP', 'PNEG', 'SCAD']

        self.mode = mode

        self.A = A.to(self.device)  # Move A to the correct device
        self.A.requires_grad = False

        self.T = T

        self.L = torch.max(torch.real(torch.linalg.eigvals(A.t() @ A))).to(self.device)

        # Initialization of the learnable parameters

        self.lambd = nn.ParameterList([
            nn.Parameter(torch.tensor(1).reshape(1, 1).to(self.device) * lambd / self.L, requires_grad=True)
            for _ in range(self.T + 1)
        ])

        self.mu = nn.ParameterList([
            nn.Parameter(torch.tensor(1).reshape(1, 1).to(self.device) / self.L, requires_grad=True)
            for _ in range(self.T + 1)
        ])

        self.theta = nn.ParameterList([
            nn.Parameter(torch.tensor(1.0).reshape(1, 1).to(self.device) * 5, requires_grad=True)
            for _ in range(self.T + 1)
            ])
        
        # Linear layer

        self.W = self.W_optimization().to(self.device)
        self.W1 = torch.clone((self.W.T @ self.A)).to(self.device)
        self.W2 = torch.clone(self.W.T).to(self.device)

        # Support selection mechanism parameters
        self.p = p
        self.p_max = p_max

        # Losses when doing inference (placeholder for NMSE accumulation)
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Mode setting for the layer
        if mode == 'EXP':

            self.ddx = self.ddxEXP
            self.eta = self.etaEXP

        if mode == 'PNEG':

            self.P = nn.ParameterList([
            nn.Parameter(torch.tensor(1.0).reshape(1, 1).to(self.device) * (-0.1), requires_grad=True)
            for _ in range(self.T + 1)
            ])
            self.ddx = self.ddxNEG
            self.eta = self.etaNEG

        if mode == 'SCAD':
       
            self.a = nn.ParameterList([
            nn.Parameter(torch.tensor(1.0).reshape(1, 1).to(self.device)*10, requires_grad=True)
            for _ in range(self.T + 1)
            ])        
            self.ddx = self.ddxSCAD
            self.eta = self.etaSCAD
    
    #_________________________________________________________________
    #______________ METHODS FOR ENABLING DIFFERENT LAYERS_____________
    #_________________________________________________________________

    def W_optimization(self):
        N, M = self.A.shape
        W = cp.Variable((N, M))

        objective = cp.Minimize(cp.norm(W.T @ self.A.cpu().numpy(), 'fro'))
        constraints = [W[:, m].T @ self.A.cpu().numpy()[:, m] == 1 for m in range(M)]
        prob = cp.Problem(objective, constraints)

        prob.solve(solver=cp.MOSEK)
        print('Linear layer initialized minimizing coherence!')
        return torch.from_numpy(W.value).float()
    
    # Derivatives of the nonconvex components
    def ddxEXP(self, x, t):
        return torch.sign(x) * self.theta[t] * (1 - torch.exp(-self.theta[t] * torch.abs(x)))

    def ddxNEG(self, x, t):
        return -torch.sign(x) * self.P[t] * self.theta[t] * (1 - (1 + self.theta[t] * torch.abs(x)) ** (self.P[t] - 1))

    def ddxSCAD(self, x, t):
        abs_x = torch.abs(x)

        mask1 = (abs_x <= 1)
        mask2 = (1 / self.theta[t] < abs_x) & (abs_x <= self.a[t] / self.theta[t])
        mask3 = (abs_x > self.a[t] / self.theta[t])

        # Compute the value for each condition
        val1 = torch.zeros_like(x)
        val2 = torch.sign(x) * (2 * self.theta[t] * (self.theta[t] * abs_x - 1)) / (self.a[t] ** 2 - 1)
        val3 = torch.sign(x) * (2 * self.theta[t] / (self.a[t] + 1))

        # Apply the masks to compute the final result
        result = torch.where(mask1, val1, torch.where(mask2, val2, val3))

        return result

    # Parametrization for the surrogates
    def etaEXP(self, t):
        return self.theta[t]

    def etaNEG(self, t):
        return -self.P[t] * self.theta[t]

    def etaSCAD(self, t):
        return 2 * self.theta[t] / (self.a[t] + 1)
    
    #___________________________________________________________________
    #___________________________________________________________________
        
    def _shrink(self, x, beta, t):
        # Get the absolute values of the elements in x
        abs_x = torch.abs(x)
        
        # Sort the elements of x by magnitude along the last dimension (num_features)
        sorted_abs_x, _ = torch.sort(abs_x, dim=-1, descending=True)

        # Determine the threshold index corresponding to the top p% elements in each sample
        p = torch.min(torch.tensor([self.p * t, self.p_max], device=self.device))
        threshold_idx = int(p * x.shape[-1])
        
        # Get the magnitude threshold for the top p% of elements (per batch)
        if threshold_idx > 0:
            threshold_value = sorted_abs_x[:, threshold_idx - 1:threshold_idx]  # Shape: (batch_size, 1)
        else:
            threshold_value = torch.zeros(x.shape[0], 1, device=x.device)  # Shape: (batch_size, 1)

        # Create a mask to exclude the top p% of elements from shrinkage
        mask = abs_x >= threshold_value
        
        # Apply soft thresholding only to elements outside the top p%
        x_shrink = beta * F.softshrink(x / beta, lambd=1)
        
        # Return the original values for the top p% and the shrinked values for others
        return torch.where(mask, x, x_shrink)

    
    def forward(self, y, its=None, S=None):     
        # Move inputs to the correct device
        if its is None:
            its = self.T
            
        y = y.to(self.device)
        if S is not None:
            S = S.to(self.device)

        # Initial sparse estimate using the first layer
        x = torch.zeros((y.shape[0], self.A.shape[1])).to(self.device)
        x = self._shrink(self.mu[0] * torch.matmul(y, self.W2.t()) + self.lambd[0] * self.ddx(x, 0) , self.eta(0) * self.lambd[0], 1)
        
        # Loop over layers to refine the estimate
        for t in range(1, its + 1):
            x = self._shrink(x - self.mu[t] * (torch.matmul(x, self.W1.t()) - torch.matmul(y, self.W2.t())) + self.lambd[t] * self.ddx(x, t), 
                             self.eta(t) * self.lambd[t],
                             t)
            
            if S is not None:  # During inference, compute the NMSE at each layer
                with torch.no_grad():
                    mse_loss = F.mse_loss(x.detach(), S.detach(), reduction="sum")
                    signal_power = torch.sum(S.detach() ** 2)

                    self.losses[t - 1] += mse_loss.item()
                    self.est_powers[t - 1] += signal_power.item() + 1e-6

        return x

    # Method to compute NMSE during inference mode
    def compute_nmse_inference(self, test_loader):
        # Reset the losses accumulator
        self.losses = torch.zeros(self.T, device=self.device)
        
        # Iterate over test_loader
        for _, (Y, S) in enumerate(test_loader):
            Y, S = Y.to(self.device), S.to(self.device)
            _ = self.forward(y = Y, its = None, S = S)  # This will accumulate NMSE values
        
        # Convert accumulated NMSE to dB
        nmse_db = 10 * torch.log10(self.losses / self.est_powers)
        
        # Reset the losses after inference
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Return NMSE in dB for each layer
        return nmse_db

# %%
n_ = 500
m_ = 250
p_ = 0.1

# Sensing matrix

A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
A_ /= torch.linalg.norm(A_, dim = 0)

# Building a training set and a test set 
train_set = SyntheticSignals(
    A = A_,
    n = n_,        
    m = m_,
    p = p_,
    SNR = None,
    size = 10000,
    batch_size = 1000
    ).set_loader()

test_set = SyntheticSignals(
    A = A_,
    n = n_,        
    m = m_,
    p = p_,
    SNR = None,
    size = 1000
    ).set_loader()

# %%
model = ALDC_ISTA(torch.clone(A_), 'SCAD', 0.4, T = 16)
# Out:
# Linear layer initialized minimizing coherence!

# %%
import torch.optim as optim

def layerwise_train_DC(
        model, 
        train_loader, 
        valid_loader, 
        model_class,
        DCSIP,
        lr=5e-4, 
        ft_lr=3e-5,
        num_epochs=100, 
        verbose=True, 
        clip_value=10.0, 
        eps=1e-6, 
        fine_tune_epochs=100, 
        patience=10):

    assert model_class in [
        'L-DC-ISTA',
        'LISTA-DC-CPSS',
        'TIL-DC-ISTA',
        'AL-DC-ISTA'
    ]

    assert DCSIP in [
        'EXP',
        'PNEG',
        'SCAD'
    ]

    device = model.device
    model = model.to(device)

    linear_shared = True

    loss_train_all = {}
    loss_test_all = {}

    T = model.T  # Number of layers/iterations

    for t in range(T+1):

        if verbose:
            print(f"===== Training Layer {t+1}/{T} =====")

        # Freeze parameters beyond current layer t
        for layer_idx in range(t):
            model.lambd[layer_idx].requires_grad = False
            if model_class != 'LISTA' and linear_shared == True:
                model.mu[layer_idx].requires_grad = False
                model.theta[layer_idx].requires_grad = False
                if DCSIP == 'SCAD':
                    model.a[layer_idx].requires_grad = False
                if DCSIP == 'PNEG':
                    model.P[layer_idx].requires_grad = False

            if not linear_shared:
                if model_class == 'LISTA':
                    model.Ws_1[layer_idx].weight.requires_grad = False
                    model.Ws_2[layer_idx].weight.requires_grad = False
                if model_class == 'LISTA-CPSS':
                    model.Ws[layer_idx].weight.requires_grad = False            


        # Define optimizer to include W1, W2, and parameters up to layer t
        if model_class == 'LISTA':
            if not linear_shared:
                optimizer = optim.Adam(
                    list(model.Ws_1.parameters())[:t+1] + 
                    list(model.Ws_2.parameters())[:t+1] + 
                    list(model.beta)[:t+1],
                    lr=lr,
                    eps=eps
                )
            else:
                optimizer = optim.Adam(
                    list(model.Ws_1.parameters()) + 
                    list(model.Ws_2.parameters()) + 
                    list(model.beta)[:t+1] + 
                    list(model.mu)[:t+1],
                    lr=lr,
                    eps=eps
                )

        if model_class == 'LISTA-CPSS':
            optimizer = optim.Adam(
                list(model.Ws.parameters())[:t+1] +
                list(model.beta)[:t+1],
                lr=lr,
                eps=eps
            )

        if model_class == 'TILISTA':
            optimizer = optim.Adam(
                list(model.W.parameters()) +
                list(model.beta)[:t+1] + 
                list(model.mu)[:t+1],
                lr=lr,
                eps=eps
            )

        if model_class == 'AL-DC-ISTA':
            params = list(model.lambd)[:t+1] + list(model.theta)[:t+1] + list(model.mu)[:t+1]
            if DCSIP == 'PNEG':
                params += list(model.P)[:t+1]
            if DCSIP == 'SCAD':
                params += list(model.a)[:t+1]
            optimizer = optim.Adam(
                params,
                lr=lr,
                eps=eps
            )

        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

        # Initialize loss tracking for current layer
        loss_train = np.zeros((num_epochs,))
        loss_test = np.zeros((num_epochs,))

        # Early stopping variables
        best_val_loss = float('inf')
        epochs_since_improvement = 0
        best_model_state = None

        for epoch in range(num_epochs):
            model.train()
            train_loss = 0.0
            signal_power_train = 0.0

            for Y, S in train_loader:
                Y = Y.to(device)
                S = S.to(device)

                optimizer.zero_grad()
                S_hat = model(y=Y, its=t, S = None)

                mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                signal_power = torch.sum(S ** 2)

                loss = mse_loss
                loss.backward()

                # Apply gradient clipping
                torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)

                optimizer.step()

                train_loss += mse_loss.item()
                signal_power_train += signal_power.item()

            # Compute NMSE in dB for training set
            nmse_train = train_loss / (signal_power_train + eps)
            loss_train[epoch] = 10 * np.log10(nmse_train + eps)
            scheduler.step()

            # Validation
            model.eval()
            test_loss_epoch = 0.0
            signal_power_test = 0.0

            with torch.no_grad():
                for Y, S in valid_loader:
                    Y = Y.to(device)
                    S = S.to(device)

                    S_hat = model(Y, its=t)

                    mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                    signal_power = torch.sum(S ** 2)

                    test_loss_epoch += mse_loss.item()
                    signal_power_test += signal_power.item()

            nmse_test = test_loss_epoch / (signal_power_test + eps)
            loss_test[epoch] = 10 * np.log10(nmse_test + eps)

            if verbose and (epoch % 10 == 0 or epoch == num_epochs - 1):
                print(
                    f"Layer {t+1}, Epoch {epoch+1}/{num_epochs}, "
                    f"Train NMSE (dB): {loss_train[epoch]:.6f}, "
                    f"Validation NMSE (dB): {loss_test[epoch]:.6f}"
                )

            # Early stopping check
            if loss_test[epoch] < best_val_loss:
                best_val_loss = loss_test[epoch]
                epochs_since_improvement = 0
                best_model_state = model.state_dict()  # Save the best model state
            else:
                epochs_since_improvement += 1

            if epochs_since_improvement >= patience:
                if verbose:
                    print(f"Early stopping triggered after {epoch+1} epochs")
                model.load_state_dict(best_model_state)  # Restore best model state
                break

        # Store losses for current layer
        loss_train_all[f"Layer_{t+1}"] = loss_train[:epoch+1]
        loss_test_all[f"Layer_{t+1}"] = loss_test[:epoch+1]

        if verbose:
            print(f"===== Finished Training Layer {t+1}/{T} =====\n")

        # Optionally, fine-tune the entire network
        if fine_tune_epochs > 0:
            if verbose:
                print("===== Fine-Tuning the Entire Network =====")

            # Unfreeze all parameters
            for layer_idx in range(t + 1):
                model.theta[layer_idx].requires_grad = True
                if model_class != 'LISTA' and linear_shared == True:
                    model.mu[layer_idx].requires_grad = True
                    model.lambd[layer_idx].requires_grad = True
                    if DCSIP == 'SCAD':
                        model.a[layer_idx].requires_grad = True
                    if DCSIP == 'PNEG':
                        model.P[layer_idx].requires_grad = True
                if not linear_shared:
                    if model_class == 'LISTA':
                        model.Ws_1[layer_idx].weight.requires_grad = True
                        model.Ws_2[layer_idx].weight.requires_grad = True
                    if model_class == 'LISTA-CPSS':
                        model.Ws[layer_idx].weight.requires_grad = True   

            if model_class == 'LISTA':
                if not linear_shared:
                    optimizer = optim.Adam(
                        list(model.Ws_1.parameters())[:t+1] + 
                        list(model.Ws_2.parameters())[:t+1] + 
                        list(model.beta)[:t+1],
                        lr=ft_lr,
                        eps=eps
                    )
                else:
                    optimizer = optim.Adam(
                        list(model.Ws_1.parameters()) + 
                        list(model.Ws_2.parameters()) + 
                        list(model.beta)[:t+1] + 
                        list(model.mu)[:t+1],
                        lr=ft_lr,
                        eps=eps
                    )

            if model_class == 'LISTA-CPSS':
                optimizer = optim.Adam(
                    list(model.Ws.parameters())[:t+1] +
                    list(model.beta)[:t+1],
                    lr=ft_lr,
                    eps=eps
                )

            if model_class == 'TILISTA':
                optimizer = optim.Adam(
                    list(model.W.parameters()) +
                    list(model.beta)[:t+1] + 
                    list(model.mu)[:t+1],
                    lr=ft_lr,
                    eps=eps
                )

            if model_class == 'AL-DC-ISTA':
                params = list(model.lambd)[:t+1] + list(model.theta)[:t+1] + list(model.mu)[:t+1]
                if DCSIP == 'PNEG':
                    params += list(model.P)[:t+1]
                if DCSIP == 'SCAD':
                    params += list(model.a)[:t+1]
                optimizer = optim.Adam(
                    params,
                    lr=lr,
                    eps=eps
                )

            scheduler_ft = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

            # Initialize loss tracking for fine-tuning
            loss_train_ft = np.zeros((fine_tune_epochs,))
            loss_test_ft = np.zeros((fine_tune_epochs,))

            best_val_loss_ft = float('inf')
            epochs_since_improvement_ft = 0
            best_model_state_ft = None

            for epoch in range(fine_tune_epochs):
                model.train()
                train_loss = 0.0
                signal_power_train = 0.0

                for Y, S in train_loader:
                    Y = Y.to(device)
                    S = S.to(device)

                    optimizer.zero_grad()
                    S_hat = model(Y, its=t)

                    mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                    signal_power = torch.sum(S ** 2)

                    loss = mse_loss
                    loss.backward()

                    # Apply gradient clipping
                    torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)

                    optimizer.step()

                    train_loss += mse_loss.item()
                    signal_power_train += signal_power.item()

                # Compute NMSE in dB for training set
                nmse_train = train_loss / (signal_power_train + eps)
                loss_train_ft[epoch] = 10 * np.log10(nmse_train + eps)
                scheduler_ft.step()

                # Validation
                model.eval()
                test_loss_epoch = 0.0
                signal_power_test = 0.0

                with torch.no_grad():
                    for Y, S in valid_loader:
                        Y = Y.to(device)
                        S = S.to(device)

                        S_hat = model(Y, its=t)

                        mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                        signal_power = torch.sum(S ** 2)

                        test_loss_epoch += mse_loss.item()
                        signal_power_test += signal_power.item()

                nmse_test = test_loss_epoch / (signal_power_test + eps)
                loss_test_ft[epoch] = 10 * np.log10(nmse_test + eps)

                if verbose and (epoch % 10 == 0 or epoch == fine_tune_epochs - 1):
                    print(
                        f"Fine-Tune Epoch {epoch+1}/{fine_tune_epochs}, "
                        f"Train NMSE (dB): {loss_train_ft[epoch]:.6f}, "
                        f"Validation NMSE (dB): {loss_test_ft[epoch]:.6f}"
                    )

                # Early stopping for fine-tuning
                if loss_test_ft[epoch] < best_val_loss_ft:
                    best_val_loss_ft = loss_test_ft[epoch]
                    epochs_since_improvement_ft = 0
                    best_model_state_ft = model.state_dict()  # Save the best model state
                else:
                    epochs_since_improvement_ft += 1

                if epochs_since_improvement_ft >= patience:
                    if verbose:
                        print(f"Early stopping for fine-tuning triggered after {epoch+1} epochs")
                    model.load_state_dict(best_model_state_ft)  # Restore best model state
                    break

            # Store fine-tuning losses
            loss_train_all["Fine_Tune"] = loss_train_ft[:epoch+1]
            loss_test_all["Fine_Tune"] = loss_test_ft[:epoch+1]

            if verbose:
                print("===== Finished Fine-Tuning =====\n")

    return loss_train_all, loss_test_all

# %%
layerwise_train_DC(model, train_set, test_set, 'AL-DC-ISTA', 'SCAD', lr = 3e-3, ft_lr = 3e-5)
# Out:
# ===== Training Layer 1/16 =====
# Layer 1, Epoch 1/100, Train NMSE (dB): -1.470782, Validation NMSE (dB): -1.672440
# Layer 1, Epoch 11/100, Train NMSE (dB): -3.922607, Validation NMSE (dB): -4.042473
# Layer 1, Epoch 21/100, Train NMSE (dB): -5.789668, Validation NMSE (dB): -5.852898
# Layer 1, Epoch 31/100, Train NMSE (dB): -6.219081, Validation NMSE (dB): -6.216844
# Layer 1, Epoch 41/100, Train NMSE (dB): -6.219029, Validation NMSE (dB): -6.216775
# Layer 1, Epoch 51/100, Train NMSE (dB): -6.219066, Validation NMSE (dB): -6.216773
# Early stopping triggered after 52 epochs
# ===== Finished Training Layer 1/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -6.218822, Validation NMSE (dB): -6.216666
# Fine-Tune Epoch 11/100, Train NMSE (dB): -6.218996, Validation NMSE (dB): -6.216871
# Early stopping for fine-tuning triggered after 12 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 2/16 =====
# Layer 2, Epoch 1/100, Train NMSE (dB): -6.922911, Validation NMSE (dB): -7.078903
# Layer 2, Epoch 11/100, Train NMSE (dB): -8.248875, Validation NMSE (dB): -8.305824
# Layer 2, Epoch 21/100, Train NMSE (dB): -8.940310, Validation NMSE (dB): -8.975079
# Layer 2, Epoch 31/100, Train NMSE (dB): -9.089237, Validation NMSE (dB): -9.109672
# Layer 2, Epoch 41/100, Train NMSE (dB): -9.103688, Validation NMSE (dB): -9.123454
# Layer 2, Epoch 51/100, Train NMSE (dB): -9.108348, Validation NMSE (dB): -9.128308
# Layer 2, Epoch 61/100, Train NMSE (dB): -9.109396, Validation NMSE (dB): -9.128962
# Layer 2, Epoch 71/100, Train NMSE (dB): -9.110102, Validation NMSE (dB): -9.129555
# Layer 2, Epoch 81/100, Train NMSE (dB): -9.110800, Validation NMSE (dB): -9.130515
# Layer 2, Epoch 91/100, Train NMSE (dB): -9.111401, Validation NMSE (dB): -9.131067
# Layer 2, Epoch 100/100, Train NMSE (dB): -9.111901, Validation NMSE (dB): -9.131310
# ===== Finished Training Layer 2/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -9.344908, Validation NMSE (dB): -9.612718
# Fine-Tune Epoch 11/100, Train NMSE (dB): -10.349338, Validation NMSE (dB): -10.356073
# Fine-Tune Epoch 21/100, Train NMSE (dB): -10.394658, Validation NMSE (dB): -10.389482
# Fine-Tune Epoch 31/100, Train NMSE (dB): -10.400759, Validation NMSE (dB): -10.395306
# Fine-Tune Epoch 41/100, Train NMSE (dB): -10.406907, Validation NMSE (dB): -10.404044
# Fine-Tune Epoch 51/100, Train NMSE (dB): -10.414721, Validation NMSE (dB): -10.411447
# Fine-Tune Epoch 61/100, Train NMSE (dB): -10.416322, Validation NMSE (dB): -10.411979
# Fine-Tune Epoch 71/100, Train NMSE (dB): -10.417605, Validation NMSE (dB): -10.414304
# Fine-Tune Epoch 81/100, Train NMSE (dB): -10.418675, Validation NMSE (dB): -10.416231
# Fine-Tune Epoch 91/100, Train NMSE (dB): -10.419607, Validation NMSE (dB): -10.417519
# Fine-Tune Epoch 100/100, Train NMSE (dB): -10.420577, Validation NMSE (dB): -10.418832
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 3/16 =====
# Layer 3, Epoch 1/100, Train NMSE (dB): -10.984336, Validation NMSE (dB): -11.158518
# Layer 3, Epoch 11/100, Train NMSE (dB): -12.192874, Validation NMSE (dB): -12.242467
# Layer 3, Epoch 21/100, Train NMSE (dB): -12.513330, Validation NMSE (dB): -12.524002
# Layer 3, Epoch 31/100, Train NMSE (dB): -12.521723, Validation NMSE (dB): -12.532481
# Layer 3, Epoch 41/100, Train NMSE (dB): -12.527743, Validation NMSE (dB): -12.538460
# Layer 3, Epoch 51/100, Train NMSE (dB): -12.533413, Validation NMSE (dB): -12.543615
# Layer 3, Epoch 61/100, Train NMSE (dB): -12.534407, Validation NMSE (dB): -12.544567
# Layer 3, Epoch 71/100, Train NMSE (dB): -12.535126, Validation NMSE (dB): -12.545301
# Layer 3, Epoch 81/100, Train NMSE (dB): -12.535720, Validation NMSE (dB): -12.545945
# Layer 3, Epoch 91/100, Train NMSE (dB): -12.536248, Validation NMSE (dB): -12.546389
# Layer 3, Epoch 100/100, Train NMSE (dB): -12.536760, Validation NMSE (dB): -12.546859
# ===== Finished Training Layer 3/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -12.657452, Validation NMSE (dB): -12.755257
# Fine-Tune Epoch 11/100, Train NMSE (dB): -13.096647, Validation NMSE (dB): -13.113149
# Fine-Tune Epoch 21/100, Train NMSE (dB): -13.240972, Validation NMSE (dB): -13.263138
# Fine-Tune Epoch 31/100, Train NMSE (dB): -13.340778, Validation NMSE (dB): -13.364334
# Fine-Tune Epoch 41/100, Train NMSE (dB): -13.414747, Validation NMSE (dB): -13.433869
# Fine-Tune Epoch 51/100, Train NMSE (dB): -13.474626, Validation NMSE (dB): -13.492731
# Fine-Tune Epoch 61/100, Train NMSE (dB): -13.484652, Validation NMSE (dB): -13.502817
# Fine-Tune Epoch 71/100, Train NMSE (dB): -13.492283, Validation NMSE (dB): -13.508346
# Fine-Tune Epoch 81/100, Train NMSE (dB): -13.498649, Validation NMSE (dB): -13.513509
# Fine-Tune Epoch 91/100, Train NMSE (dB): -13.504517, Validation NMSE (dB): -13.519587
# Fine-Tune Epoch 100/100, Train NMSE (dB): -13.510663, Validation NMSE (dB): -13.525613
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 4/16 =====
# Layer 4, Epoch 1/100, Train NMSE (dB): -13.902816, Validation NMSE (dB): -14.184864
# Layer 4, Epoch 11/100, Train NMSE (dB): -15.297746, Validation NMSE (dB): -15.363924
# Layer 4, Epoch 21/100, Train NMSE (dB): -15.528574, Validation NMSE (dB): -15.564950
# Layer 4, Epoch 31/100, Train NMSE (dB): -15.534561, Validation NMSE (dB): -15.569994
# Layer 4, Epoch 41/100, Train NMSE (dB): -15.538592, Validation NMSE (dB): -15.574596
# Layer 4, Epoch 51/100, Train NMSE (dB): -15.542350, Validation NMSE (dB): -15.578118
# Layer 4, Epoch 61/100, Train NMSE (dB): -15.542893, Validation NMSE (dB): -15.578633
# Layer 4, Epoch 71/100, Train NMSE (dB): -15.543384, Validation NMSE (dB): -15.579108
# Layer 4, Epoch 81/100, Train NMSE (dB): -15.543785, Validation NMSE (dB): -15.579504
# Layer 4, Epoch 91/100, Train NMSE (dB): -15.544142, Validation NMSE (dB): -15.579835
# Layer 4, Epoch 100/100, Train NMSE (dB): -15.544467, Validation NMSE (dB): -15.580151
# ===== Finished Training Layer 4/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -15.725496, Validation NMSE (dB): -15.900377
# Fine-Tune Epoch 11/100, Train NMSE (dB): -16.267279, Validation NMSE (dB): -16.307300
# Fine-Tune Epoch 21/100, Train NMSE (dB): -16.341027, Validation NMSE (dB): -16.382162
# Fine-Tune Epoch 31/100, Train NMSE (dB): -16.413371, Validation NMSE (dB): -16.456975
# Fine-Tune Epoch 41/100, Train NMSE (dB): -16.464751, Validation NMSE (dB): -16.509702
# Fine-Tune Epoch 51/100, Train NMSE (dB): -16.551232, Validation NMSE (dB): -16.597979
# Fine-Tune Epoch 61/100, Train NMSE (dB): -16.570824, Validation NMSE (dB): -16.620975
# Fine-Tune Epoch 71/100, Train NMSE (dB): -16.593477, Validation NMSE (dB): -16.645443
# Fine-Tune Epoch 81/100, Train NMSE (dB): -16.618587, Validation NMSE (dB): -16.667465
# Fine-Tune Epoch 91/100, Train NMSE (dB): -16.642049, Validation NMSE (dB): -16.686730
# Fine-Tune Epoch 100/100, Train NMSE (dB): -16.666315, Validation NMSE (dB): -16.706750
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 5/16 =====
# Layer 5, Epoch 1/100, Train NMSE (dB): -16.821811, Validation NMSE (dB): -17.268994
# Layer 5, Epoch 11/100, Train NMSE (dB): -18.663898, Validation NMSE (dB): -18.767866
# Layer 5, Epoch 21/100, Train NMSE (dB): -18.922049, Validation NMSE (dB): -18.986653
# Layer 5, Epoch 31/100, Train NMSE (dB): -18.929857, Validation NMSE (dB): -18.994395
# Layer 5, Epoch 41/100, Train NMSE (dB): -18.936047, Validation NMSE (dB): -19.000716
# Layer 5, Epoch 51/100, Train NMSE (dB): -18.940683, Validation NMSE (dB): -19.005080
# Layer 5, Epoch 61/100, Train NMSE (dB): -18.941243, Validation NMSE (dB): -19.005654
# Layer 5, Epoch 71/100, Train NMSE (dB): -18.941718, Validation NMSE (dB): -19.006094
# Layer 5, Epoch 81/100, Train NMSE (dB): -18.942121, Validation NMSE (dB): -19.006558
# Layer 5, Epoch 91/100, Train NMSE (dB): -18.942539, Validation NMSE (dB): -19.006974
# Layer 5, Epoch 100/100, Train NMSE (dB): -18.942883, Validation NMSE (dB): -19.007300
# ===== Finished Training Layer 5/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -19.111678, Validation NMSE (dB): -19.307059
# Fine-Tune Epoch 11/100, Train NMSE (dB): -19.834119, Validation NMSE (dB): -19.916154
# Fine-Tune Epoch 21/100, Train NMSE (dB): -20.572324, Validation NMSE (dB): -20.628616
# Fine-Tune Epoch 31/100, Train NMSE (dB): -20.673642, Validation NMSE (dB): -20.722083
# Fine-Tune Epoch 41/100, Train NMSE (dB): -20.764553, Validation NMSE (dB): -20.805687
# Fine-Tune Epoch 51/100, Train NMSE (dB): -20.808546, Validation NMSE (dB): -20.841285
# Fine-Tune Epoch 61/100, Train NMSE (dB): -20.815402, Validation NMSE (dB): -20.844424
# Fine-Tune Epoch 71/100, Train NMSE (dB): -20.820190, Validation NMSE (dB): -20.847443
# Fine-Tune Epoch 81/100, Train NMSE (dB): -20.824370, Validation NMSE (dB): -20.851140
# Fine-Tune Epoch 91/100, Train NMSE (dB): -20.827617, Validation NMSE (dB): -20.853987
# Fine-Tune Epoch 100/100, Train NMSE (dB): -20.830605, Validation NMSE (dB): -20.856561
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 6/16 =====
# Layer 6, Epoch 1/100, Train NMSE (dB): -20.036678, Validation NMSE (dB): -20.759266
# Layer 6, Epoch 11/100, Train NMSE (dB): -22.561387, Validation NMSE (dB): -22.638947
# Layer 6, Epoch 21/100, Train NMSE (dB): -23.016986, Validation NMSE (dB): -23.055298
# Layer 6, Epoch 31/100, Train NMSE (dB): -23.060300, Validation NMSE (dB): -23.092505
# Layer 6, Epoch 41/100, Train NMSE (dB): -23.071546, Validation NMSE (dB): -23.102785
# Layer 6, Epoch 51/100, Train NMSE (dB): -23.076956, Validation NMSE (dB): -23.107717
# Layer 6, Epoch 61/100, Train NMSE (dB): -23.077536, Validation NMSE (dB): -23.108173
# Layer 6, Epoch 71/100, Train NMSE (dB): -23.078003, Validation NMSE (dB): -23.108590
# Layer 6, Epoch 81/100, Train NMSE (dB): -23.078429, Validation NMSE (dB): -23.108995
# Layer 6, Epoch 91/100, Train NMSE (dB): -23.078825, Validation NMSE (dB): -23.109463
# Layer 6, Epoch 100/100, Train NMSE (dB): -23.079134, Validation NMSE (dB): -23.109707
# ===== Finished Training Layer 6/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -23.476006, Validation NMSE (dB): -23.865619
# Fine-Tune Epoch 11/100, Train NMSE (dB): -24.983602, Validation NMSE (dB): -25.036797
# Fine-Tune Epoch 21/100, Train NMSE (dB): -25.209305, Validation NMSE (dB): -25.232649
# Fine-Tune Epoch 31/100, Train NMSE (dB): -25.325533, Validation NMSE (dB): -25.348348
# Fine-Tune Epoch 41/100, Train NMSE (dB): -25.329246, Validation NMSE (dB): -25.327088
# Early stopping for fine-tuning triggered after 46 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 7/16 =====
# Layer 7, Epoch 1/100, Train NMSE (dB): -24.206587, Validation NMSE (dB): -25.158938
# Layer 7, Epoch 11/100, Train NMSE (dB): -27.440008, Validation NMSE (dB): -27.506225
# Layer 7, Epoch 21/100, Train NMSE (dB): -27.919249, Validation NMSE (dB): -27.948932
# Layer 7, Epoch 31/100, Train NMSE (dB): -27.945077, Validation NMSE (dB): -27.973243
# Layer 7, Epoch 41/100, Train NMSE (dB): -27.959965, Validation NMSE (dB): -27.985579
# Layer 7, Epoch 51/100, Train NMSE (dB): -27.968285, Validation NMSE (dB): -27.996515
# Layer 7, Epoch 61/100, Train NMSE (dB): -27.970898, Validation NMSE (dB): -27.997928
# Layer 7, Epoch 71/100, Train NMSE (dB): -27.972357, Validation NMSE (dB): -27.999488
# Layer 7, Epoch 81/100, Train NMSE (dB): -27.973666, Validation NMSE (dB): -28.000789
# Layer 7, Epoch 91/100, Train NMSE (dB): -27.974865, Validation NMSE (dB): -28.002008
# Layer 7, Epoch 100/100, Train NMSE (dB): -27.975927, Validation NMSE (dB): -28.003028
# ===== Finished Training Layer 7/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -28.193903, Validation NMSE (dB): -28.454508
# Fine-Tune Epoch 11/100, Train NMSE (dB): -28.839777, Validation NMSE (dB): -28.854743
# Fine-Tune Epoch 21/100, Train NMSE (dB): -29.043236, Validation NMSE (dB): -29.066301
# Fine-Tune Epoch 31/100, Train NMSE (dB): -29.473333, Validation NMSE (dB): -29.513832
# Fine-Tune Epoch 41/100, Train NMSE (dB): -29.527096, Validation NMSE (dB): -29.538998
# Early stopping for fine-tuning triggered after 46 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 8/16 =====
# Layer 8, Epoch 1/100, Train NMSE (dB): -27.574601, Validation NMSE (dB): -28.893421
# Layer 8, Epoch 11/100, Train NMSE (dB): -32.217089, Validation NMSE (dB): -32.341806
# Layer 8, Epoch 21/100, Train NMSE (dB): -32.751293, Validation NMSE (dB): -32.827377
# Layer 8, Epoch 31/100, Train NMSE (dB): -32.824523, Validation NMSE (dB): -32.896052
# Layer 8, Epoch 41/100, Train NMSE (dB): -32.867267, Validation NMSE (dB): -32.940519
# Layer 8, Epoch 51/100, Train NMSE (dB): -32.897596, Validation NMSE (dB): -32.968699
# Layer 8, Epoch 61/100, Train NMSE (dB): -32.901301, Validation NMSE (dB): -32.972341
# Layer 8, Epoch 71/100, Train NMSE (dB): -32.904497, Validation NMSE (dB): -32.975486
# Layer 8, Epoch 81/100, Train NMSE (dB): -32.907377, Validation NMSE (dB): -32.978645
# Layer 8, Epoch 91/100, Train NMSE (dB): -32.910476, Validation NMSE (dB): -32.981510
# Layer 8, Epoch 100/100, Train NMSE (dB): -32.913048, Validation NMSE (dB): -32.984078
# ===== Finished Training Layer 8/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -33.192343, Validation NMSE (dB): -33.554002
# Fine-Tune Epoch 11/100, Train NMSE (dB): -33.999904, Validation NMSE (dB): -34.038897
# Fine-Tune Epoch 21/100, Train NMSE (dB): -34.051121, Validation NMSE (dB): -34.060338
# Early stopping for fine-tuning triggered after 25 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 9/16 =====
# Layer 9, Epoch 1/100, Train NMSE (dB): -31.764472, Validation NMSE (dB): -33.407348
# Layer 9, Epoch 11/100, Train NMSE (dB): -36.904199, Validation NMSE (dB): -36.992364
# Layer 9, Epoch 21/100, Train NMSE (dB): -37.745741, Validation NMSE (dB): -37.788579
# Layer 9, Epoch 31/100, Train NMSE (dB): -38.035046, Validation NMSE (dB): -38.073144
# Layer 9, Epoch 41/100, Train NMSE (dB): -38.225120, Validation NMSE (dB): -38.266409
# Layer 9, Epoch 51/100, Train NMSE (dB): -38.333827, Validation NMSE (dB): -38.375546
# Layer 9, Epoch 61/100, Train NMSE (dB): -38.346571, Validation NMSE (dB): -38.386892
# Layer 9, Epoch 71/100, Train NMSE (dB): -38.356482, Validation NMSE (dB): -38.396895
# Layer 9, Epoch 81/100, Train NMSE (dB): -38.365459, Validation NMSE (dB): -38.406393
# Layer 9, Epoch 91/100, Train NMSE (dB): -38.374200, Validation NMSE (dB): -38.415497
# Layer 9, Epoch 100/100, Train NMSE (dB): -38.381555, Validation NMSE (dB): -38.423465
# ===== Finished Training Layer 9/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -39.269516, Validation NMSE (dB): -39.735890
# Fine-Tune Epoch 11/100, Train NMSE (dB): -40.391905, Validation NMSE (dB): -40.502468
# Fine-Tune Epoch 21/100, Train NMSE (dB): -40.586094, Validation NMSE (dB): -40.680166
# Fine-Tune Epoch 31/100, Train NMSE (dB): -40.740091, Validation NMSE (dB): -40.841122
# Fine-Tune Epoch 41/100, Train NMSE (dB): -40.880778, Validation NMSE (dB): -40.952016
# Fine-Tune Epoch 51/100, Train NMSE (dB): -40.974876, Validation NMSE (dB): -41.066814
# Early stopping for fine-tuning triggered after 59 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 10/16 =====
# Layer 10, Epoch 1/100, Train NMSE (dB): -32.478091, Validation NMSE (dB): -35.051393
# Layer 10, Epoch 11/100, Train NMSE (dB): -44.009066, Validation NMSE (dB): -44.260052
# Layer 10, Epoch 21/100, Train NMSE (dB): -44.855246, Validation NMSE (dB): -45.059396
# Layer 10, Epoch 31/100, Train NMSE (dB): -45.081868, Validation NMSE (dB): -45.286150
# Layer 10, Epoch 41/100, Train NMSE (dB): -45.146374, Validation NMSE (dB): -45.347738
# Layer 10, Epoch 51/100, Train NMSE (dB): -45.196347, Validation NMSE (dB): -45.399233
# Layer 10, Epoch 61/100, Train NMSE (dB): -45.201764, Validation NMSE (dB): -45.405204
# Layer 10, Epoch 71/100, Train NMSE (dB): -45.207266, Validation NMSE (dB): -45.410641
# Layer 10, Epoch 81/100, Train NMSE (dB): -45.212241, Validation NMSE (dB): -45.416452
# Layer 10, Epoch 91/100, Train NMSE (dB): -45.217424, Validation NMSE (dB): -45.421587
# Layer 10, Epoch 100/100, Train NMSE (dB): -45.222879, Validation NMSE (dB): -45.426880
# ===== Finished Training Layer 10/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -45.516405, Validation NMSE (dB): -46.108305
# Fine-Tune Epoch 11/100, Train NMSE (dB): -46.347980, Validation NMSE (dB): -46.619275
# Fine-Tune Epoch 21/100, Train NMSE (dB): -46.567032, Validation NMSE (dB): -46.831284
# Fine-Tune Epoch 31/100, Train NMSE (dB): -46.582044, Validation NMSE (dB): -46.815238
# Early stopping for fine-tuning triggered after 37 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 11/16 =====
# Layer 11, Epoch 1/100, Train NMSE (dB): -32.891241, Validation NMSE (dB): -35.766825
# Layer 11, Epoch 11/100, Train NMSE (dB): -49.081044, Validation NMSE (dB): -49.556384
# Layer 11, Epoch 21/100, Train NMSE (dB): -49.660907, Validation NMSE (dB): -50.115168
# Layer 11, Epoch 31/100, Train NMSE (dB): -49.700334, Validation NMSE (dB): -50.149552
# Layer 11, Epoch 41/100, Train NMSE (dB): -49.702700, Validation NMSE (dB): -50.158130
# Layer 11, Epoch 51/100, Train NMSE (dB): -49.712939, Validation NMSE (dB): -50.160571
# Layer 11, Epoch 61/100, Train NMSE (dB): -49.717056, Validation NMSE (dB): -50.164233
# Layer 11, Epoch 71/100, Train NMSE (dB): -49.718047, Validation NMSE (dB): -50.165508
# Layer 11, Epoch 81/100, Train NMSE (dB): -49.718697, Validation NMSE (dB): -50.167406
# Layer 11, Epoch 91/100, Train NMSE (dB): -49.720244, Validation NMSE (dB): -50.167482
# Layer 11, Epoch 100/100, Train NMSE (dB): -49.721183, Validation NMSE (dB): -50.169623
# ===== Finished Training Layer 11/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -49.276865, Validation NMSE (dB): -50.273346
# Fine-Tune Epoch 11/100, Train NMSE (dB): -49.792817, Validation NMSE (dB): -49.984922
# Early stopping for fine-tuning triggered after 18 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 12/16 =====
# Layer 12, Epoch 1/100, Train NMSE (dB): -33.345086, Validation NMSE (dB): -36.418972
# Layer 12, Epoch 11/100, Train NMSE (dB): -50.947097, Validation NMSE (dB): -51.343726
# Layer 12, Epoch 21/100, Train NMSE (dB): -51.579814, Validation NMSE (dB): -51.976157
# Layer 12, Epoch 31/100, Train NMSE (dB): -51.704061, Validation NMSE (dB): -52.125057
# Layer 12, Epoch 41/100, Train NMSE (dB): -51.743286, Validation NMSE (dB): -52.115959
# Layer 12, Epoch 51/100, Train NMSE (dB): -51.776402, Validation NMSE (dB): -52.157602
# Layer 12, Epoch 61/100, Train NMSE (dB): -51.778361, Validation NMSE (dB): -52.159722
# Layer 12, Epoch 71/100, Train NMSE (dB): -51.779608, Validation NMSE (dB): -52.160422
# Layer 12, Epoch 81/100, Train NMSE (dB): -51.778210, Validation NMSE (dB): -52.155958
# Layer 12, Epoch 91/100, Train NMSE (dB): -51.781609, Validation NMSE (dB): -52.162650
# Layer 12, Epoch 100/100, Train NMSE (dB): -51.781289, Validation NMSE (dB): -52.162564
# ===== Finished Training Layer 12/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -51.085564, Validation NMSE (dB): -52.739238
# Fine-Tune Epoch 11/100, Train NMSE (dB): -52.845265, Validation NMSE (dB): -53.106861
# Fine-Tune Epoch 21/100, Train NMSE (dB): -53.203292, Validation NMSE (dB): -53.487788
# Fine-Tune Epoch 31/100, Train NMSE (dB): -53.371215, Validation NMSE (dB): -53.713449
# Fine-Tune Epoch 41/100, Train NMSE (dB): -53.466622, Validation NMSE (dB): -53.749935
# Fine-Tune Epoch 51/100, Train NMSE (dB): -53.713264, Validation NMSE (dB): -54.006076
# Fine-Tune Epoch 61/100, Train NMSE (dB): -53.760663, Validation NMSE (dB): -54.064617
# Fine-Tune Epoch 71/100, Train NMSE (dB): -53.811664, Validation NMSE (dB): -54.090843
# Fine-Tune Epoch 81/100, Train NMSE (dB): -53.861719, Validation NMSE (dB): -54.116599
# Fine-Tune Epoch 91/100, Train NMSE (dB): -53.923946, Validation NMSE (dB): -54.188361
# Fine-Tune Epoch 100/100, Train NMSE (dB): -53.984051, Validation NMSE (dB): -54.271631
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 13/16 =====
# Layer 13, Epoch 1/100, Train NMSE (dB): -33.436326, Validation NMSE (dB): -36.572387
# Layer 13, Epoch 11/100, Train NMSE (dB): -55.303431, Validation NMSE (dB): -55.720396
# Layer 13, Epoch 21/100, Train NMSE (dB): -55.941018, Validation NMSE (dB): -56.349375
# Layer 13, Epoch 31/100, Train NMSE (dB): -56.021398, Validation NMSE (dB): -56.430517
# Layer 13, Epoch 41/100, Train NMSE (dB): -56.022722, Validation NMSE (dB): -56.424347
# Layer 13, Epoch 51/100, Train NMSE (dB): -56.027779, Validation NMSE (dB): -56.438903
# Layer 13, Epoch 61/100, Train NMSE (dB): -56.035742, Validation NMSE (dB): -56.436626
# Layer 13, Epoch 71/100, Train NMSE (dB): -56.035830, Validation NMSE (dB): -56.439246
# Layer 13, Epoch 81/100, Train NMSE (dB): -56.035031, Validation NMSE (dB): -56.440707
# Layer 13, Epoch 91/100, Train NMSE (dB): -56.036343, Validation NMSE (dB): -56.440628
# Layer 13, Epoch 100/100, Train NMSE (dB): -56.036103, Validation NMSE (dB): -56.440749
# ===== Finished Training Layer 13/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -55.026459, Validation NMSE (dB): -54.585962
# Fine-Tune Epoch 11/100, Train NMSE (dB): -56.740097, Validation NMSE (dB): -56.972062
# Fine-Tune Epoch 21/100, Train NMSE (dB): -56.737865, Validation NMSE (dB): -56.972470
# Early stopping for fine-tuning triggered after 23 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 14/16 =====
# Layer 14, Epoch 1/100, Train NMSE (dB): -33.351666, Validation NMSE (dB): -36.460840
# Layer 14, Epoch 11/100, Train NMSE (dB): -57.590337, Validation NMSE (dB): -57.876399
# Layer 14, Epoch 21/100, Train NMSE (dB): -57.810666, Validation NMSE (dB): -58.096327
# Layer 14, Epoch 31/100, Train NMSE (dB): -57.840941, Validation NMSE (dB): -58.127706
# Layer 14, Epoch 41/100, Train NMSE (dB): -57.833981, Validation NMSE (dB): -58.113021
# Layer 14, Epoch 51/100, Train NMSE (dB): -57.847363, Validation NMSE (dB): -58.117671
# Layer 14, Epoch 61/100, Train NMSE (dB): -57.860222, Validation NMSE (dB): -58.134379
# Early stopping triggered after 63 epochs
# ===== Finished Training Layer 14/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -56.929808, Validation NMSE (dB): -57.681835
# Fine-Tune Epoch 11/100, Train NMSE (dB): -58.253024, Validation NMSE (dB): -58.419056
# Fine-Tune Epoch 21/100, Train NMSE (dB): -58.190795, Validation NMSE (dB): -58.364732
# Early stopping for fine-tuning triggered after 25 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 15/16 =====
# Layer 15, Epoch 1/100, Train NMSE (dB): -33.335051, Validation NMSE (dB): -36.443030
# Layer 15, Epoch 11/100, Train NMSE (dB): -58.583638, Validation NMSE (dB): -58.772560
# Layer 15, Epoch 21/100, Train NMSE (dB): -58.795263, Validation NMSE (dB): -59.015155
# Layer 15, Epoch 31/100, Train NMSE (dB): -58.806070, Validation NMSE (dB): -59.025694
# Layer 15, Epoch 41/100, Train NMSE (dB): -58.800686, Validation NMSE (dB): -59.020191
# Early stopping triggered after 44 epochs
# ===== Finished Training Layer 15/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -56.758128, Validation NMSE (dB): -58.094265
# Fine-Tune Epoch 11/100, Train NMSE (dB): -59.039879, Validation NMSE (dB): -59.179306
# Fine-Tune Epoch 21/100, Train NMSE (dB): -59.046688, Validation NMSE (dB): -59.208420
# Fine-Tune Epoch 31/100, Train NMSE (dB): -58.963792, Validation NMSE (dB): -59.201371
# Fine-Tune Epoch 41/100, Train NMSE (dB): -59.052990, Validation NMSE (dB): -59.230798
# Fine-Tune Epoch 51/100, Train NMSE (dB): -59.055357, Validation NMSE (dB): -59.211454
# Early stopping for fine-tuning triggered after 51 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 16/16 =====
# Layer 16, Epoch 1/100, Train NMSE (dB): -33.399795, Validation NMSE (dB): -36.530796
# Layer 16, Epoch 11/100, Train NMSE (dB): -59.260477, Validation NMSE (dB): -59.357866
# Layer 16, Epoch 21/100, Train NMSE (dB): -59.393039, Validation NMSE (dB): -59.514305
# Layer 16, Epoch 31/100, Train NMSE (dB): -59.463603, Validation NMSE (dB): -59.606926
# Layer 16, Epoch 41/100, Train NMSE (dB): -59.469724, Validation NMSE (dB): -59.391787
# Early stopping triggered after 49 epochs
# ===== Finished Training Layer 16/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -58.003892, Validation NMSE (dB): -59.399580
# Fine-Tune Epoch 11/100, Train NMSE (dB): -59.532933, Validation NMSE (dB): -59.647226
# Fine-Tune Epoch 21/100, Train NMSE (dB): -59.582685, Validation NMSE (dB): -59.660773
# Early stopping for fine-tuning triggered after 27 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer
#          -59.02404659, -59.01769071, -59.01414173, -59.01944567,
#          -59.02019074, -59.02146146, -59.02497627, -58.98648081]),
#   'Layer_16': array([-36.53079587, -48.14322303, -49.88852628, -56.740914  ,
#          -57.8260117 , -59.28976855, -59.3551356 , -59.37878266,
#          -59.38620883, -59.36994691, -59.35786594, -59.30281194,
#          -59.45036541, -59.47986447, -59.48953589, -59.50184871,
#          -59.30499676, -59.4578365 , -59.45715779, -59.54586858,
#          -59.51430508, -59.55629819, -59.51550895, -59.56498881,
#          -59.56264399, -59.58810542, -59.59328391, -59.58164205,
#          -59.5941618 , -59.6019478 , -59.6069256 , -59.61121639,
#          -59.61422531, -59.61541184, -59.61818934, -59.61915516,
#          -59.6208399 , -59.62203852, -59.62368061, -59.62076815,
#          -59.39178672, -59.55661242, -59.61659092, -59.56026096,
#          -59.38105111, -59.54314577, -59.50529534, -59.52353228,
#          -59.50889126]),
#   'Layer_17': array([-36.53642598, -48.18375079, -49.92105294, -56.9461711 ,
#          -58.09232497, -59.62524229, -59.71212816, -59.73053737,
#          -59.74410508, -59.74749776, -59.76144698, -59.76780607,
#          -59.77214454, -59.77985875, -59.78492065, -59.78952023,
#          -59.79347882, -59.79697504, -59.79582843, -59.75174633,
#          -59.48633101, -59.79767869, -59.79806158, -59.70317429,
#          -59.72525437, -59.75385404, -59.63539079, -59.75571527,
#          -59.52353762, -59.6717942 , -59.23691705, -59.32184902,
#          -59.64775247])})

# %%
model.compute_nmse_inference(test_set)[-1].cpu()
# Out:
# tensor(-71.6841)

# %%
model2 = ALISTA(torch.clone(A_), 0.4, T = 16)
# Out:
# Linear layer initialized minimizing coherence!

# %%
def layerwise_train(
        model, 
        train_loader, 
        valid_loader, 
        model_class,
        lr=5e-4, 
        ft_lr=3e-5,
        num_epochs=100, 
        verbose=True, 
        clip_value=10.0, 
        eps=1e-6, 
        fine_tune_epochs=100, 
        patience=10):

    assert model_class in [
        'LISTA',
        'LISTA-CPSS',
        'TILISTA',
        'ALISTA'
    ]

    device = model.device
    model = model.to(device)

    linear_shared = model.linear_shared

    loss_train_all = {}
    loss_test_all = {}

    T = model.T  # Number of layers/iterations

    for t in range(T+1):
        if verbose:
            print(f"===== Training Layer {t+1}/{T} =====")

        # Freeze parameters beyond current layer t
        for layer_idx in range(t):
            model.beta[layer_idx].requires_grad = False
            if model_class != 'LISTA' and linear_shared == True:
                model.mu[layer_idx].requires_grad = False
            if not linear_shared:
                if model_class == 'LISTA':
                    model.Ws_1[layer_idx].weight.requires_grad = False
                    model.Ws_2[layer_idx].weight.requires_grad = False
                if model_class == 'LISTA-CPSS':
                    model.Ws[layer_idx].weight.requires_grad = False            

        # Define optimizer to include W1, W2, and parameters up to layer t
        if model_class == 'LISTA':
            if not linear_shared:
                optimizer = optim.Adam(
                    list(model.Ws_1.parameters())[:t+1] + 
                    list(model.Ws_2.parameters())[:t+1] + 
                    list(model.beta)[:t+1],
                    lr=lr,
                    eps=eps
                )
            else:
                optimizer = optim.Adam(
                    list(model.Ws_1.parameters()) + 
                    list(model.Ws_2.parameters()) + 
                    list(model.beta)[:t+1] + 
                    list(model.mu)[:t+1],
                    lr=lr,
                    eps=eps
                )

        if model_class == 'LISTA-CPSS':
            optimizer = optim.Adam(
                list(model.Ws.parameters())[:t+1] +
                list(model.beta)[:t+1],
                lr=lr,
                eps=eps
            )

        if model_class == 'TILISTA':
            optimizer = optim.Adam(
                list(model.W.parameters()) +
                list(model.beta)[:t+1] + 
                list(model.mu)[:t+1],
                lr=lr,
                eps=eps
            )

        if model_class == 'ALISTA':
            optimizer = optim.Adam(
                list(model.beta)[:t+1] + 
                list(model.mu)[:t+1],
                lr=lr,
                eps=eps
            )

        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

        # Initialize loss tracking for current layer
        loss_train = np.zeros((num_epochs,))
        loss_test = np.zeros((num_epochs,))

        # Early stopping variables
        best_val_loss = float('inf')
        epochs_since_improvement = 0
        best_model_state = None

        for epoch in range(num_epochs):
            model.train()
            train_loss = 0.0
            signal_power_train = 0.0

            for Y, S in train_loader:
                Y = Y.to(device)
                S = S.to(device)

                optimizer.zero_grad()
                S_hat = model(Y, its=t)

                mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                signal_power = torch.sum(S ** 2)

                loss = mse_loss
                loss.backward()

                # Apply gradient clipping
                torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)

                optimizer.step()

                train_loss += mse_loss.item()
                signal_power_train += signal_power.item()

            # Compute NMSE in dB for training set
            nmse_train = train_loss / (signal_power_train + eps)
            loss_train[epoch] = 10 * np.log10(nmse_train + eps)
            scheduler.step()

            # Validation
            model.eval()
            test_loss_epoch = 0.0
            signal_power_test = 0.0

            with torch.no_grad():
                for Y, S in valid_loader:
                    Y = Y.to(device)
                    S = S.to(device)

                    S_hat = model(Y, its=t)

                    mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                    signal_power = torch.sum(S ** 2)

                    test_loss_epoch += mse_loss.item()
                    signal_power_test += signal_power.item()

            nmse_test = test_loss_epoch / (signal_power_test + eps)
            loss_test[epoch] = 10 * np.log10(nmse_test + eps)

            if verbose and (epoch % 10 == 0 or epoch == num_epochs - 1):
                print(
                    f"Layer {t+1}, Epoch {epoch+1}/{num_epochs}, "
                    f"Train NMSE (dB): {loss_train[epoch]:.6f}, "
                    f"Validation NMSE (dB): {loss_test[epoch]:.6f}"
                )

            # Early stopping check
            if loss_test[epoch] < best_val_loss:
                best_val_loss = loss_test[epoch]
                epochs_since_improvement = 0
                best_model_state = model.state_dict()  # Save the best model state
            else:
                epochs_since_improvement += 1

            if epochs_since_improvement >= patience:
                if verbose:
                    print(f"Early stopping triggered after {epoch+1} epochs")
                model.load_state_dict(best_model_state)  # Restore best model state
                break

        # Store losses for current layer
        loss_train_all[f"Layer_{t+1}"] = loss_train[:epoch+1]
        loss_test_all[f"Layer_{t+1}"] = loss_test[:epoch+1]

        if verbose:
            print(f"===== Finished Training Layer {t+1}/{T} =====\n")

        # Optionally, fine-tune the entire network
        if fine_tune_epochs > 0:
            if verbose:
                print("===== Fine-Tuning the Entire Network =====")

            # Unfreeze all parameters
            for layer_idx in range(t + 1):
                model.beta[layer_idx].requires_grad = True
                if model_class != 'LISTA' and linear_shared == True:
                    model.mu[layer_idx].requires_grad = True
                if not linear_shared:
                    if model_class == 'LISTA':
                        model.Ws_1[layer_idx].weight.requires_grad = True
                        model.Ws_2[layer_idx].weight.requires_grad = True
                    if model_class == 'LISTA-CPSS':
                        model.Ws[layer_idx].weight.requires_grad = True   

            if model_class == 'LISTA':
                if not linear_shared:
                    optimizer = optim.Adam(
                        list(model.Ws_1.parameters())[:t+1] + 
                        list(model.Ws_2.parameters())[:t+1] + 
                        list(model.beta)[:t+1],
                        lr=ft_lr,
                        eps=eps
                    )
                else:
                    optimizer = optim.Adam(
                        list(model.Ws_1.parameters()) + 
                        list(model.Ws_2.parameters()) + 
                        list(model.beta)[:t+1] + 
                        list(model.mu)[:t+1],
                        lr=ft_lr,
                        eps=eps
                    )

            if model_class == 'LISTA-CPSS':
                optimizer = optim.Adam(
                    list(model.Ws.parameters())[:t+1] +
                    list(model.beta)[:t+1],
                    lr=ft_lr,
                    eps=eps
                )

            if model_class == 'TILISTA':
                optimizer = optim.Adam(
                    list(model.W.parameters()) +
                    list(model.beta)[:t+1] + 
                    list(model.mu)[:t+1],
                    lr=ft_lr,
                    eps=eps
                )

            if model_class == 'ALISTA':
                optimizer = optim.Adam(
                    list(model.beta)[:t+1] + 
                    list(model.mu)[:t+1],
                    lr=ft_lr,
                    eps=eps
                )

            scheduler_ft = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

            # Initialize loss tracking for fine-tuning
            loss_train_ft = np.zeros((fine_tune_epochs,))
            loss_test_ft = np.zeros((fine_tune_epochs,))

            best_val_loss_ft = float('inf')
            epochs_since_improvement_ft = 0
            best_model_state_ft = None

            for epoch in range(fine_tune_epochs):
                model.train()
                train_loss = 0.0
                signal_power_train = 0.0

                for Y, S in train_loader:
                    Y = Y.to(device)
                    S = S.to(device)

                    optimizer.zero_grad()
                    S_hat = model(Y, its=t)

                    mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                    signal_power = torch.sum(S ** 2)

                    loss = mse_loss
                    loss.backward()

                    # Apply gradient clipping
                    torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)

                    optimizer.step()

                    train_loss += mse_loss.item()
                    signal_power_train += signal_power.item()

                # Compute NMSE in dB for training set
                nmse_train = train_loss / (signal_power_train + eps)
                loss_train_ft[epoch] = 10 * np.log10(nmse_train + eps)
                scheduler_ft.step()

                # Validation
                model.eval()
                test_loss_epoch = 0.0
                signal_power_test = 0.0

                with torch.no_grad():
                    for Y, S in valid_loader:
                        Y = Y.to(device)
                        S = S.to(device)

                        S_hat = model(Y, its=t)

                        mse_loss = F.mse_loss(S_hat, S, reduction="sum")
                        signal_power = torch.sum(S ** 2)

                        test_loss_epoch += mse_loss.item()
                        signal_power_test += signal_power.item()

                nmse_test = test_loss_epoch / (signal_power_test + eps)
                loss_test_ft[epoch] = 10 * np.log10(nmse_test + eps)

                if verbose and (epoch % 10 == 0 or epoch == fine_tune_epochs - 1):
                    print(
                        f"Fine-Tune Epoch {epoch+1}/{fine_tune_epochs}, "
                        f"Train NMSE (dB): {loss_train_ft[epoch]:.6f}, "
                        f"Validation NMSE (dB): {loss_test_ft[epoch]:.6f}"
                    )

                # Early stopping for fine-tuning
                if loss_test_ft[epoch] < best_val_loss_ft:
                    best_val_loss_ft = loss_test_ft[epoch]
                    epochs_since_improvement_ft = 0
                    best_model_state_ft = model.state_dict()  # Save the best model state
                else:
                    epochs_since_improvement_ft += 1

                if epochs_since_improvement_ft >= patience:
                    if verbose:
                        print(f"Early stopping for fine-tuning triggered after {epoch+1} epochs")
                    model.load_state_dict(best_model_state_ft)  # Restore best model state
                    break

            # Store fine-tuning losses
            loss_train_all["Fine_Tune"] = loss_train_ft[:epoch+1]
            loss_test_all["Fine_Tune"] = loss_test_ft[:epoch+1]

            if verbose:
                print("===== Finished Fine-Tuning =====\n")

    return loss_train_all, loss_test_all

# %%
layerwise_train(model2, train_set, test_set, 'ALISTA', lr = 3e-3, ft_lr = 3e-5)
# Out:
# ===== Training Layer 1/16 =====
# Layer 1, Epoch 1/100, Train NMSE (dB): -1.424022, Validation NMSE (dB): -1.633382
# Layer 1, Epoch 11/100, Train NMSE (dB): -3.905359, Validation NMSE (dB): -4.019544
# Layer 1, Epoch 21/100, Train NMSE (dB): -5.782291, Validation NMSE (dB): -5.835913
# Layer 1, Epoch 31/100, Train NMSE (dB): -6.223689, Validation NMSE (dB): -6.209320
# Layer 1, Epoch 41/100, Train NMSE (dB): -6.223953, Validation NMSE (dB): -6.209493
# Early stopping triggered after 50 epochs
# ===== Finished Training Layer 1/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -6.222848, Validation NMSE (dB): -6.208870
# Fine-Tune Epoch 11/100, Train NMSE (dB): -6.223966, Validation NMSE (dB): -6.209515
# Fine-Tune Epoch 21/100, Train NMSE (dB): -6.224019, Validation NMSE (dB): -6.209494
# Early stopping for fine-tuning triggered after 21 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 2/16 =====
# Layer 2, Epoch 1/100, Train NMSE (dB): -6.895934, Validation NMSE (dB): -7.041902
# Layer 2, Epoch 11/100, Train NMSE (dB): -8.202951, Validation NMSE (dB): -8.230446
# Layer 2, Epoch 21/100, Train NMSE (dB): -8.680784, Validation NMSE (dB): -8.671307
# Layer 2, Epoch 31/100, Train NMSE (dB): -8.685322, Validation NMSE (dB): -8.672620
# Early stopping triggered after 32 epochs
# ===== Finished Training Layer 2/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -8.686878, Validation NMSE (dB): -8.676109
# Fine-Tune Epoch 11/100, Train NMSE (dB): -8.722432, Validation NMSE (dB): -8.711299
# Fine-Tune Epoch 21/100, Train NMSE (dB): -8.757921, Validation NMSE (dB): -8.746405
# Fine-Tune Epoch 31/100, Train NMSE (dB): -8.793090, Validation NMSE (dB): -8.781495
# Fine-Tune Epoch 41/100, Train NMSE (dB): -8.828014, Validation NMSE (dB): -8.816250
# Fine-Tune Epoch 51/100, Train NMSE (dB): -8.861222, Validation NMSE (dB): -8.847570
# Fine-Tune Epoch 61/100, Train NMSE (dB): -8.864674, Validation NMSE (dB): -8.850974
# Fine-Tune Epoch 71/100, Train NMSE (dB): -8.868075, Validation NMSE (dB): -8.854369
# Fine-Tune Epoch 81/100, Train NMSE (dB): -8.871452, Validation NMSE (dB): -8.857711
# Fine-Tune Epoch 91/100, Train NMSE (dB): -8.874801, Validation NMSE (dB): -8.861037
# Fine-Tune Epoch 100/100, Train NMSE (dB): -8.877798, Validation NMSE (dB): -8.864099
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 3/16 =====
# Layer 3, Epoch 1/100, Train NMSE (dB): -9.289528, Validation NMSE (dB): -9.395195
# Layer 3, Epoch 11/100, Train NMSE (dB): -10.110771, Validation NMSE (dB): -10.121980
# Layer 3, Epoch 21/100, Train NMSE (dB): -10.511072, Validation NMSE (dB): -10.504837
# Layer 3, Epoch 31/100, Train NMSE (dB): -10.587126, Validation NMSE (dB): -10.573444
# Layer 3, Epoch 41/100, Train NMSE (dB): -10.587298, Validation NMSE (dB): -10.573458
# Early stopping triggered after 46 epochs
# ===== Finished Training Layer 3/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -10.591757, Validation NMSE (dB): -10.583332
# Fine-Tune Epoch 11/100, Train NMSE (dB): -10.688604, Validation NMSE (dB): -10.680322
# Fine-Tune Epoch 21/100, Train NMSE (dB): -10.784040, Validation NMSE (dB): -10.775704
# Fine-Tune Epoch 31/100, Train NMSE (dB): -10.878220, Validation NMSE (dB): -10.869772
# Fine-Tune Epoch 41/100, Train NMSE (dB): -10.970860, Validation NMSE (dB): -10.962743
# Fine-Tune Epoch 51/100, Train NMSE (dB): -11.058341, Validation NMSE (dB): -11.045882
# Fine-Tune Epoch 61/100, Train NMSE (dB): -11.067364, Validation NMSE (dB): -11.054961
# Fine-Tune Epoch 71/100, Train NMSE (dB): -11.076329, Validation NMSE (dB): -11.063795
# Fine-Tune Epoch 81/100, Train NMSE (dB): -11.085206, Validation NMSE (dB): -11.072731
# Fine-Tune Epoch 91/100, Train NMSE (dB): -11.094067, Validation NMSE (dB): -11.081556
# Fine-Tune Epoch 100/100, Train NMSE (dB): -11.102079, Validation NMSE (dB): -11.089448
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 4/16 =====
# Layer 4, Epoch 1/100, Train NMSE (dB): -11.507472, Validation NMSE (dB): -11.650330
# Layer 4, Epoch 11/100, Train NMSE (dB): -12.469415, Validation NMSE (dB): -12.486497
# Layer 4, Epoch 21/100, Train NMSE (dB): -12.905085, Validation NMSE (dB): -12.905139
# Layer 4, Epoch 31/100, Train NMSE (dB): -12.978598, Validation NMSE (dB): -12.972753
# Layer 4, Epoch 41/100, Train NMSE (dB): -12.978621, Validation NMSE (dB): -12.972837
# Early stopping triggered after 42 epochs
# ===== Finished Training Layer 4/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -12.985092, Validation NMSE (dB): -12.986820
# Fine-Tune Epoch 11/100, Train NMSE (dB): -13.124704, Validation NMSE (dB): -13.125674
# Fine-Tune Epoch 21/100, Train NMSE (dB): -13.260244, Validation NMSE (dB): -13.260186
# Fine-Tune Epoch 31/100, Train NMSE (dB): -13.392154, Validation NMSE (dB): -13.391219
# Fine-Tune Epoch 41/100, Train NMSE (dB): -13.521417, Validation NMSE (dB): -13.520285
# Fine-Tune Epoch 51/100, Train NMSE (dB): -13.643280, Validation NMSE (dB): -13.636761
# Fine-Tune Epoch 61/100, Train NMSE (dB): -13.655822, Validation NMSE (dB): -13.649377
# Fine-Tune Epoch 71/100, Train NMSE (dB): -13.668249, Validation NMSE (dB): -13.661648
# Fine-Tune Epoch 81/100, Train NMSE (dB): -13.680696, Validation NMSE (dB): -13.674215
# Fine-Tune Epoch 91/100, Train NMSE (dB): -13.693086, Validation NMSE (dB): -13.686487
# Fine-Tune Epoch 100/100, Train NMSE (dB): -13.704353, Validation NMSE (dB): -13.697908
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 5/16 =====
# Layer 5, Epoch 1/100, Train NMSE (dB): -14.025733, Validation NMSE (dB): -14.228085
# Layer 5, Epoch 11/100, Train NMSE (dB): -15.117378, Validation NMSE (dB): -15.144775
# Layer 5, Epoch 21/100, Train NMSE (dB): -15.617577, Validation NMSE (dB): -15.626534
# Layer 5, Epoch 31/100, Train NMSE (dB): -15.744212, Validation NMSE (dB): -15.745955
# Layer 5, Epoch 41/100, Train NMSE (dB): -15.744929, Validation NMSE (dB): -15.746359
# Early stopping triggered after 50 epochs
# ===== Finished Training Layer 5/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -15.755844, Validation NMSE (dB): -15.769788
# Fine-Tune Epoch 11/100, Train NMSE (dB): -15.990913, Validation NMSE (dB): -16.006089
# Fine-Tune Epoch 21/100, Train NMSE (dB): -16.219731, Validation NMSE (dB): -16.233195
# Fine-Tune Epoch 31/100, Train NMSE (dB): -16.441534, Validation NMSE (dB): -16.454399
# Fine-Tune Epoch 41/100, Train NMSE (dB): -16.655047, Validation NMSE (dB): -16.668444
# Fine-Tune Epoch 51/100, Train NMSE (dB): -16.852833, Validation NMSE (dB): -16.856028
# Fine-Tune Epoch 61/100, Train NMSE (dB): -16.872989, Validation NMSE (dB): -16.876066
# Fine-Tune Epoch 71/100, Train NMSE (dB): -16.892695, Validation NMSE (dB): -16.895590
# Fine-Tune Epoch 81/100, Train NMSE (dB): -16.912259, Validation NMSE (dB): -16.915451
# Fine-Tune Epoch 91/100, Train NMSE (dB): -16.931678, Validation NMSE (dB): -16.934383
# Fine-Tune Epoch 100/100, Train NMSE (dB): -16.949101, Validation NMSE (dB): -16.951399
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 6/16 =====
# Layer 6, Epoch 1/100, Train NMSE (dB): -17.170778, Validation NMSE (dB): -17.468195
# Layer 6, Epoch 11/100, Train NMSE (dB): -18.528620, Validation NMSE (dB): -18.565639
# Layer 6, Epoch 21/100, Train NMSE (dB): -19.040377, Validation NMSE (dB): -19.057143
# Layer 6, Epoch 31/100, Train NMSE (dB): -19.139867, Validation NMSE (dB): -19.153101
# Layer 6, Epoch 41/100, Train NMSE (dB): -19.140162, Validation NMSE (dB): -19.155145
# Early stopping triggered after 46 epochs
# ===== Finished Training Layer 6/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -19.155379, Validation NMSE (dB): -19.186260
# Fine-Tune Epoch 11/100, Train NMSE (dB): -19.451297, Validation NMSE (dB): -19.480058
# Fine-Tune Epoch 21/100, Train NMSE (dB): -19.734792, Validation NMSE (dB): -19.761491
# Fine-Tune Epoch 31/100, Train NMSE (dB): -20.004060, Validation NMSE (dB): -20.030885
# Fine-Tune Epoch 41/100, Train NMSE (dB): -20.260138, Validation NMSE (dB): -20.284422
# Fine-Tune Epoch 51/100, Train NMSE (dB): -20.492344, Validation NMSE (dB): -20.504225
# Fine-Tune Epoch 61/100, Train NMSE (dB): -20.515643, Validation NMSE (dB): -20.526918
# Fine-Tune Epoch 71/100, Train NMSE (dB): -20.539032, Validation NMSE (dB): -20.549234
# Fine-Tune Epoch 81/100, Train NMSE (dB): -20.561952, Validation NMSE (dB): -20.572914
# Fine-Tune Epoch 91/100, Train NMSE (dB): -20.584559, Validation NMSE (dB): -20.595642
# Fine-Tune Epoch 100/100, Train NMSE (dB): -20.604752, Validation NMSE (dB): -20.615649
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 7/16 =====
# Layer 7, Epoch 1/100, Train NMSE (dB): -20.640316, Validation NMSE (dB): -21.048804
# Layer 7, Epoch 11/100, Train NMSE (dB): -22.326476, Validation NMSE (dB): -22.374396
# Layer 7, Epoch 21/100, Train NMSE (dB): -22.920624, Validation NMSE (dB): -22.947686
# Layer 7, Epoch 31/100, Train NMSE (dB): -23.064138, Validation NMSE (dB): -23.086218
# Layer 7, Epoch 41/100, Train NMSE (dB): -23.065122, Validation NMSE (dB): -23.086536
# Layer 7, Epoch 51/100, Train NMSE (dB): -23.065159, Validation NMSE (dB): -23.090633
# Early stopping triggered after 57 epochs
# ===== Finished Training Layer 7/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -23.088989, Validation NMSE (dB): -23.138915
# Fine-Tune Epoch 11/100, Train NMSE (dB): -23.526050, Validation NMSE (dB): -23.567890
# Fine-Tune Epoch 21/100, Train NMSE (dB): -23.928539, Validation NMSE (dB): -23.971732
# Fine-Tune Epoch 31/100, Train NMSE (dB): -24.300333, Validation NMSE (dB): -24.344187
# Fine-Tune Epoch 41/100, Train NMSE (dB): -24.640380, Validation NMSE (dB): -24.683038
# Fine-Tune Epoch 51/100, Train NMSE (dB): -24.932965, Validation NMSE (dB): -24.958520
# Fine-Tune Epoch 61/100, Train NMSE (dB): -24.961606, Validation NMSE (dB): -24.986823
# Fine-Tune Epoch 71/100, Train NMSE (dB): -24.989040, Validation NMSE (dB): -25.014588
# Fine-Tune Epoch 81/100, Train NMSE (dB): -25.016228, Validation NMSE (dB): -25.041432
# Fine-Tune Epoch 91/100, Train NMSE (dB): -25.042777, Validation NMSE (dB): -25.069023
# Fine-Tune Epoch 100/100, Train NMSE (dB): -25.066203, Validation NMSE (dB): -25.093856
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 8/16 =====
# Layer 8, Epoch 1/100, Train NMSE (dB): -25.086428, Validation NMSE (dB): -25.540609
# Layer 8, Epoch 11/100, Train NMSE (dB): -27.077252, Validation NMSE (dB): -27.137433
# Layer 8, Epoch 21/100, Train NMSE (dB): -27.751235, Validation NMSE (dB): -27.780926
# Layer 8, Epoch 31/100, Train NMSE (dB): -27.936948, Validation NMSE (dB): -27.951672
# Layer 8, Epoch 41/100, Train NMSE (dB): -27.950413, Validation NMSE (dB): -27.975340
# Layer 8, Epoch 51/100, Train NMSE (dB): -27.952060, Validation NMSE (dB): -27.975510
# Layer 8, Epoch 61/100, Train NMSE (dB): -27.951974, Validation NMSE (dB): -27.975466
# Layer 8, Epoch 71/100, Train NMSE (dB): -27.952164, Validation NMSE (dB): -27.975652
# Layer 8, Epoch 81/100, Train NMSE (dB): -27.952110, Validation NMSE (dB): -27.975552
# Layer 8, Epoch 91/100, Train NMSE (dB): -27.952079, Validation NMSE (dB): -27.975828
# Layer 8, Epoch 100/100, Train NMSE (dB): -27.952176, Validation NMSE (dB): -27.975774
# ===== Finished Training Layer 8/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -27.980846, Validation NMSE (dB): -28.035895
# Fine-Tune Epoch 11/100, Train NMSE (dB): -28.492851, Validation NMSE (dB): -28.533081
# Fine-Tune Epoch 21/100, Train NMSE (dB): -28.944880, Validation NMSE (dB): -28.980680
# Fine-Tune Epoch 31/100, Train NMSE (dB): -29.346332, Validation NMSE (dB): -29.381338
# Fine-Tune Epoch 41/100, Train NMSE (dB): -29.687968, Validation NMSE (dB): -29.731870
# Fine-Tune Epoch 51/100, Train NMSE (dB): -29.964693, Validation NMSE (dB): -29.998363
# Fine-Tune Epoch 61/100, Train NMSE (dB): -29.990620, Validation NMSE (dB): -30.024250
# Fine-Tune Epoch 71/100, Train NMSE (dB): -30.015666, Validation NMSE (dB): -30.049277
# Fine-Tune Epoch 81/100, Train NMSE (dB): -30.039737, Validation NMSE (dB): -30.075251
# Fine-Tune Epoch 91/100, Train NMSE (dB): -30.064071, Validation NMSE (dB): -30.098456
# Fine-Tune Epoch 100/100, Train NMSE (dB): -30.084669, Validation NMSE (dB): -30.118825
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 9/16 =====
# Layer 9, Epoch 1/100, Train NMSE (dB): -31.041182, Validation NMSE (dB): -31.174125
# Layer 9, Epoch 11/100, Train NMSE (dB): -32.524734, Validation NMSE (dB): -32.582990
# Layer 9, Epoch 21/100, Train NMSE (dB): -33.522093, Validation NMSE (dB): -33.546833
# Layer 9, Epoch 31/100, Train NMSE (dB): -33.855324, Validation NMSE (dB): -33.867771
# Layer 9, Epoch 41/100, Train NMSE (dB): -33.880488, Validation NMSE (dB): -33.894941
# Layer 9, Epoch 51/100, Train NMSE (dB): -33.881080, Validation NMSE (dB): -33.896490
# Layer 9, Epoch 61/100, Train NMSE (dB): -33.880958, Validation NMSE (dB): -33.896511
# Layer 9, Epoch 71/100, Train NMSE (dB): -33.880991, Validation NMSE (dB): -33.896555
# Layer 9, Epoch 81/100, Train NMSE (dB): -33.880982, Validation NMSE (dB): -33.896574
# Layer 9, Epoch 91/100, Train NMSE (dB): -33.880839, Validation NMSE (dB): -33.896484
# Layer 9, Epoch 100/100, Train NMSE (dB): -33.880980, Validation NMSE (dB): -33.896558
# ===== Finished Training Layer 9/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -33.918820, Validation NMSE (dB): -33.977105
# Fine-Tune Epoch 11/100, Train NMSE (dB): -34.552513, Validation NMSE (dB): -34.578243
# Fine-Tune Epoch 21/100, Train NMSE (dB): -35.062803, Validation NMSE (dB): -35.078096
# Fine-Tune Epoch 31/100, Train NMSE (dB): -35.462518, Validation NMSE (dB): -35.495522
# Fine-Tune Epoch 41/100, Train NMSE (dB): -35.761430, Validation NMSE (dB): -35.801112
# Fine-Tune Epoch 51/100, Train NMSE (dB): -35.960717, Validation NMSE (dB): -35.978349
# Fine-Tune Epoch 61/100, Train NMSE (dB): -35.977884, Validation NMSE (dB): -35.995894
# Fine-Tune Epoch 71/100, Train NMSE (dB): -35.993689, Validation NMSE (dB): -36.013465
# Fine-Tune Epoch 81/100, Train NMSE (dB): -36.006862, Validation NMSE (dB): -36.028498
# Fine-Tune Epoch 91/100, Train NMSE (dB): -36.018223, Validation NMSE (dB): -36.042179
# Fine-Tune Epoch 100/100, Train NMSE (dB): -36.029040, Validation NMSE (dB): -36.057255
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 10/16 =====
# Layer 10, Epoch 1/100, Train NMSE (dB): -37.142161, Validation NMSE (dB): -37.260623
# Layer 10, Epoch 11/100, Train NMSE (dB): -38.804660, Validation NMSE (dB): -38.876641
# Layer 10, Epoch 21/100, Train NMSE (dB): -39.807709, Validation NMSE (dB): -39.826777
# Layer 10, Epoch 31/100, Train NMSE (dB): -40.191748, Validation NMSE (dB): -40.188422
# Layer 10, Epoch 41/100, Train NMSE (dB): -40.289593, Validation NMSE (dB): -40.275774
# Layer 10, Epoch 51/100, Train NMSE (dB): -40.306785, Validation NMSE (dB): -40.290414
# Layer 10, Epoch 61/100, Train NMSE (dB): -40.307278, Validation NMSE (dB): -40.291798
# Layer 10, Epoch 71/100, Train NMSE (dB): -40.308018, Validation NMSE (dB): -40.292225
# Layer 10, Epoch 81/100, Train NMSE (dB): -40.308384, Validation NMSE (dB): -40.292589
# Layer 10, Epoch 91/100, Train NMSE (dB): -40.308686, Validation NMSE (dB): -40.292896
# Layer 10, Epoch 100/100, Train NMSE (dB): -40.308937, Validation NMSE (dB): -40.293114
# ===== Finished Training Layer 10/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -40.327767, Validation NMSE (dB): -40.332627
# Fine-Tune Epoch 11/100, Train NMSE (dB): -40.659377, Validation NMSE (dB): -40.658946
# Fine-Tune Epoch 21/100, Train NMSE (dB): -40.870270, Validation NMSE (dB): -40.860845
# Fine-Tune Epoch 31/100, Train NMSE (dB): -40.992145, Validation NMSE (dB): -40.988117
# Fine-Tune Epoch 41/100, Train NMSE (dB): -41.061481, Validation NMSE (dB): -41.066788
# Fine-Tune Epoch 51/100, Train NMSE (dB): -41.096375, Validation NMSE (dB): -41.097448
# Fine-Tune Epoch 61/100, Train NMSE (dB): -41.099965, Validation NMSE (dB): -41.101890
# Fine-Tune Epoch 71/100, Train NMSE (dB): -41.102829, Validation NMSE (dB): -41.105377
# Fine-Tune Epoch 81/100, Train NMSE (dB): -41.106067, Validation NMSE (dB): -41.107051
# Fine-Tune Epoch 91/100, Train NMSE (dB): -41.108369, Validation NMSE (dB): -41.109058
# Fine-Tune Epoch 100/100, Train NMSE (dB): -41.110453, Validation NMSE (dB): -41.111355
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 11/16 =====
# Layer 11, Epoch 1/100, Train NMSE (dB): -42.076785, Validation NMSE (dB): -42.166547
# Layer 11, Epoch 11/100, Train NMSE (dB): -43.433994, Validation NMSE (dB): -43.499625
# Layer 11, Epoch 21/100, Train NMSE (dB): -44.229999, Validation NMSE (dB): -44.256853
# Layer 11, Epoch 31/100, Train NMSE (dB): -44.516871, Validation NMSE (dB): -44.515993
# Layer 11, Epoch 41/100, Train NMSE (dB): -44.574337, Validation NMSE (dB): -44.562067
# Layer 11, Epoch 51/100, Train NMSE (dB): -44.582078, Validation NMSE (dB): -44.566853
# Layer 11, Epoch 61/100, Train NMSE (dB): -44.582249, Validation NMSE (dB): -44.566921
# Layer 11, Epoch 71/100, Train NMSE (dB): -44.582406, Validation NMSE (dB): -44.566961
# Layer 11, Epoch 81/100, Train NMSE (dB): -44.582529, Validation NMSE (dB): -44.566984
# Layer 11, Epoch 91/100, Train NMSE (dB): -44.582625, Validation NMSE (dB): -44.567033
# Early stopping triggered after 97 epochs
# ===== Finished Training Layer 11/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -44.585614, Validation NMSE (dB): -44.573760
# Fine-Tune Epoch 11/100, Train NMSE (dB): -44.637948, Validation NMSE (dB): -44.620033
# Fine-Tune Epoch 21/100, Train NMSE (dB): -44.671546, Validation NMSE (dB): -44.656907
# Fine-Tune Epoch 31/100, Train NMSE (dB): -44.703729, Validation NMSE (dB): -44.685468
# Fine-Tune Epoch 41/100, Train NMSE (dB): -44.730811, Validation NMSE (dB): -44.714921
# Fine-Tune Epoch 51/100, Train NMSE (dB): -44.754800, Validation NMSE (dB): -44.752100
# Fine-Tune Epoch 61/100, Train NMSE (dB): -44.757633, Validation NMSE (dB): -44.758913
# Fine-Tune Epoch 71/100, Train NMSE (dB): -44.760183, Validation NMSE (dB): -44.763296
# Fine-Tune Epoch 81/100, Train NMSE (dB): -44.762471, Validation NMSE (dB): -44.766570
# Fine-Tune Epoch 91/100, Train NMSE (dB): -44.765744, Validation NMSE (dB): -44.768864
# Fine-Tune Epoch 100/100, Train NMSE (dB): -44.767709, Validation NMSE (dB): -44.770746
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 12/16 =====
# Layer 12, Epoch 1/100, Train NMSE (dB): -45.525632, Validation NMSE (dB): -45.590098
# Layer 12, Epoch 11/100, Train NMSE (dB): -46.616992, Validation NMSE (dB): -46.655598
# Layer 12, Epoch 21/100, Train NMSE (dB): -47.228449, Validation NMSE (dB): -47.236681
# Layer 12, Epoch 31/100, Train NMSE (dB): -47.444752, Validation NMSE (dB): -47.438557
# Layer 12, Epoch 41/100, Train NMSE (dB): -47.496024, Validation NMSE (dB): -47.485466
# Layer 12, Epoch 51/100, Train NMSE (dB): -47.504795, Validation NMSE (dB): -47.493212
# Layer 12, Epoch 61/100, Train NMSE (dB): -47.505060, Validation NMSE (dB): -47.493473
# Layer 12, Epoch 71/100, Train NMSE (dB): -47.505300, Validation NMSE (dB): -47.493565
# Layer 12, Epoch 81/100, Train NMSE (dB): -47.505518, Validation NMSE (dB): -47.493773
# Layer 12, Epoch 91/100, Train NMSE (dB): -47.505732, Validation NMSE (dB): -47.493941
# Layer 12, Epoch 100/100, Train NMSE (dB): -47.505869, Validation NMSE (dB): -47.494073
# ===== Finished Training Layer 12/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -47.507804, Validation NMSE (dB): -47.499212
# Fine-Tune Epoch 11/100, Train NMSE (dB): -47.545843, Validation NMSE (dB): -47.536275
# Fine-Tune Epoch 21/100, Train NMSE (dB): -47.574416, Validation NMSE (dB): -47.571250
# Fine-Tune Epoch 31/100, Train NMSE (dB): -47.604841, Validation NMSE (dB): -47.596054
# Fine-Tune Epoch 41/100, Train NMSE (dB): -47.634586, Validation NMSE (dB): -47.624700
# Fine-Tune Epoch 51/100, Train NMSE (dB): -47.662191, Validation NMSE (dB): -47.651460
# Fine-Tune Epoch 61/100, Train NMSE (dB): -47.664883, Validation NMSE (dB): -47.654096
# Fine-Tune Epoch 71/100, Train NMSE (dB): -47.667657, Validation NMSE (dB): -47.658764
# Fine-Tune Epoch 81/100, Train NMSE (dB): -47.670844, Validation NMSE (dB): -47.662399
# Fine-Tune Epoch 91/100, Train NMSE (dB): -47.673610, Validation NMSE (dB): -47.665529
# Fine-Tune Epoch 100/100, Train NMSE (dB): -47.676084, Validation NMSE (dB): -47.667989
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 13/16 =====
# Layer 13, Epoch 1/100, Train NMSE (dB): -48.347517, Validation NMSE (dB): -48.398298
# Layer 13, Epoch 11/100, Train NMSE (dB): -49.316343, Validation NMSE (dB): -49.351910
# Layer 13, Epoch 21/100, Train NMSE (dB): -49.898617, Validation NMSE (dB): -49.905258
# Layer 13, Epoch 31/100, Train NMSE (dB): -50.098447, Validation NMSE (dB): -50.094028
# Layer 13, Epoch 41/100, Train NMSE (dB): -50.150021, Validation NMSE (dB): -50.140464
# Layer 13, Epoch 51/100, Train NMSE (dB): -50.161536, Validation NMSE (dB): -50.151280
# Layer 13, Epoch 61/100, Train NMSE (dB): -50.161983, Validation NMSE (dB): -50.151720
# Layer 13, Epoch 71/100, Train NMSE (dB): -50.162396, Validation NMSE (dB): -50.152124
# Layer 13, Epoch 81/100, Train NMSE (dB): -50.162789, Validation NMSE (dB): -50.152453
# Layer 13, Epoch 91/100, Train NMSE (dB): -50.163121, Validation NMSE (dB): -50.152805
# Layer 13, Epoch 100/100, Train NMSE (dB): -50.163372, Validation NMSE (dB): -50.153016
# ===== Finished Training Layer 13/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -50.165020, Validation NMSE (dB): -50.156903
# Fine-Tune Epoch 11/100, Train NMSE (dB): -50.203574, Validation NMSE (dB): -50.199595
# Fine-Tune Epoch 21/100, Train NMSE (dB): -50.238882, Validation NMSE (dB): -50.232930
# Fine-Tune Epoch 31/100, Train NMSE (dB): -50.273143, Validation NMSE (dB): -50.267914
# Fine-Tune Epoch 41/100, Train NMSE (dB): -50.306795, Validation NMSE (dB): -50.298698
# Fine-Tune Epoch 51/100, Train NMSE (dB): -50.339872, Validation NMSE (dB): -50.322772
# Fine-Tune Epoch 61/100, Train NMSE (dB): -50.342392, Validation NMSE (dB): -50.326376
# Fine-Tune Epoch 71/100, Train NMSE (dB): -50.346526, Validation NMSE (dB): -50.327836
# Fine-Tune Epoch 81/100, Train NMSE (dB): -50.349588, Validation NMSE (dB): -50.330363
# Fine-Tune Epoch 91/100, Train NMSE (dB): -50.352366, Validation NMSE (dB): -50.332745
# Fine-Tune Epoch 100/100, Train NMSE (dB): -50.356240, Validation NMSE (dB): -50.337365
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 14/16 =====
# Layer 14, Epoch 1/100, Train NMSE (dB): -50.983862, Validation NMSE (dB): -51.015484
# Layer 14, Epoch 11/100, Train NMSE (dB): -51.875495, Validation NMSE (dB): -51.886588
# Layer 14, Epoch 21/100, Train NMSE (dB): -52.371302, Validation NMSE (dB): -52.358732
# Layer 14, Epoch 31/100, Train NMSE (dB): -52.533232, Validation NMSE (dB): -52.513113
# Layer 14, Epoch 41/100, Train NMSE (dB): -52.576231, Validation NMSE (dB): -52.554123
# Layer 14, Epoch 51/100, Train NMSE (dB): -52.586422, Validation NMSE (dB): -52.561353
# Layer 14, Epoch 61/100, Train NMSE (dB): -52.586844, Validation NMSE (dB): -52.561728
# Layer 14, Epoch 71/100, Train NMSE (dB): -52.587242, Validation NMSE (dB): -52.562339
# Layer 14, Epoch 81/100, Train NMSE (dB): -52.587602, Validation NMSE (dB): -52.562775
# Layer 14, Epoch 91/100, Train NMSE (dB): -52.587963, Validation NMSE (dB): -52.562994
# Layer 14, Epoch 100/100, Train NMSE (dB): -52.588215, Validation NMSE (dB): -52.563330
# ===== Finished Training Layer 14/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -52.589055, Validation NMSE (dB): -52.565915
# Fine-Tune Epoch 11/100, Train NMSE (dB): -52.625066, Validation NMSE (dB): -52.611626
# Fine-Tune Epoch 21/100, Train NMSE (dB): -52.658142, Validation NMSE (dB): -52.653405
# Fine-Tune Epoch 31/100, Train NMSE (dB): -52.689995, Validation NMSE (dB): -52.691402
# Fine-Tune Epoch 41/100, Train NMSE (dB): -52.721924, Validation NMSE (dB): -52.715794
# Fine-Tune Epoch 51/100, Train NMSE (dB): -52.754030, Validation NMSE (dB): -52.744136
# Fine-Tune Epoch 61/100, Train NMSE (dB): -52.757858, Validation NMSE (dB): -52.746167
# Fine-Tune Epoch 71/100, Train NMSE (dB): -52.760515, Validation NMSE (dB): -52.749885
# Fine-Tune Epoch 81/100, Train NMSE (dB): -52.764151, Validation NMSE (dB): -52.750111
# Fine-Tune Epoch 91/100, Train NMSE (dB): -52.767193, Validation NMSE (dB): -52.752266
# Fine-Tune Epoch 100/100, Train NMSE (dB): -52.770033, Validation NMSE (dB): -52.755422
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 15/16 =====
# Layer 15, Epoch 1/100, Train NMSE (dB): -53.310466, Validation NMSE (dB): -53.343042
# Layer 15, Epoch 11/100, Train NMSE (dB): -54.067929, Validation NMSE (dB): -54.088324
# Layer 15, Epoch 21/100, Train NMSE (dB): -54.506296, Validation NMSE (dB): -54.504734
# Layer 15, Epoch 31/100, Train NMSE (dB): -54.652046, Validation NMSE (dB): -54.640820
# Layer 15, Epoch 41/100, Train NMSE (dB): -54.691181, Validation NMSE (dB): -54.677614
# Layer 15, Epoch 51/100, Train NMSE (dB): -54.700431, Validation NMSE (dB): -54.686651
# Layer 15, Epoch 61/100, Train NMSE (dB): -54.700840, Validation NMSE (dB): -54.687096
# Layer 15, Epoch 71/100, Train NMSE (dB): -54.701220, Validation NMSE (dB): -54.687366
# Layer 15, Epoch 81/100, Train NMSE (dB): -54.701568, Validation NMSE (dB): -54.687723
# Layer 15, Epoch 91/100, Train NMSE (dB): -54.701877, Validation NMSE (dB): -54.688027
# Layer 15, Epoch 100/100, Train NMSE (dB): -54.702196, Validation NMSE (dB): -54.688498
# ===== Finished Training Layer 15/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -54.704590, Validation NMSE (dB): -54.688500
# Fine-Tune Epoch 11/100, Train NMSE (dB): -54.736244, Validation NMSE (dB): -54.710902
# Fine-Tune Epoch 21/100, Train NMSE (dB): -54.770410, Validation NMSE (dB): -54.746909
# Fine-Tune Epoch 31/100, Train NMSE (dB): -54.800424, Validation NMSE (dB): -54.786212
# Fine-Tune Epoch 41/100, Train NMSE (dB): -54.830969, Validation NMSE (dB): -54.813864
# Fine-Tune Epoch 51/100, Train NMSE (dB): -54.858933, Validation NMSE (dB): -54.844034
# Fine-Tune Epoch 61/100, Train NMSE (dB): -54.861862, Validation NMSE (dB): -54.854327
# Fine-Tune Epoch 71/100, Train NMSE (dB): -54.864399, Validation NMSE (dB): -54.853715
# Early stopping for fine-tuning triggered after 73 epochs
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 16/16 =====
# Layer 16, Epoch 1/100, Train NMSE (dB): -55.325822, Validation NMSE (dB): -55.352354
# Layer 16, Epoch 11/100, Train NMSE (dB): -55.952305, Validation NMSE (dB): -55.966232
# Layer 16, Epoch 21/100, Train NMSE (dB): -56.285397, Validation NMSE (dB): -56.283380
# Layer 16, Epoch 31/100, Train NMSE (dB): -56.391904, Validation NMSE (dB): -56.385025
# Layer 16, Epoch 41/100, Train NMSE (dB): -56.421201, Validation NMSE (dB): -56.414515
# Layer 16, Epoch 51/100, Train NMSE (dB): -56.429096, Validation NMSE (dB): -56.422296
# Layer 16, Epoch 61/100, Train NMSE (dB): -56.429436, Validation NMSE (dB): -56.422471
# Layer 16, Epoch 71/100, Train NMSE (dB): -56.429757, Validation NMSE (dB): -56.422900
# Layer 16, Epoch 81/100, Train NMSE (dB): -56.430047, Validation NMSE (dB): -56.423572
# Layer 16, Epoch 91/100, Train NMSE (dB): -56.430310, Validation NMSE (dB): -56.423665
# Layer 16, Epoch 100/100, Train NMSE (dB): -56.430515, Validation NMSE (dB): -56.424115
# ===== Finished Training Layer 16/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -56.433040, Validation NMSE (dB): -56.423137
# Fine-Tune Epoch 11/100, Train NMSE (dB): -56.466515, Validation NMSE (dB): -56.447330
# Fine-Tune Epoch 21/100, Train NMSE (dB): -56.495237, Validation NMSE (dB): -56.485574
# Fine-Tune Epoch 31/100, Train NMSE (dB): -56.520005, Validation NMSE (dB): -56.503569
# Fine-Tune Epoch 41/100, Train NMSE (dB): -56.545446, Validation NMSE (dB): -56.530414
# Fine-Tune Epoch 51/100, Train NMSE (dB): -56.567845, Validation NMSE (dB): -56.554055
# Fine-Tune Epoch 61/100, Train NMSE (dB): -56.570812, Validation NMSE (dB): -56.555228
# Fine-Tune Epoch 71/100, Train NMSE (dB): -56.571436, Validation NMSE (dB): -56.557521
# Fine-Tune Epoch 81/100, Train NMSE (dB): -56.573740, Validation NMSE (dB): -56.562566
# Fine-Tune Epoch 91/100, Train NMSE (dB): -56.576052, Validation NMSE (dB): -56.563446
# Fine-Tune Epoch 100/100, Train NMSE (dB): -56.579155, Validation NMSE (dB): -56.570590
# ===== Finished Fine-Tuning =====
#
# ===== Training Layer 17/16 =====
# Layer 17, Epoch 1/100, Train NMSE (dB): -56.925143, Validation NMSE (dB): -56.948151
# Layer 17, Epoch 11/100, Train NMSE (dB): -57.384474, Validation NMSE (dB): -57.400474
# Layer 17, Epoch 21/100, Train NMSE (dB): -57.634365, Validation NMSE (dB): -57.639114
# Layer 17, Epoch 31/100, Train NMSE (dB): -57.716466, Validation NMSE (dB): -57.714569
# Layer 17, Epoch 41/100, Train NMSE (dB): -57.738894, Validation NMSE (dB): -57.734985
# Layer 17, Epoch 51/100, Train NMSE (dB): -57.744576, Validation NMSE (dB): -57.739930
# Layer 17, Epoch 61/100, Train NMSE (dB): -57.744838, Validation NMSE (dB): -57.740256
# Layer 17, Epoch 71/100, Train NMSE (dB): -57.745084, Validation NMSE (dB): -57.740451
# Layer 17, Epoch 81/100, Train NMSE (dB): -57.745307, Validation NMSE (dB): -57.740667
# Layer 17, Epoch 91/100, Train NMSE (dB): -57.745510, Validation NMSE (dB): -57.740954
# Layer 17, Epoch 100/100, Train NMSE (dB): -57.745675, Validation NMSE (dB): -57.740977
# ===== Finished Training Layer 17/16 =====
#
# ===== Fine-Tuning the Entire Network =====
# Fine-Tune Epoch 1/100, Train NMSE (dB): -57.746899, Validation NMSE (dB): -57.741341
# Fine-Tune Epoch 11/100, Train NMSE (dB): -57.768417, Validation NMSE (dB): -57.765385
# Fine-Tune Epoch 21/100, Train NMSE (dB): -57.787154, Validation NMSE (dB): -57.779675
# Fine-Tune Epoch 31/100, Train NMSE (dB): -57.806715, Validation NMSE (dB): -57.794404
# Fine-Tune Epoch 41/100, Train NMSE (dB): -57.828145, Validation NMSE (dB): -57.812785
# Fine-Tune Epoch 51/100, Train NMSE (dB): -57.845645, Validation NMSE (dB): -57.832468
# Fine-Tune Epoch 61/100, Train NMSE (dB): -57.847706, Validation NMSE (dB): -57.834605
# Fine-Tune Epoch 71/100, Train NMSE (dB): -57.848157, Validation NMSE (dB): -57.833494
# Early stopping for fine-tuning triggered after 72 epochs
# ===== Finished Fine-Tuning =====
# ({'Layer_1': array([-1.42402246, -1.77968769, -2.03069635, -2.25964844, -2.50548948,
#          -2.74549427, -2.98153429, -3.21526789, -3.44761406, -3.67814538,
#          -3.90535947, -4.12845398, -4.34663126, -4.55900366, -4.7646461 ,
#          -4.96245331, -5.15047412, -5.32810469, -5.49338684, -5.6453349 ,
#          -5.78229089, -5.90274093, -6.00528686, -6.08931447, -6.15343838,
#          -6.19697677, -6.2194237 , -6.22251274, -6.22219959, -6.22360736,
#          -6.22368888, -6.22390119, -6.22355983, -6.22392661, -6.223916  ,
#          -6.22392399, -6.22400029, -6.22397419, -6.22400025, -6.22400586,
#          -6.22395296, -6.22383928, -6.22385163, -6.22392643, -6.22381456,
#          -6.22392413, -6.22398303, -6.22393968, -6.2236478 , -6.22351925]),
#   'Fine_Tune': array([-57.74689864, -57.7493656 , -57.75164344, -57.75441181,
#          -57.75627763, -57.75785485, -57.75998968, -57.76213188,
#          -57.76427193, -57.76566181, -57.76841673, -57.77044178,
#          -57.77232696, -57.77415175, -57.77630778, -57.77822025,
#          -57.78003468, -57.78169979, -57.78342124, -57.78546641,
#          -57.73498472, -57.73609009, -57.73668627, -57.73742767,
#          -57.73810899, -57.73847798, -57.73885188, -57.7394171 ,
#          -57.7396188 , -57.73994817, -57.73993046, -57.73984322,
#          -57.73985423, -57.74015184, -57.73993405, -57.74018336,
#          -57.74024443, -57.73998893, -57.74015926, -57.74021222,
#          -57.74025629, -57.74035559, -57.74028183, -57.74022801,
#          -57.74011805, -57.74036279, -57.7403781 , -57.7403885 ,
#          -57.74040535, -57.74041051, -57.74045121, -57.74029146,
#          -57.74059727, -57.74053448, -57.74066808, -57.74038275,
#          -57.74051195, -57.74056696, -57.74055598, -57.74061463,
#          -57.74066663, -57.74050222, -57.7405583 , -57.74082512,
#          -57.74088081, -57.74075491, -57.7407239 , -57.74082993,
#          -57.74084274, -57.7408679 , -57.74095409, -57.74080165,
#          -57.74083166, -57.74075144, -57.74073183, -57.74105724,
#          -57.74103862, -57.74107474, -57.74083499, -57.74097737])})

# %%
model2.compute_nmse_inference(test_set)
# Out:
# tensor([ -7.9949, -11.3335, -14.1636, -17.5738, -20.7830, -25.1252, -29.6864,
#         -35.0528, -39.9037, -45.6084, -48.8130, -51.6654, -54.3458, -56.9199,
#         -59.4318, -61.8914], device='cuda:0')

# %%
plt.plot(model2.compute_nmse_inference(test_set).cpu(), marker = 'o', linestyle='dashed', label = 'ALISTA')
plt.plot(model.compute_nmse_inference(test_set).cpu(), marker = '>', linestyle='dashed', label = 'AL-DC-ISTA (ours)')
plt.ylabel('NMSE (db)')
plt.xlabel('Layers')
plt.legend()
plt.grid(True, which="both", ls="--", linewidth=0.5)

# %%
def Conditioning(A, k = 1):
    U, S, Vh = torch.linalg.svd(A, full_matrices=False)
    S = torch.ones_like(S)
    S[-1] = 1/k

    return U @ torch.diag_embed(S) @ Vh

# %%
ks = [1,10,50,100,500,1000,5000]

conditioning_experiment = {k: {
    'ALISTA':None,
    'AL-DC-ISTA':None
} for k in ks}

n_ = 500
m_ = 250
p_ = 0.1

# Sensing matrix

A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
A_ /= torch.linalg.norm(A_, dim = 0)

for k in tqdm(ks):
    B = Conditioning(torch.clone(A_), k)

    train_set = SyntheticSignals(
        A = B,
        n = n_,        
        m = m_,
        p = p_,
        SNR = None,
        size = 10000,
        batch_size = 1000
        ).set_loader()

    test_set = SyntheticSignals(
        A = B,
        n = n_,        
        m = m_,
        p = p_,
        SNR = None,
        size = 1000
        ).set_loader()
    
    model_1 = ALISTA(torch.clone(B), 0.4, T = 16)
    layerwise_train(model_1, train_set, test_set, 'ALISTA', lr = 3e-3, ft_lr = 3e-5, verbose=False)
    conditioning_experiment[k]['ALISTA'] = model_1.compute_nmse_inference(test_set)[-1].cpu()

    model_2 = ALDC_ISTA(torch.clone(B), 'PNEG', 0.4, T = 16)
    layerwise_train_DC(model_2, train_set, test_set, 'AL-DC-ISTA', 'PNEG', lr = 3e-3, ft_lr = 3e-5, verbose=False)
    conditioning_experiment[k]['AL-DC-ISTA'] = model_2.compute_nmse_inference(test_set)[-1].cpu()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Linear layer initialized minimizing coherence!
# Linear layer initialized minimizing coherence!
#  14%|█▍        | 1/7 [25:48<2:34:53, 1548.89s/it]
# Linear layer initialized minimizing coherence!
# Linear layer initialized minimizing coherence!
#  29%|██▊       | 2/7 [50:01<2:04:20, 1492.13s/it]
# Linear layer initialized minimizing coherence!
# Linear layer initialized minimizing coherence!
#  43%|████▎     | 3/7 [1:15:01<1:39:42, 1495.61s/it]
# Linear layer initialized minimizing coherence!
# Linear layer initialized minimizing coherence!
#  57%|█████▋    | 4/7 [1:40:01<1:14:52, 1497.35s/it]
# Linear layer initialized minimizing coherence!
# Linear layer initialized minimizing coherence!
#  71%|███████▏  | 5/7 [2:06:25<50:57, 1528.63s/it]
# Linear layer initialized minimizing coherence!
# Linear layer initialized minimizing coherence!
#  86%|████████▌ | 6/7 [2:34:51<26:29, 1589.01s/it]
# Linear layer initialized minimizing coherence!
# Linear layer initialized minimizing coherence!
# 100%|██████████| 7/7 [2:58:15<00:00, 1527.94s/it]

# %%
conditioning_experiment
# Out:
# {1: {'ALISTA': tensor(-61.5615), 'AL-DC-ISTA': tensor(-75.1331)},
#  10: {'ALISTA': tensor(-61.3966), 'AL-DC-ISTA': tensor(-76.6237)},
#  50: {'ALISTA': tensor(-62.2799), 'AL-DC-ISTA': tensor(-77.9011)},
#  100: {'ALISTA': tensor(-61.8582), 'AL-DC-ISTA': tensor(-75.3886)},
#  500: {'ALISTA': tensor(-62.0387), 'AL-DC-ISTA': tensor(-78.3605)},
#  1000: {'ALISTA': tensor(-62.0197), 'AL-DC-ISTA': tensor(-78.1148)},
#  5000: {'ALISTA': tensor(-61.1420), 'AL-DC-ISTA': tensor(-53.7872)}}

# %%
import pickle

# %%
with open('conditioning_experiment.pkl', 'wb') as handle:
    pickle.dump(conditioning_experiment, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
SNRs = [1,10,20,30]

errors_experiment = {SNR: {
    'ALISTA':None,
    'AL-DC-ISTA':None
} for SNR in SNRs}

n_ = 500
m_ = 250
p_ = 0.1

# Sensing matrix

A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
A_ /= torch.linalg.norm(A_, dim = 0)

for SNR in tqdm(SNRs):

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 10000,
        batch_size = 1000
        ).set_loader()
    
    '''
    model_1 = ALISTA(torch.clone(A_), 0.4, T = 16)
    layerwise_train(model_1, train_set, test_set, 'ALISTA', lr = 3e-3, ft_lr = 3e-5, verbose=True)
    errors_experiment[SNR]['ALISTA'] = model_1.compute_nmse_inference(test_set)[-1].cpu()
    '''
    model_2 = ALDC_ISTA(torch.clone(A_), 'PNEG', 0.4, T = 16)
    layerwise_train_DC(model_2, train_set, test_set, 'AL-DC-ISTA', 'PNEG', lr = 3e-3, ft_lr = 3e-5, verbose=True)
    errors_experiment[SNR]['AL-DC-ISTA'] = model_2.compute_nmse_inference(test_set)[-1].cpu()

# %%
with open('errors_experiment.pkl', 'wb') as handle:
    pickle.dump(errors_experiment, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
errors_experiment
# Out:
# {1: {'ALISTA': tensor(-1.6746), 'AL-DC-ISTA': tensor(-1.7294)},
#  10: {'ALISTA': tensor(-9.2776), 'AL-DC-ISTA': tensor(-9.4370)},
#  20: {'ALISTA': tensor(-12.5047), 'AL-DC-ISTA': tensor(-12.7470)},
#  30: {'ALISTA': tensor(-14.5633), 'AL-DC-ISTA': tensor(-14.7739)},
#  40: {'ALISTA': tensor(-16.0360), 'AL-DC-ISTA': tensor(-16.2535)},
#  50: {'ALISTA': tensor(-17.0583), 'AL-DC-ISTA': tensor(-17.1243)},
#  60: {'ALISTA': tensor(-17.9102), 'AL-DC-ISTA': tensor(-17.9922)}}

# %%
plt.plot([errors_experiment[SNR]['ALISTA'] for SNR in SNRs])
plt.plot([errors_experiment[SNR]['AL-DC-ISTA'] for SNR in SNRs])

# %%
M = 10
LAYERS = 5
BETA_INIT = 0.4
EPOCHS = 50
SNR = None

ALISTA_LOSS = torch.zeros((M, LAYERS))
ALDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
ALDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
ALDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 200
    m_ = 150
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = ALISTA(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=True)

    model2 = ALDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=True)

    model3 = ALDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = ALDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    ALISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set).cpu()
    ALDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set).cpu()
    ALDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set).cpu()
    ALDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set).cpu()

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()

# %%
#ALISTA_LOSS = ALISTA_LOSS.cpu().numpy()
#ALDC_LISTA_EXP_LOSS = ALDC_LISTA_EXP_LOSS.cpu().numpy()
ALDC_LISTA_PNEG_LOSS = ALDC_LISTA_PNEG_LOSS.cpu().numpy()
ALDC_LISTA_SCAD_LOSS = ALDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

plt.plot(np.mean(ALISTA_LOSS, axis = 0), label='LISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(ALISTA_LOSS, axis = 0) - (2/np.sqrt(ALISTA_LOSS.shape[1])) * np.std(ALISTA_LOSS, axis = 0), 
                    np.mean(ALISTA_LOSS, axis = 0) + (2/np.sqrt(ALISTA_LOSS.shape[1])) * np.std(ALISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(ALDC_LISTA_EXP_LOSS, axis = 0), label='LDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(ALDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(ALDC_LISTA_EXP_LOSS.shape[1])) * np.std(ALDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(ALDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(ALDC_LISTA_EXP_LOSS.shape[1])) * np.std(ALDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(ALDC_LISTA_PNEG_LOSS, axis = 0), label='LDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(ALDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(ALDC_LISTA_PNEG_LOSS.shape[1])) * np.std(ALDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(ALDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(ALDC_LISTA_PNEG_LOSS.shape[1])) * np.std(ALDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(ALDC_LISTA_SCAD_LOSS, axis = 0), label='LDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(ALDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(ALDC_LISTA_SCAD_LOSS.shape[1])) * np.std(ALDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(ALDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(ALDC_LISTA_SCAD_LOSS.shape[1])) * np.std(ALDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
class ALDC_ISTA(nn.Module):
    def __init__(self, A, mode, lambd=0.1, p =0.012, p_max = 0.12, T = 5):
        super().__init__()
    
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        assert mode in ['EXP', 'PNEG', 'SCAD']

        self.mode = mode

        self.A = A.to(self.device)  # Move A to the correct device
        self.A.requires_grad = False

        self.T = T

        self.L = torch.max(torch.real(torch.linalg.eigvals(A.t() @ A))).to(self.device)

        # Initialization of the learnable parameters
        self.mu = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) / self.L, requires_grad=True)
        self.lambd = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * lambd, requires_grad=True)
        
        # Linear layers
        self.Z = torch.linalg.pinv(self.A.T).to(self.device) * lambd 

        self.W = self.W_optimization().to(self.device)
        self.W1 = torch.clone((self.W.T @ self.A)).to(self.device)
        self.W2 = torch.clone(self.W.T).to(self.device)
        self.W3  = torch.clone((self.W.T @ self.Z)).to(self.device)

        # Support selection mechanism parameters
        self.p = p
        self.p_max = p_max

        # Losses when doing inference (placeholder for NMSE accumulation)
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Mode setting for the layer
        if mode == 'EXP':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * lambd /self.L, requires_grad=True)
            self.ddx = self.ddxEXP
            self.eta = self.etaEXP

        if mode == 'PNEG':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * (-lambd /(0.1*self.L)), requires_grad=True)
            self.P = - nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) *0.1, requires_grad=True)
            self.ddx = self.ddxNEG
            self.eta = self.etaNEG

        if mode == 'SCAD':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * 1.5 * lambd / self.L, requires_grad=True)
            self.a = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * 2, requires_grad=True)
            self.ddx = self.ddxSCAD
            self.eta = self.etaSCAD
    
    #_________________________________________________________________
    #______________ METHODS FOR ENABLING DIFFERENT LAYERS_____________
    #_________________________________________________________________

    def W_optimization(self):
        N, M = self.A.shape
        W = cp.Variable((N, M))

        objective = cp.Minimize(cp.norm(W.T @ self.A.cpu().numpy(), 'fro'))
        constraints = [W[:, m].T @ self.A.cpu().numpy()[:, m] == 1 for m in range(M)]
        prob = cp.Problem(objective, constraints)

        prob.solve(solver=cp.MOSEK)
        print('Linear layer initialized minimizing coherence!')
        return torch.from_numpy(W.value).float()
    
    # Derivatives of the nonconvex components
    def ddxEXP(self, x, t):
        return torch.sign(x) * self.theta[t,:,:] * (1 - torch.exp(-self.theta[t,:,:] * torch.abs(x)))

    def ddxNEG(self, x, t):
        return -torch.sign(x) * self.P[t,:,:] * self.theta[t,:,:] * (1 - (1 + self.theta[t,:,:] * torch.abs(x)) ** (self.P[t,:,:] - 1))

    def ddxSCAD(self, x, t):
        abs_x = torch.abs(x)

        mask1 = (abs_x <= 1)
        mask2 = (1 / self.theta[t,:,:] < abs_x) & (abs_x <= self.a[t,:,:] / self.theta[t,:,:])
        mask3 = (abs_x > self.a[t,:,:] / self.theta[t,:,:])

        # Compute the value for each condition
        val1 = torch.zeros_like(x)
        val2 = torch.sign(x) * (2 * self.theta[t,:,:] * (self.theta[t,:,:] * abs_x - 1)) / (self.a[t,:,:] ** 2 - 1)
        val3 = torch.sign(x) * (2 * self.theta[t,:,:] / (self.a[t,:,:] + 1))

        # Apply the masks to compute the final result
        result = torch.where(mask1, val1, torch.where(mask2, val2, val3))

        return result

    # Parametrization for the surrogates
    def etaEXP(self, t):
        return self.theta[t,:,:]

    def etaNEG(self, t):
        return -self.P[t,:,:] * self.theta[t,:,:]

    def etaSCAD(self, t):
        return 2 * self.theta[t,:,:] / (self.a[t,:,:] + 1)
    
    #___________________________________________________________________
    #___________________________________________________________________
        
    def _shrink(self, x, beta, t):
        # Get the absolute values of the elements in x
        abs_x = torch.abs(x)
        
        # Sort the elements of x by magnitude along the last dimension (num_features)
        sorted_abs_x, _ = torch.sort(abs_x, dim=-1, descending=True)

        # Determine the threshold index corresponding to the top p% elements in each sample
        p = torch.min(torch.tensor([self.p * t, self.p_max], device=self.device))
        threshold_idx = int(p * x.shape[-1])
        
        # Get the magnitude threshold for the top p% of elements (per batch)
        if threshold_idx > 0:
            threshold_value = sorted_abs_x[:, threshold_idx - 1:threshold_idx]  # Shape: (batch_size, 1)
        else:
            threshold_value = torch.zeros(x.shape[0], 1, device=x.device)  # Shape: (batch_size, 1)

        # Create a mask to exclude the top p% of elements from shrinkage
        mask = abs_x >= threshold_value
        
        # Apply soft thresholding only to elements outside the top p%
        x_shrink = beta * F.softshrink(x / beta, lambd=1)
        
        # Return the original values for the top p% and the shrinked values for others
        return torch.where(mask, x, x_shrink)

    
    def forward(self, y, S=None):     
        # Move inputs to the correct device
        y = y.to(self.device)
        if S is not None:
            S = S.to(self.device)

        # Initial sparse estimate using the first layer
        x = self._shrink(self.mu[0, :, :] * torch.matmul(y, self.W2.t()), self.eta(0) * self.lambd[0,:,:] * self.mu[0,:,:], 0)
        
        # Loop over layers to refine the estimate
        for t in range(1, self.T + 1):
            x = self._shrink(x - self.mu[t, :, :] * (torch.matmul(x, self.W1.t()) - torch.matmul(y, self.W2.t()) + torch.matmul(self.ddx(x, t), self.W3.t())), 
                             self.eta(t) * self.lambd[t,:,:] * self.mu[t,:,:],
                             t)
            
            if S is not None:  # During inference, compute the NMSE at each layer
                with torch.no_grad():
                    mse_loss = F.mse_loss(x.detach(), S.detach(), reduction="sum")
                    signal_power = torch.sum(S.detach() ** 2)

                    self.losses[t - 1] += mse_loss.item()
                    self.est_powers[t - 1] += signal_power.item() + 1e-6

        return x

    # Method to compute NMSE during inference mode
    def compute_nmse_inference(self, test_loader):
        # Reset the losses accumulator
        self.losses = torch.zeros(self.T, device=self.device)
        
        # Iterate over test_loader
        for _, (Y, S) in enumerate(test_loader):
            Y, S = Y.to(self.device), S.to(self.device)
            _ = self.forward(Y, S)  # This will accumulate NMSE values
        
        # Convert accumulated NMSE to dB
        nmse_db = 10 * torch.log10(self.losses / self.est_powers)
        
        # Reset the losses after inference
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Return NMSE in dB for each layer
        return nmse_db

# %% [markdown]
# __________

# %%
class TiLDC_ISTA(nn.Module):
    def __init__(self, A, mode, lambd=0.1, p =0.012, p_max = 0.12, T = 5):
        super().__init__()
    
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        assert mode in ['EXP', 'PNEG', 'SCAD']

        self.mode = mode

        self.A = A.to(self.device)  # Move A to the correct device
        self.A.requires_grad = False

        self.T = T

        self.L = torch.max(torch.real(torch.linalg.eigvals(A.t() @ A))).to(self.device)

        # Initialization of the learnable parameters
        self.mu = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) / self.L, requires_grad=True)
        
        # Linear layers
        self.W1 = nn.Linear(A.shape[1], A.shape[0], bias=False).to(self.device)
        self.W1.weight.data = torch.clone(self.A.T).to(self.device) 

        self.W2 = nn.Linear(A.shape[1], A.shape[1], bias=False).to(self.device)


        # Support selection mechanism parameters
        self.p = p
        self.p_max = p_max

        # Losses when doing inference (placeholder for NMSE accumulation)
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Mode setting for the layer
        if mode == 'EXP':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * lambd /self.L, requires_grad=True)
            self.ddx = self.ddxEXP
            self.eta = self.etaEXP

        if mode == 'PNEG':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * (-lambd /self.L), requires_grad=True)
            self.P = - nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * 1, requires_grad=True)
            self.ddx = self.ddxNEG
            self.eta = self.etaNEG

        if mode == 'SCAD':
            self.theta = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * 1.5 * lambd / self.L, requires_grad=True)
            self.a = nn.Parameter(torch.ones(self.T + 1, 1, 1).to(self.device) * 2, requires_grad=True)
            self.ddx = self.ddxSCAD
            self.eta = self.etaSCAD

    #_________________________________________________________________
    #______________ METHODS FOR ENABLING DIFFERENT LAYERS_____________
    #_________________________________________________________________
    
    # Derivatives of the nonconvex components
    def ddxEXP(self, x, t):
        return torch.sign(x) * self.theta[t,:,:] * (1 - torch.exp(-self.theta[t,:,:] * torch.abs(x)))

    def ddxNEG(self, x, t):
        return -torch.sign(x) * self.P[t,:,:] * self.theta[t,:,:] * (1 - (1 + self.theta[t,:,:] * torch.abs(x)) ** (self.P[t,:,:] - 1))

    def ddxSCAD(self, x, t):
        abs_x = torch.abs(x)

        mask1 = (abs_x <= 1)
        mask2 = (1 / self.theta[t,:,:] < abs_x) & (abs_x <= self.a[t,:,:] / self.theta[t,:,:])
        mask3 = (abs_x > self.a[t,:,:] / self.theta[t,:,:])

        # Compute the value for each condition
        val1 = torch.zeros_like(x)
        val2 = torch.sign(x) * (2 * self.theta[t,:,:] * (self.theta[t,:,:] * abs_x - 1)) / (self.a[t,:,:] ** 2 - 1)
        val3 = torch.sign(x) * (2 * self.theta[t,:,:] / (self.a[t,:,:] + 1))

        # Apply the masks to compute the final result
        result = torch.where(mask1, val1, torch.where(mask2, val2, val3))

        return result

    # Parametrization for the surrogates
    def etaEXP(self, t):
        return self.theta[t,:,:]

    def etaNEG(self, t):
        return -self.P[t,:,:] * self.theta[t,:,:]

    def etaSCAD(self, t):
        return 2 * self.theta[t,:,:] / (self.a[t,:,:] + 1)
    
    #___________________________________________________________________
    #___________________________________________________________________
        
    def _shrink(self, x, beta, t):
        # Get the absolute values of the elements in x
        abs_x = torch.abs(x)
        
        # Sort the elements of x by magnitude along the last dimension (num_features)
        sorted_abs_x, _ = torch.sort(abs_x, dim=-1, descending=True)

        # Determine the threshold index corresponding to the top p% elements in each sample
        p = torch.min(torch.tensor([self.p * t, self.p_max], device=self.device))
        threshold_idx = int(p * x.shape[-1])
        
        # Get the magnitude threshold for the top p% of elements (per batch)
        if threshold_idx > 0:
            threshold_value = sorted_abs_x[:, threshold_idx - 1:threshold_idx]  # Shape: (batch_size, 1)
        else:
            threshold_value = torch.zeros(x.shape[0], 1, device=x.device)  # Shape: (batch_size, 1)

        # Create a mask to exclude the top p% of elements from shrinkage
        mask = abs_x >= threshold_value
        
        # Apply soft thresholding only to elements outside the top p%
        x_shrink = beta * F.softshrink(x / beta, lambd=1)
        
        # Return the original values for the top p% and the shrinked values for others
        return torch.where(mask, x, x_shrink)

    
    def forward(self, y, S=None):     
        # Move inputs to the correct device
        y = y.to(self.device)
        if S is not None:
            S = S.to(self.device)

        # Initial sparse estimate using the first layer
        x = self._shrink(self.mu[0, :, :] * self.W1(y), self.eta(0), 0)
        
        # Loop over layers to refine the estimate
        for t in range(1, self.T + 1):
            x = self._shrink(x - self.mu[t, :, :] * self.W1(torch.matmul(x, self.A.t()) - y) + self.eta(t) * self.ddx(x, t),
                             self.eta(t),
                             t)
            
            if S is not None:  # During inference, compute the NMSE at each layer
                with torch.no_grad():
                    mse_loss = F.mse_loss(x.detach(), S.detach(), reduction="sum")
                    signal_power = torch.sum(S.detach() ** 2)

                    self.losses[t - 1] += mse_loss.item()
                    self.est_powers[t - 1] += signal_power.item() + 1e-6

        return x

    # Method to compute NMSE during inference mode
    def compute_nmse_inference(self, test_loader):
        # Reset the losses accumulator
        self.losses = torch.zeros(self.T, device=self.device)
        
        # Iterate over test_loader
        for _, (Y, S) in enumerate(test_loader):
            Y, S = Y.to(self.device), S.to(self.device)
            _ = self.forward(Y, S)  # This will accumulate NMSE values
        
        # Convert accumulated NMSE to dB
        nmse_db = 10 * torch.log10(self.losses / self.est_powers)
        
        # Reset the losses after inference
        self.losses = torch.zeros(self.T, device=self.device)
        self.est_powers = torch.zeros(self.T, device=self.device)

        # Return NMSE in dB for each layer
        return nmse_db

# %%
M = 10
LAYERS = 5
BETA_INIT = 0.4
EPOCHS = 50
SNR = 10

TiLISTA_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 200
    m_ = 150
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = TiLISTA(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = TiLDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = TiLDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = TiLDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    TiLISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set).cpu()

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
# Out:
# 100%|██████████| 10/10 [10:42<00:00, 64.23s/it]

# %%
TiLISTA_LOSS = TiLISTA_LOSS.cpu().numpy()
TiLDC_LISTA_EXP_LOSS = TiLDC_LISTA_EXP_LOSS.cpu().numpy()
TiLDC_LISTA_PNEG_LOSS = TiLDC_LISTA_PNEG_LOSS.cpu().numpy()
TiLDC_LISTA_SCAD_LOSS = TiLDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

plt.plot(np.mean(TiLISTA_LOSS, axis = 0), label='TiLISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLISTA_LOSS, axis = 0) - (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    np.mean(TiLISTA_LOSS, axis = 0) + (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0), label='TiLDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0), label='TiLDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0), label='TiLDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# %%
M = 10
LAYERS = 5
BETA_INIT = 0.4
EPOCHS = 50
SNR = 10

TiLISTA_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_EXP_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_PNEG_LOSS = torch.zeros((M, LAYERS))
TiLDC_LISTA_SCAD_LOSS = torch.zeros((M, LAYERS))

ISTA_LOSS = torch.zeros((M, LAYERS))
FISTA_LOSS = torch.zeros((M, LAYERS))

for m in tqdm(range(M)):
    # Dimensions for the signal, its sparsity and its observation

    n_ = 200
    m_ = 150
    p_ = 0.1

    # Sensing matrix

    A_ = torch.normal(0, torch.sqrt(torch.tensor(1/m_)), size = (m_, n_))
    A_ /= torch.linalg.norm(A_, dim = 0)

    # Building a training set and a test set 
    train_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 4000
        ).set_loader()

    test_set = SyntheticSignals(
        A = A_,
        n = n_,        
        m = m_,
        p = p_,
        SNR = SNR,
        size = 1000
        ).set_loader()
    
    model1 = TiLISTA(torch.clone(A_), BETA_INIT, LAYERS)
    train(model1, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model2 = TiLDC_ISTA(torch.clone(A_), 'EXP', BETA_INIT, T = LAYERS)
    train(model2, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model3 = TiLDC_ISTA(torch.clone(A_), 'PNEG', BETA_INIT, T = LAYERS)
    train(model3, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    model4 = TiLDC_ISTA(torch.clone(A_), 'SCAD', BETA_INIT, T = LAYERS)
    train(model4, train_set, test_set, num_epochs = EPOCHS, verbose=False)

    TiLISTA_LOSS[m,:] = model1.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_EXP_LOSS[m,:] = model2.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_PNEG_LOSS[m,:] = model3.compute_nmse_inference(test_set).cpu()
    TiLDC_LISTA_SCAD_LOSS[m,:] = model4.compute_nmse_inference(test_set).cpu()

    ISTA_LOSS[m,:] = ISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
    FISTA_LOSS[m,:] = FISTA_BATCH(test_set, LAYERS, A_, rho = BETA_INIT).cpu()
# Out:
# 100%|██████████| 10/10 [09:58<00:00, 59.85s/it]

# %%
TiLISTA_LOSS = TiLISTA_LOSS.cpu().numpy()
TiLDC_LISTA_EXP_LOSS = TiLDC_LISTA_EXP_LOSS.cpu().numpy()
TiLDC_LISTA_PNEG_LOSS = TiLDC_LISTA_PNEG_LOSS.cpu().numpy()
TiLDC_LISTA_SCAD_LOSS = TiLDC_LISTA_SCAD_LOSS.cpu().numpy()

ISTA_LOSS = ISTA_LOSS.cpu().numpy()
FISTA_LOSS = FISTA_LOSS.cpu().numpy()

plt.plot(np.mean(TiLISTA_LOSS, axis = 0), label='TiLISTA', color='darkred', marker = '8')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLISTA_LOSS, axis = 0) - (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    np.mean(TiLISTA_LOSS, axis = 0) + (2/np.sqrt(TiLISTA_LOSS.shape[1])) * np.std(TiLISTA_LOSS, axis = 0), 
                    color='darkred', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0), label='TiLDC-ISTA-EXP', color='forestgreen', marker = '>')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_EXP_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_EXP_LOSS.shape[1])) * np.std(TiLDC_LISTA_EXP_LOSS, axis = 0), 
                    color='limegreen', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0), label='TiLDC-ISTA-PNEG', color='darkolivegreen', marker = '<')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_PNEG_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_PNEG_LOSS.shape[1])) * np.std(TiLDC_LISTA_PNEG_LOSS, axis = 0), 
                    color='greenyellow', 
                    alpha=0.2)

plt.plot(np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0), label='TiLDC-ISTA-SCAD', color='darkseagreen', marker = '^')
plt.fill_between(range(LAYERS), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) - (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    np.mean(TiLDC_LISTA_SCAD_LOSS, axis = 0) + (2/np.sqrt(TiLDC_LISTA_SCAD_LOSS.shape[1])) * np.std(TiLDC_LISTA_SCAD_LOSS, axis = 0), 
                    color='palegreen', 
                    alpha=0.2)

plt.plot(np.mean(ISTA_LOSS, axis = 0), label='ISTA', color='darkblue', marker = 'D')
plt.fill_between(range(LAYERS), 
                np.mean(ISTA_LOSS, axis = 0) - (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                np.mean(ISTA_LOSS, axis = 0) + (2/np.sqrt(ISTA_LOSS.shape[1])) * np.std(ISTA_LOSS, axis = 0), 
                color='cornflowerblue', 
                alpha=0.2)

plt.plot(np.mean(FISTA_LOSS, axis = 0), label='FISTA', color='deepskyblue', marker = 'v')
plt.fill_between(range(LAYERS), 
                np.mean(FISTA_LOSS, axis = 0) - (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                np.mean(FISTA_LOSS, axis = 0) + (2/np.sqrt(FISTA_LOSS.shape[1])) * np.std(FISTA_LOSS, axis = 0), 
                color='skyblue', 
                alpha=0.2)

plt.xticks(range(LAYERS))

plt.ylabel('NMSE (dB)')
plt.xlabel('Iterations / Layer')


plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
